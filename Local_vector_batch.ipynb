# %%
# general tools
import os
import sys
import time
import h5py
import random
from glob import glob

import numpy as np
from random import shuffle

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend
from keras_unet_collection import utils as k_utils
# Out:
# 2022-10-29 20:15:01.643149: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
sys.path.insert(0, '/glade/u/home/ksha/NCAR/')
sys.path.insert(0, '/glade/u/home/ksha/NCAR/libs/')

from namelist import *
import data_utils as du

# %%
def pos_mixer(TRAIN, L, a0=0, a1=0.2):
    data_shape = TRAIN.shape
    out = np.empty((L, data_shape[-1]))
    
    for i in range(L):
        inds = np.random.choice(data_shape[0], 2)
        a = np.random.uniform(a0, a1)
        out[i, :] = a*TRAIN[inds[0], :] + (1-a)*TRAIN[inds[1], :]
    return out

# %%
def create_model():

    IN = keras.Input((768,))

    X = IN

    X = keras.layers.Dense(1024, activity_regularizer=keras.regularizers.L2(1e-2))(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.Activation("gelu")(X)

    X = keras.layers.Dropout(0.3)(X)
    #X = keras.layers.GaussianDropout(0.1)(X)

    X = keras.layers.Dense(512, activity_regularizer=keras.regularizers.L2(1e-2))(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.Activation("gelu")(X)

    X = keras.layers.Dropout(0.3)(X)
    #X = keras.layers.GaussianDropout(0.1)(X)

    X = keras.layers.Dense(128, activity_regularizer=keras.regularizers.L2(1e-2))(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.Activation("gelu")(X)

    X = keras.layers.Dropout(0.3)(X)

    X = keras.layers.Dense(64, activity_regularizer=keras.regularizers.L2(1e-2))(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.Activation("gelu")(X)

    OUT = X
    OUT = keras.layers.Dense(1, activation='sigmoid', bias_initializer=keras.initializers.Constant(-10))(OUT)

    model = keras.models.Model(inputs=IN, outputs=OUT)
    
    return model

# %%
def verif_metric(VALID_target, Y_pred, ref):


    # fpr, tpr, thresholds = roc_curve(VALID_target.ravel(), Y_pred.ravel())
    # AUC = auc(fpr, tpr)
    # AUC_metric = 1 - AUC
    
    BS = np.mean((VALID_target.ravel() - Y_pred.ravel())**2)
    #ll = log_loss(VALID_target.ravel(), Y_pred.ravel())
    
    #print('{}'.format(BS))
    metric = BS

    return metric / ref

# %%
def set_seeds(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)

# %%
batch_dir = '/glade/scratch/ksha/DATA/NCAR_batch/'
temp_dir = '/glade/work/ksha/NCAR/Keras_models/'

key = 'HEAD_Lead2'

min_del = 0
max_tol = 10 # early stopping with patience

epochs = 500
batch_size = 200
L_train = 200

# %%
with h5py.File(save_dir+'HRRR_domain.hdf', 'r') as h5io:
    land_mask_80km = h5io['land_mask_80km'][...]
    
grid_shape = land_mask_80km.shape

# %% [markdown]
# ### Training set

# %%
data_lead1_p0 = np.load('/glade/work/ksha/NCAR/TRAIN_pred_lead1_part0_vec2.npy', allow_pickle=True)[()]
data_lead1_p1 = np.load('/glade/work/ksha/NCAR/TRAIN_pred_lead1_part1_vec2.npy', allow_pickle=True)[()]
data_lead1_p2 = np.load('/glade/work/ksha/NCAR/TRAIN_pred_lead1_part2_vec2.npy', allow_pickle=True)[()]

data_lead2_p0 = np.load('/glade/work/ksha/NCAR/TRAIN_pred_lead2_part0_vec2.npy', allow_pickle=True)[()]
data_lead2_p1 = np.load('/glade/work/ksha/NCAR/TRAIN_pred_lead2_part1_vec2.npy', allow_pickle=True)[()]
data_lead2_p2 = np.load('/glade/work/ksha/NCAR/TRAIN_pred_lead2_part2_vec2.npy', allow_pickle=True)[()]

data_lead3_p0 = np.load('/glade/work/ksha/NCAR/TRAIN_pred_lead3_part0_vec2.npy', allow_pickle=True)[()]
data_lead3_p1 = np.load('/glade/work/ksha/NCAR/TRAIN_pred_lead3_part1_vec2.npy', allow_pickle=True)[()]
data_lead3_p2 = np.load('/glade/work/ksha/NCAR/TRAIN_pred_lead3_part2_vec2.npy', allow_pickle=True)[()]

data_lead4_p0 = np.load('/glade/work/ksha/NCAR/TRAIN_pred_lead4_part0_vec2.npy', allow_pickle=True)[()]
data_lead4_p1 = np.load('/glade/work/ksha/NCAR/TRAIN_pred_lead4_part1_vec2.npy', allow_pickle=True)[()]
data_lead4_p2 = np.load('/glade/work/ksha/NCAR/TRAIN_pred_lead4_part2_vec2.npy', allow_pickle=True)[()]

TRAIN_256 = np.concatenate((data_lead2_p0['y_vector'], 
                            data_lead2_p1['y_vector'], 
                            data_lead2_p2['y_vector'],
                            data_lead3_p0['y_vector'], 
                            data_lead3_p1['y_vector'], 
                            data_lead3_p2['y_vector'],
                            data_lead4_p0['y_vector'], 
                            data_lead4_p1['y_vector'], 
                            data_lead4_p2['y_vector'],), axis=0)


TRAIN_pred = np.concatenate((data_lead2_p0['y_pred'], 
                             data_lead2_p1['y_pred'], 
                             data_lead2_p2['y_pred'],
                             data_lead3_p0['y_pred'], 
                             data_lead3_p1['y_pred'], 
                             data_lead3_p2['y_pred'],
                             data_lead4_p0['y_pred'], 
                             data_lead4_p1['y_pred'], 
                             data_lead4_p2['y_pred'],), axis=0)

TRAIN_Y = np.concatenate((data_lead2_p0['y_true'], 
                          data_lead2_p1['y_true'], 
                          data_lead2_p2['y_true'],
                          data_lead3_p0['y_true'], 
                          data_lead3_p1['y_true'], 
                          data_lead3_p2['y_true'],
                          data_lead4_p0['y_true'], 
                          data_lead4_p1['y_true'], 
                          data_lead4_p2['y_true'],), axis=0)

TRAIN_256_pick = TRAIN_256 #[flag_pick_train, :]
TRAIN_pred_pick = TRAIN_pred #[flag_pick_train, :]
TRAIN_Y_pick = TRAIN_Y #[flag_pick_train]

TRAIN_256_pos = TRAIN_256[TRAIN_Y==1]
TRAIN_256_neg = TRAIN_256[TRAIN_Y==0]

filename_valid = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch/VALID*neg_neg_neg*lead2.npy")) + \
                 sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch/VALID*pos*lead2.npy"))

data_p_valid = np.load('/glade/work/ksha/NCAR/TEST_pred_lead2_vec2.npy', allow_pickle=True)[()]

filename_test = filename_valid + \
                sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v4/*neg_neg_neg*lead{}.npy".format(2))) + \
                sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v4/*pos*lead{}.npy".format(2)))

data_p_test = np.load('/glade/work/ksha/NCAR/TEST_pred_lead2_v4_vec2.npy', allow_pickle=True)[()]

TEST_256 = np.concatenate((data_p_valid['y_vector'], data_p_test['y_vector']), axis=0)
TEST_pred = np.concatenate((data_p_valid['y_pred'], data_p_test['y_pred']), axis=0)
TEST_Y = np.concatenate((data_p_valid['y_true'], data_p_test['y_true']), axis=0)

# %%
for ix in range(grid_shape[0]):
    for iy in range(grid_shape[1]):
        if land_mask_80km[ix, iy]:

            name_block5 = []

            for i in range(ix-2, ix+3):
                for j in range(iy-2, iy+3):
                    name_block5.append('indx{}_indy{}'.format(i, j))

            L_test = len(filename_test)

            flag_pick_test = [False,]*L_test
            filename_pick_test = []

            for i, name in enumerate(filename_test):
                for patterns in name_block5:
                    if patterns in name:
                        flag_pick_test[i] = True
                        filename_pick_test.append(name)
                        break;

            # ========== Sample Checks ========== #

            N_samples = np.sum(np.array(flag_pick_test))

            if N_samples < 1:
                continue;

            TEST_256_pick = TEST_256[flag_pick_test, :]
            TEST_pred_pick = TEST_pred[flag_pick_test, :]
            TEST_Y_pick = TEST_Y[flag_pick_test]

            if np.sum(TEST_Y_pick) < 25:
                continue;

            ref = np.sum(TEST_Y_pick) / len(TEST_Y_pick)

            # =========== Model Section ========== #

            model_name = '{}_ix{}_iy{}'.format(key, ix, iy)
            model_path = temp_dir+model_name

            model = create_model()

            model.compile(loss=keras.losses.BinaryCrossentropy(from_logits=False),
                          optimizer=keras.optimizers.Adam(lr=1e-5))

            tol = 0
            
            print('===== ix:{}; iy:{} starts ====='.format(ix, iy))
            
            # ========== Training loop ========== #
            L_pos = len(TRAIN_256_pos)
            L_neg = len(TRAIN_256_neg)

            training_rounds = 10
            seeds = [12342, 2536234, 98765, 473, 865, 7456, 69472, 3456357, 3425, 678]

            record = 1.1
            print("Initial record: {}".format(record))


            min_del = 0
            max_tol = 10 # early stopping with patience

            epochs = 500
            batch_size = 200
            L_train = 200 #int(len(TRAIN_Y_pick) / batch_size)

            for r in range(training_rounds):
                if r == 0:
                    tol = 0
                else:
                    tol = -200

                model = create_model()

                model.compile(loss=keras.losses.BinaryCrossentropy(from_logits=False),
                              optimizer=keras.optimizers.Adam(lr=1e-5))

                set_seeds(seeds[r])
                print('Training round {}'.format(r))

                for i in range(epochs):

                    #backend.set_value(model.optimizer.learning_rate, learning_rate[i])

                    #print('epoch = {}'.format(i))
                    start_time = time.time()

                    # loop of batch
                    for j in range(L_train):

                        #N_aug = int(np.random.uniform(2, 7))
                        #N_pos = int(np.random.uniform(30, 50))
                        N_pos = 100
                        #N_aug = int(np.random.uniform(20, 45))

                        N_neg = batch_size - N_pos

                        ind_neg = du.shuffle_ind(L_neg)
                        ind_pos = du.shuffle_ind(L_pos)

                        ind_neg_pick = ind_neg[:N_neg]
                        ind_pos_pick = ind_pos[:N_pos]

                        X_batch_neg = TRAIN_256_neg[ind_neg_pick, :] #
                        X_batch_pos = pos_mixer(TRAIN_256_pos, N_pos, a0=0, a1=0.05) # 

                        # np.random.shuffle(TRAIN_256_neg)
                        # np.random.shuffle(TRAIN_256_pos)

                        # X_batch_neg = TRAIN_256_neg[:N_neg, :]
                        # X_batch_pos = TRAIN_256_pos[:N_pos, :]

                        X_batch = np.concatenate((X_batch_neg, X_batch_pos), axis=0)

                        Y_batch = np.concatenate((np.random.uniform(0.0, 0.01, size=N_neg), 
                                                  np.random.uniform(0.98, 0.999, size=N_pos)), axis=0)

                        # Y_batch = np.ones([batch_size,])
                        # Y_batch[:N_neg] = 0.0

                        ind_ = du.shuffle_ind(batch_size)

                        X_batch = X_batch[ind_, :]
                        Y_batch = Y_batch[ind_]

                        # train on batch
                        model.train_on_batch(X_batch, Y_batch);

                    # epoch end operations
                    Y_pred = model.predict([TEST_256_pick])

                    Y_pred[Y_pred<0] = 0
                    Y_pred[Y_pred>1] = 1

                    record_temp = verif_metric(TEST_Y_pick, Y_pred, ref)

                    # if i % 10 == 0:
                    #     model.save(model_path_backup)

                    if (record - record_temp > min_del):
                        print('Validation loss improved from {} to {}'.format(record, record_temp))
                        record = record_temp
                        tol = 0
                        #print('tol: {}'.format(tol))
                        # save
                        print('save to: {}'.format(model_path))
                        model.save(model_path)
                    else:
                        print('Validation loss {} NOT improved'.format(record_temp))
                        if record_temp > 1.0:
                            print('Early stopping')
                            break;
                        else:
                            tol += 1
                            if tol >= max_tol:
                                print('Early stopping')
                                break;
                            else:
                                continue;
                    print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 2022-10-29 20:16:02.304527: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-10-29 20:16:02.431965: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-10-29 20:16:02.493652: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:1a:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2022-10-29 20:16:02.493722: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-29 20:16:02.662622: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-10-29 20:16:02.662700: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-10-29 20:16:02.751808: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-29 20:16:02.866700: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-29 20:16:02.974126: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-10-29 20:16:03.061206: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-10-29 20:16:03.198844: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-10-29 20:16:03.200012: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-10-29 20:16:03.205790: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-29 20:16:03.206184: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-10-29 20:16:03.206824: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:1a:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2022-10-29 20:16:03.206877: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-29 20:16:03.206912: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-10-29 20:16:03.206924: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-10-29 20:16:03.206935: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-29 20:16:03.206944: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-29 20:16:03.206954: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-10-29 20:16:03.206964: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-10-29 20:16:03.206974: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-10-29 20:16:03.207828: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-10-29 20:16:03.207883: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-29 20:16:06.071908: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-29 20:16:06.072057: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-10-29 20:16:06.072163: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-10-29 20:16:06.075819: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30132 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:1a:00.0, compute capability: 7.0)
# ===== ix:19; iy:46 starts =====
# Initial record: 1.1
# Training round 0
# 2022-10-29 20:16:09.483779: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-10-29 20:16:09.513958: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2600000000 Hz
# 2022-10-29 20:16:09.909477: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# Validation loss improved from 1.1 to 0.9998328737149161
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# 2022-10-29 20:16:24.866986: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 18.188510179519653 seconds ---
# Validation loss improved from 0.9998328737149161 to 0.9997563894458157
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.544184923171997 seconds ---
# Validation loss improved from 0.9997563894458157 to 0.9996680195166937
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.730008363723755 seconds ---
# Validation loss improved from 0.9996680195166937 to 0.9995629281977984
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.353801727294922 seconds ---
# Validation loss improved from 0.9995629281977984 to 0.999407124766116
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.48692512512207 seconds ---
# Validation loss improved from 0.999407124766116 to 0.9992379636946808
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.119373559951782 seconds ---
# Validation loss improved from 0.9992379636946808 to 0.9989628983413558
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.420088768005371 seconds ---
# Validation loss improved from 0.9989628983413558 to 0.9987350786360526
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.09561800956726 seconds ---
# Validation loss improved from 0.9987350786360526 to 0.9984115738635913
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 13.887331485748291 seconds ---
# Validation loss improved from 0.9984115738635913 to 0.9979511091680395
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.58388090133667 seconds ---
# Validation loss improved from 0.9979511091680395 to 0.997286720504358
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.193569660186768 seconds ---
# Validation loss improved from 0.997286720504358 to 0.9968563641572685
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 13.900959014892578 seconds ---
# Validation loss improved from 0.9968563641572685 to 0.9961824062026333
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.392775297164917 seconds ---
# Validation loss improved from 0.9961824062026333 to 0.9950290474113919
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.542903900146484 seconds ---
# Validation loss improved from 0.9950290474113919 to 0.9944141589834231
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 13.251005411148071 seconds ---
# Validation loss improved from 0.9944141589834231 to 0.9931522112551214
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 13.672358512878418 seconds ---
# Validation loss improved from 0.9931522112551214 to 0.9924912585974215
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.4077730178833 seconds ---
# Validation loss improved from 0.9924912585974215 to 0.9912957828451378
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.148755550384521 seconds ---
# Validation loss improved from 0.9912957828451378 to 0.9911328671874206
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 13.877233505249023 seconds ---
# Validation loss improved from 0.9911328671874206 to 0.9878480723168366
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.127741575241089 seconds ---
# Validation loss improved from 0.9878480723168366 to 0.9875767507079434
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.226495265960693 seconds ---
# Validation loss improved from 0.9875767507079434 to 0.9826003626791495
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.406737089157104 seconds ---
# Validation loss improved from 0.9826003626791495 to 0.9820576568353039
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 13.698779344558716 seconds ---
# Validation loss improved from 0.9820576568353039 to 0.9802552344164779
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.220976114273071 seconds ---
# Validation loss improved from 0.9802552344164779 to 0.9796310166197144
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.05185866355896 seconds ---
# Validation loss improved from 0.9796310166197144 to 0.976428287851974
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 13.915675401687622 seconds ---
# Validation loss improved from 0.976428287851974 to 0.971040555468714
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.762712478637695 seconds ---
# Validation loss improved from 0.971040555468714 to 0.9618893777505995
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 13.890067338943481 seconds ---
# Validation loss 0.9625032756081056 NOT improved
# Validation loss 0.9621165343451386 NOT improved
# Validation loss 0.9635261016982885 NOT improved
# Validation loss improved from 0.9618893777505995 to 0.9606781918679181
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.572263479232788 seconds ---
# Validation loss improved from 0.9606781918679181 to 0.9518909101548702
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.508434534072876 seconds ---
# Validation loss 0.9583806511356754 NOT improved
# Validation loss 0.9567981596697976 NOT improved
# Validation loss 0.9645012571736493 NOT improved
# Validation loss 0.9634629483635246 NOT improved
# Validation loss 0.9671383445545363 NOT improved
# Validation loss 0.9580847672445356 NOT improved
# Validation loss 0.9785831939550003 NOT improved
# Validation loss 0.9901893192720352 NOT improved
# Validation loss 0.9945768892282828 NOT improved
# Validation loss 0.992795263357395 NOT improved
# Early stopping
# Training round 1
# Validation loss 0.9998142084812256 NOT improved
# Validation loss 0.9995573555148193 NOT improved
# Validation loss 0.9993547418791693 NOT improved
# Validation loss 0.9990362542732528 NOT improved
# Validation loss 0.9985258147148423 NOT improved
# Validation loss 0.9980785564209774 NOT improved
# Validation loss 0.9974190151324066 NOT improved
# Validation loss 0.9965038799164848 NOT improved
# Validation loss 0.9957804385336352 NOT improved
# Validation loss 0.9944582616376931 NOT improved
# Validation loss 0.9935856378282018 NOT improved
# Validation loss 0.9923016650316135 NOT improved
# Validation loss 0.9907099271195537 NOT improved
# Validation loss 0.988864062354468 NOT improved
# Validation loss 0.986199260207217 NOT improved
# Validation loss 0.9840288042109538 NOT improved
# Validation loss 0.9799849148454534 NOT improved
# Validation loss 0.9795007493324119 NOT improved
# Validation loss 0.9775585803963617 NOT improved
# Validation loss 0.9712240135953246 NOT improved
# Validation loss 0.9679596413597603 NOT improved
# Validation loss 0.9667028109319264 NOT improved
# Validation loss 0.962133851901522 NOT improved
# Validation loss 0.9597998802110159 NOT improved
# Validation loss 0.995763998969427 NOT improved
# Validation loss 0.9943674721837608 NOT improved
# Validation loss 0.9936752932875849 NOT improved
# Validation loss 0.9918506596404495 NOT improved
# Validation loss 0.9906802900051926 NOT improved
# Validation loss 0.9892422787218386 NOT improved
# Validation loss 0.9870127329719492 NOT improved
# Validation loss 0.9871963670315399 NOT improved
# Validation loss 0.984290625696215 NOT improved
# Validation loss 0.9853551947054424 NOT improved
# Validation loss 0.9837408637222709 NOT improved
# Validation loss 0.9799573032855504 NOT improved
# Validation loss 0.976921798732253 NOT improved
# Validation loss 0.9749039595194285 NOT improved
# Validation loss 0.9736509591690666 NOT improved
# Validation loss 0.9742072290979319 NOT improved
# Validation loss 0.9699283553007826 NOT improved
# Validation loss 0.9704299873192104 NOT improved
# Validation loss 0.9684332315842119 NOT improved
# Validation loss 0.9723242553762982 NOT improved
# Validation loss 0.9701775589688041 NOT improved
# Validation loss 0.976796017651511 NOT improved
# Validation loss 0.9829525036388003 NOT improved
# Validation loss 0.983869051221229 NOT improved
# Validation loss 0.9883517013199472 NOT improved
# Validation loss 0.9950439156637345 NOT improved
# Validation loss 1.0079668603490937 NOT improved
# Early stopping
# Training round 4
# Validation loss 0.9995795047146384 NOT improved
# Validation loss 0.9989172124542057 NOT improved
# Validation loss 0.9980545355167123 NOT improved
# Validation loss 0.9968763318344039 NOT improved
# Validation loss 0.9950021674927592 NOT improved
# Validation loss 0.9920732817804376 NOT improved
# Validation loss 0.9877481370339503 NOT improved
# Validation loss 0.9851810669397173 NOT improved
# Validation loss 0.9797449063417193 NOT improved
# Validation loss 0.9750426288029005 NOT improved
# Validation loss 0.9683206048517983 NOT improved
# Validation loss 0.9608533600145402 NOT improved
# Validation loss 0.9605510627687612 NOT improved
# Validation loss 0.9567563674176025 NOT improved
# Validation loss improved from 0.9513857634732357 to 0.9496032580613009
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 13.916391849517822 seconds ---
# Validation loss improved from 0.9496032580613009 to 0.9434393772552708
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.261483907699585 seconds ---
# Validation loss improved from 0.9434393772552708 to 0.9392707807681938
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.439286231994629 seconds ---
# Validation loss improved from 0.9392707807681938 to 0.9323207459746409
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.38232421875 seconds ---
# Validation loss improved from 0.9323207459746409 to 0.930726364427985
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.007433652877808 seconds ---
# Validation loss improved from 0.930726364427985 to 0.9300184196581514
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.396704196929932 seconds ---
# Validation loss improved from 0.9300184196581514 to 0.9238443482037293
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 13.844482183456421 seconds ---
# Validation loss improved from 0.9238443482037293 to 0.923546140701516
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 14.267195224761963 seconds ---
# Validation loss improved from 0.923546140701516 to 0.9206776382188677
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy46/assets
# --- 13.710877895355225 seconds ---
# Validation loss 0.9261921576139446 NOT improved
# Validation loss 0.924868558327629 NOT improved
# Validation loss 0.9317712976028341 NOT improved
# Validation loss 0.9282948989507588 NOT improved
# Validation loss 0.9441401651682138 NOT improved
# Validation loss 0.9309004470651292 NOT improved
# Validation loss 0.9506891361314663 NOT improved
# Validation loss 0.9541480728840515 NOT improved
# Validation loss 0.9745188049681258 NOT improved
# Validation loss 0.993034775965999 NOT improved
# Early stopping
# Training round 5
# Validation loss 0.9997391741037758 NOT improved
# Validation loss 0.9994192434480513 NOT improved
# Validation loss 0.9992643511134649 NOT improved
# Validation loss 0.9990334682630321 NOT improved
# Validation loss 0.9988934572878427 NOT improved
# Validation loss 0.9985516085144394 NOT improved
# Validation loss 0.99815513010085 NOT improved
# Validation loss 0.9976262148223063 NOT improved
# Validation loss 0.9968548160643801 NOT improved
# Validation loss 0.9962541022114266 NOT improved
# Validation loss 0.9954181520165503 NOT improved
# Validation loss 0.9945141542842267 NOT improved
# Validation loss 0.9937640538356002 NOT improved
# Validation loss 0.9927293374909377 NOT improved
# Validation loss 0.9914538479533196 NOT improved
# Validation loss 0.9906726214777448 NOT improved
# Validation loss 0.989533021749396 NOT improved
# Validation loss 0.9887460465365044 NOT improved
# Validation loss 0.9859575588591389 NOT improved
# Validation loss 0.9835663863509644 NOT improved
# Validation loss 0.9818000388351985 NOT improved
# Validation loss 0.9811198598768099 NOT improved
# Validation loss 0.9771572748237561 NOT improved
# Validation loss 0.9771039783899059 NOT improved
# Validation loss 0.9749150009661154 NOT improved
# Validation loss 0.9728680889024524 NOT improved
# Validation loss 0.9834576941067794 NOT improved
# Validation loss 0.9794514424650815 NOT improved
# Validation loss 0.9797807723719862 NOT improved
# Validation loss 0.9993021476922986 NOT improved
# Validation loss 1.0126978306102918 NOT improved
# Early stopping
# Training round 9
# Validation loss 0.9997397075358634 NOT improved
# Validation loss 0.999293862528872 NOT improved
# Validation loss 0.9992680999427741 NOT improved
# Validation loss 0.999087245830266 NOT improved
# Validation loss 0.9987360089461796 NOT improved
# Validation loss 0.9982669902452032 NOT improved
# Validation loss 0.9977625115359348 NOT improved
# Validation loss 0.9968245629170005 NOT improved
# Validation loss 0.9962283375459112 NOT improved
# Validation loss 0.9951439533609628 NOT improved
# Validation loss 0.9937938591439298 NOT improved
# Validation loss 0.9920609114957338 NOT improved
# Validation loss 0.9921491149762961 NOT improved
# Validation loss 0.9895775149985341 NOT improved
# Validation loss 0.9896427035642718 NOT improved
# Validation loss 0.9873674097428952 NOT improved
# Validation loss 0.9848875569520481 NOT improved
# Validation loss 0.9854615886781499 NOT improved
# Validation loss 0.9811574476764873 NOT improved
# Validation loss 0.9819937265899814 NOT improved
# Validation loss 0.9809010435193262 NOT improved
# Validation loss 0.9755608574070807 NOT improved
# Validation loss 0.9682646554560507 NOT improved
# Validation loss 0.9625175738506169 NOT improved
# Validation loss 0.9614961069986214 NOT improved
# Validation loss 0.9663510944434803 NOT improved
# Validation loss 0.958280522506269 NOT improved
# Validation loss 0.9588604231559591 NOT improved
# Validation loss 0.952078641425961 NOT improved
# Validation loss 0.949590035186254 NOT improved
# Validation loss 0.9530050187543089 NOT improved
# Validation loss 0.9493045512920925 NOT improved
# Validation loss 0.9493831069597534 NOT improved
# Validation loss 0.9469752077179648 NOT improved
# Validation loss 0.9655268448585442 NOT improved
# Validation loss 0.9561942772011008 NOT improved
# Validation loss 1.005027177982633 NOT improved
# Early stopping
# ===== ix:19; iy:47 starts =====
# Initial record: 1.1
# Training round 0
# Validation loss improved from 1.1 to 0.9997276291506103
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 17.060575485229492 seconds ---
# Validation loss improved from 0.9997276291506103 to 0.9993806108074461
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.480597257614136 seconds ---
# Validation loss improved from 0.9993806108074461 to 0.9991358610528154
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 15.382387161254883 seconds ---
# Validation loss improved from 0.9991358610528154 to 0.99883796693705
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.459710121154785 seconds ---
# Validation loss improved from 0.99883796693705 to 0.9983951163919169
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.710415601730347 seconds ---
# Validation loss improved from 0.9983951163919169 to 0.9980463197459457
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.853334903717041 seconds ---
# Validation loss improved from 0.9980463197459457 to 0.9973548362618992
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.4968581199646 seconds ---
# Validation loss improved from 0.9973548362618992 to 0.9972885596143808
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 15.172986507415771 seconds ---
# Validation loss improved from 0.9972885596143808 to 0.9965030664296015
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 15.197092533111572 seconds ---
# Validation loss improved from 0.9965030664296015 to 0.9960053542450985
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 15.277160882949829 seconds ---
# Validation loss improved from 0.9960053542450985 to 0.9955696048837861
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.188541650772095 seconds ---
# Validation loss improved from 0.9955696048837861 to 0.9950068364380269
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.865450382232666 seconds ---
# Validation loss improved from 0.9950068364380269 to 0.9938745543134254
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 13.822354078292847 seconds ---
# Validation loss improved from 0.9938745543134254 to 0.9929491396323714
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.857126235961914 seconds ---
# Validation loss improved from 0.9929491396323714 to 0.9929016982235976
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 15.353963136672974 seconds ---
# Validation loss improved from 0.9929016982235976 to 0.9917856530740942
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 13.416079998016357 seconds ---
# Validation loss improved from 0.9917856530740942 to 0.9911668387246522
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 13.5370192527771 seconds ---
# Validation loss improved from 0.9911668387246522 to 0.9907760020001255
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.045281648635864 seconds ---
# Validation loss improved from 0.9907760020001255 to 0.989626398572994
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 13.57442045211792 seconds ---
# Validation loss improved from 0.989626398572994 to 0.9880554624081228
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.125439167022705 seconds ---
# Validation loss improved from 0.9880554624081228 to 0.986002644293963
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 13.926972150802612 seconds ---
# Validation loss improved from 0.986002644293963 to 0.985008652171165
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.340191125869751 seconds ---
# Validation loss improved from 0.985008652171165 to 0.981794459973485
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.827466249465942 seconds ---
# Validation loss improved from 0.981794459973485 to 0.9755492963803418
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 13.857962608337402 seconds ---
# Validation loss 0.9804989871161661 NOT improved
# Validation loss 0.9806716121601488 NOT improved
# Validation loss 0.9761090243154261 NOT improved
# Validation loss 0.9767944273301994 NOT improved
# Validation loss 0.9760210800159768 NOT improved
# Validation loss improved from 0.9755492963803418 to 0.9726304195072788
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.065940618515015 seconds ---
# Validation loss 0.975441866304456 NOT improved
# Validation loss 0.9763715398230498 NOT improved
# Validation loss 0.9854790956946179 NOT improved
# Validation loss 0.9886802638858492 NOT improved
# Validation loss 0.9976434129598869 NOT improved
# Validation loss 1.0011946108966296 NOT improved
# Early stopping
# Training round 1
# Validation loss 0.9997997140810055 NOT improved
# Validation loss 0.9995266097524261 NOT improved
# Validation loss 0.9993319867133914 NOT improved
# Validation loss 0.9990187784507334 NOT improved
# Validation loss 0.9985103114087366 NOT improved
# Validation loss 0.9980707512927659 NOT improved
# Validation loss 0.9974242408319433 NOT improved
# Validation loss 0.9965210601696425 NOT improved
# Validation loss 0.9957607135418611 NOT improved
# Validation loss 0.9944996587940855 NOT improved
# Validation loss 0.9936033469483971 NOT improved
# Validation loss 0.9922884793765524 NOT improved
# Validation loss 0.9908013771299533 NOT improved
# Validation loss 0.9888220044156891 NOT improved
# Validation loss 0.9862079502175645 NOT improved
# Validation loss 0.9842324039575026 NOT improved
# Validation loss 0.9800838951231102 NOT improved
# Validation loss 0.9796483381778418 NOT improved
# Validation loss 0.9780076882147795 NOT improved
# Validation loss improved from 0.9726304195072788 to 0.9715033648306144
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.525423765182495 seconds ---
# Validation loss improved from 0.9715033648306144 to 0.9677146362587095
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.327343463897705 seconds ---
# Validation loss improved from 0.9677146362587095 to 0.9664329622436867
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 15.394764423370361 seconds ---
# Validation loss improved from 0.9664329622436867 to 0.961876799386619
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.229632139205933 seconds ---
# Validation loss improved from 0.961876799386619 to 0.9600070887386057
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 13.914681196212769 seconds ---
# Validation loss improved from 0.9600070887386057 to 0.9544864640395851
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.493613243103027 seconds ---
# Validation loss 0.9566518977608538 NOT improved
# Validation loss improved from 0.9544864640395851 to 0.9500668673182455
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 13.777113199234009 seconds ---
# Validation loss 0.9517762793966906 NOT improved
# Validation loss 0.9502482840229326 NOT improved
# Validation loss improved from 0.9500668673182455 to 0.9473582018484901
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix19_iy47/assets
# --- 14.159683465957642 seconds ---
# Validation loss 0.952689428734233 NOT improved
# Validation loss 0.9484712591990654 NOT improved
# Validation loss 0.9543418007766388 NOT improved
# Validation loss 0.9508716980513439 NOT improved
# Validation loss 0.9541038059475049 NOT improved
# Validation loss 0.9686134675292595 NOT improved
# Validation loss 0.9822520906708998 NOT improved
# Validation loss 0.9958313444357805 NOT improved
# Validation loss 1.0272183786254558 NOT improved
# Early stopping
# Training round 2
# Validation loss 0.9997483408900675 NOT improved
# Validation loss 0.9992999312735439 NOT improved
# Validation loss 0.9992067034033129 NOT improved
# Validation loss 0.9990469893854605 NOT improved
# Validation loss 0.9988150439414129 NOT improved
# Validation loss 0.9983700724525428 NOT improved
# Validation loss 0.9978011988305183 NOT improved
# Validation loss 0.9973933965533203 NOT improved
# Validation loss 0.9968387444191755 NOT improved
# Validation loss 0.9963620532597945 NOT improved
# Validation loss 0.9952341513673482 NOT improved
# Validation loss 0.9943797983457433 NOT improved
# Validation loss 0.9942572351042119 NOT improved
# Validation loss 0.9922395463729787 NOT improved
# Validation loss 0.9921203291770448 NOT improved
# Validation loss 0.9890913760445231 NOT improved
# Validation loss 0.9871984881824853 NOT improved
# Validation loss 0.9907039799837842 NOT improved
# Validation loss 0.9868540865702913 NOT improved
# Validation loss 0.9867752786643261 NOT improved
# Validation loss 0.9844792268132178 NOT improved
# Validation loss 0.9822573390549756 NOT improved
# Validation loss 0.9824763189770561 NOT improved
# Validation loss 0.977651595251627 NOT improved
# Validation loss 0.9776783364871284 NOT improved
# Validation loss 0.9761716084058261 NOT improved
# Validation loss 0.9767391475083517 NOT improved
# Validation loss 0.9758854068941627 NOT improved
# Validation loss 0.9700017496517482 NOT improved
# Validation loss 0.9746584859033225 NOT improved
# Validation loss 0.9684468800608074 NOT improved
# Validation loss 0.9697698448269418 NOT improved
# Validation loss 0.9585150174886458 NOT improved
# Validation loss 0.9678167101735873 NOT improved
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.988947868347168 seconds ---
# Validation loss improved from 0.9992565601275225 to 0.9989407822835655
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.580955982208252 seconds ---
# Validation loss improved from 0.9989407822835655 to 0.9985318054331279
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.335800409317017 seconds ---
# Validation loss improved from 0.9985318054331279 to 0.9978420075624674
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 14.167023181915283 seconds ---
# Validation loss improved from 0.9978420075624674 to 0.9972456836459689
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 14.483145236968994 seconds ---
# Validation loss improved from 0.9972456836459689 to 0.996045099529944
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.413778305053711 seconds ---
# Validation loss improved from 0.996045099529944 to 0.9957952799636616
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.27672529220581 seconds ---
# Validation loss improved from 0.9957952799636616 to 0.9942987441166365
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.057896614074707 seconds ---
# Validation loss improved from 0.9942987441166365 to 0.9934306789591918
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.90380334854126 seconds ---
# Validation loss improved from 0.9934306789591918 to 0.9925676151255217
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.995902061462402 seconds ---
# Validation loss improved from 0.9925676151255217 to 0.9915701870060867
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.213084936141968 seconds ---
# Validation loss improved from 0.9915701870060867 to 0.9895831672539819
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 12.542469024658203 seconds ---
# Validation loss improved from 0.9895831672539819 to 0.9880661048601802
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.070862054824829 seconds ---
# Validation loss improved from 0.9880661048601802 to 0.9879801332177547
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 12.84984302520752 seconds ---
# Validation loss improved from 0.9879801332177547 to 0.985569653912788
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.501436471939087 seconds ---
# Validation loss improved from 0.985569653912788 to 0.985222254347733
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 14.41783332824707 seconds ---
# Validation loss improved from 0.985222254347733 to 0.9849448918827051
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.686501264572144 seconds ---
# Validation loss improved from 0.9849448918827051 to 0.9829888567222085
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.14789080619812 seconds ---
# Validation loss improved from 0.9829888567222085 to 0.9797260051490785
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.439936399459839 seconds ---
# Validation loss improved from 0.9797260051490785 to 0.9781168208201025
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.10379672050476 seconds ---
# Validation loss improved from 0.9781168208201025 to 0.9745870556862889
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.386112213134766 seconds ---
# Validation loss improved from 0.9745870556862889 to 0.9698711975375975
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 14.29248309135437 seconds ---
# Validation loss improved from 0.9698711975375975 to 0.9594647517887398
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.629230260848999 seconds ---
# Validation loss 0.969158599536371 NOT improved
# Validation loss 0.968166994819243 NOT improved
# Validation loss improved from 0.9594647517887398 to 0.9573829753422565
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.085447549819946 seconds ---
# Validation loss improved from 0.9573829753422565 to 0.9501772251533009
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.344937324523926 seconds ---
# Validation loss 0.9556174972737802 NOT improved
# Validation loss improved from 0.9501772251533009 to 0.9394568103238088
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.73061203956604 seconds ---
# Validation loss 0.9441910958309023 NOT improved
# Validation loss improved from 0.9394568103238088 to 0.9364844886048922
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 14.04419231414795 seconds ---
# Validation loss 0.9377212574119738 NOT improved
# Validation loss improved from 0.9364844886048922 to 0.9325185998205033
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.298030614852905 seconds ---
# Validation loss improved from 0.9325185998205033 to 0.930908781869434
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 12.960395097732544 seconds ---
# Validation loss improved from 0.930908781869434 to 0.922076693039523
# save to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HEAD_Lead2_ix20_iy49/assets
# --- 13.684841632843018 seconds ---
# Validation loss 0.9304126847096218 NOT improved
# Validation loss 0.9341003034718995 NOT improved
