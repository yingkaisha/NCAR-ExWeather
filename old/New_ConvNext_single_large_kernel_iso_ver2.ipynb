# %%
# general tools
import sys
from glob import glob

# data tools
import time
import h5py
import random
import numpy as np
from random import shuffle

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# deep learning tools
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import backend
from tensorflow.keras import utils
from tensorflow.keras import Model

tf.config.run_functions_eagerly(True)

# from keras_unet_collection import models as k_models
from keras_unet_collection import utils as k_utils
# from keras_unet_collection import layer_utils as k_layers
# from keras_unet_collection.activations import GELU
# Out:
# 2022-10-21 11:26:06.388595: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
sys.path.insert(0, '/glade/u/home/ksha/NCAR/')
sys.path.insert(0, '/glade/u/home/ksha/NCAR/libs/')

from namelist import *
import data_utils as du
import graph_utils as gu
#import convnext_keras as ck

from sklearn.metrics import classification_report, auc, roc_curve
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# from importlib import reload
# reload(ck)

# %%
ind_pick_from_batch = [0, 1, 3, 4, 8, 9, 10, 13, 14, 15, 16, 17, 18, 21, 22]
L_vars = len(ind_pick_from_batch)

# %%
filename_neg_train = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch/*neg_neg_neg*lead2.npy")+\
                            glob("/glade/scratch/ksha/DATA/NCAR_batch/*neg_neg_neg*lead3.npy")+\
                            glob("/glade/scratch/ksha/DATA/NCAR_batch/*neg_neg_neg*lead4.npy"))

filename_pos_train = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch/*pos*lead2.npy")+\
                            glob("/glade/scratch/ksha/DATA/NCAR_batch/*pos*lead3.npy")+\
                            glob("/glade/scratch/ksha/DATA/NCAR_batch/*pos*lead4.npy"))

filename_neg_valid = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch/VALID*neg_neg_neg*lead2.npy"))
filename_pos_valid = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch/VALID*pos*lead2.npy"))

# %%
filename_neg_valid = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v4/*neg_neg_neg*lead2.npy"))
filename_pos_valid = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v4/*pos*lead2.npy"))

# %%
len(filename_pos_valid)
# Out:
# 453

# %%
filename_valid = filename_neg_valid[::80] + filename_pos_valid

# %%
len(filename_valid)
# Out:
# 5511

# %%
with h5py.File(save_dir+'HRRR_domain.hdf', 'r') as h5io:
    lon_3km = h5io['lon_3km'][...]
    lat_3km = h5io['lat_3km'][...]
    lon_72km = h5io['lon_72km'][...]
    lat_72km = h5io['lat_72km'][...]
    land_mask_72km = h5io['land_mask_72km'][...]
    land_mask_3km = h5io['land_mask_3km'][...]

# %%
L_valid = len(filename_valid)
L_var = L_vars

TEST_input_64 = np.empty((L_valid, 64, 64, L_var))
TEST_target = np.ones(L_valid)

for i, name in enumerate(filename_valid):
    data = np.load(name)
    for k, c in enumerate(ind_pick_from_batch):
        
        TEST_input_64[i, ..., k] = data[..., c]

        if 'pos' in name:
            TEST_target[i] = 1.0
        else:
            TEST_target[i] = 0.0

# %% [markdown]
# **ConvNext**

# %%
class LayerScale(layers.Layer):
    """Layer scale module.
    References:
      - https://arxiv.org/abs/2103.17239
    Args:
      init_values (float): Initial value for layer scale. Should be within
        [0, 1].
      projection_dim (int): Projection dimensionality.
    Returns:
      Tensor multiplied to the scale.
    """

    def __init__(self, init_values, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.init_values = init_values
        self.projection_dim = projection_dim

    def build(self, input_shape):
        self.gamma = tf.Variable(
            self.init_values * tf.ones((self.projection_dim,))
        )

    def call(self, x):
        return x * self.gamma

    def get_config(self):
        config = super().get_config()
        config.update(
            {
                "init_values": self.init_values,
                "projection_dim": self.projection_dim,
            }
        )
        return config
    


def Head(num_classes=1000, name=None):
    """Implementation of classification head of RegNet.
    Args:
      num_classes: number of classes for Dense layer
      name: name prefix
    Returns:
      Classification head function.
    """
    if name is None:
        name = str(backend.get_uid("head"))

    def apply(x):
        x = layers.GlobalAveragePooling2D(name=name + "_head_gap")(x)
        x = layers.LayerNormalization(
            epsilon=1e-6, name=name + "_head_layernorm"
        )(x)
        x = layers.Dense(num_classes, name=name + "_head_dense")(x)
        return x

    return apply

# %%
depths=[3, 3, 27, 3]
projection_dims=[96, 192, 384, 768]
drop_path_rate=0.0
layer_scale_init_value=1e-6


model_name='Branch64X'
input_shape=(64, 64, 15)
IN64 = layers.Input(shape=input_shape)
X = IN64

X = layers.LocallyConnected2D(64, kernel_size=1, strides=(1, 1), padding="valid", implementation=1)(X)
X = layers.LayerNormalization(epsilon=1e-6, name="{}_lc1_norm".format(model_name))(X)
X = layers.Activation("gelu", name="{}_lc1_gelu".format(model_name))(X)

# X = layers.LocallyConnected2D(96, kernel_size=1, strides=(1, 1), padding="valid", implementation=1)(X)
# X = layers.LayerNormalization(epsilon=1e-6, name="{}_lc2_norm".format(model_name))(X)
# X = layers.Activation("gelu", name="{}_lc2_gelu".format(model_name))(X)

# ----- convnext block 0 ----- #

X = layers.Conv2D(projection_dims[0], kernel_size=4, strides=4, name="{}_down0".format(model_name))(X)
X = layers.LayerNormalization(epsilon=1e-6, name="{}_down0_norm".format(model_name))(X)

for j in range(depths[0]):
    
    X_convnext = X
    X_convnext = layers.Conv2D(filters=projection_dims[0], kernel_size=7, padding="same",
                               groups=projection_dims[0], name="{}_down0_dconv{}".format(model_name, j))(X_convnext)
    X_convnext = layers.LayerNormalization(epsilon=1e-6, name="{}_down0_dconv{}_norm".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(4 * projection_dims[0], name="{}_down0_dense{}_p1".format(model_name, j))(X_convnext)
    X_convnext = layers.Activation("gelu", name="{}_down0_gelu{}".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(projection_dims[0], name="{}_down0_dense{}_p2".format(model_name, j))(X_convnext)

    X_convnext = LayerScale(layer_scale_init_value, projection_dims[0], name="{}_down0_layerscale{}".format(model_name, j))(X_convnext)

    X = X + X_convnext


# ----- convnext block 1 ----- #

X = layers.LayerNormalization(epsilon=1e-6, name="{}_down1_norm".format(model_name))(X)
X = layers.Conv2D(projection_dims[1], kernel_size=3, padding='same', name="{}_down1".format(model_name))(X)

for j in range(depths[1]):
    
    X_convnext = X
    X_convnext = layers.Conv2D(filters=projection_dims[1], kernel_size=7, padding="same",
                               groups=projection_dims[1], name="{}_down1_dconv{}".format(model_name, j))(X_convnext)
    X_convnext = layers.LayerNormalization(epsilon=1e-6, name="{}_down1_dconv{}_norm".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(4 * projection_dims[1], name="{}_down1_dense{}_p1".format(model_name, j))(X_convnext)
    X_convnext = layers.Activation("gelu", name="{}_down1_gelu{}".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(projection_dims[1], name="{}_down1_dense{}_p2".format(model_name, j))(X_convnext)

    X_convnext = LayerScale(layer_scale_init_value, projection_dims[1], name="{}_down1_layerscale{}".format(model_name, j))(X_convnext)

    X = X + X_convnext

# ----- convnext block 2 ----- #

X = layers.LayerNormalization(epsilon=1e-6, name="{}_down2_norm".format(model_name))(X)
X = layers.Conv2D(projection_dims[2], kernel_size=3, padding='same', name="{}_down2".format(model_name))(X)

for j in range(depths[2]):
    
    X_convnext = X
    X_convnext = layers.Conv2D(filters=projection_dims[2], kernel_size=7, padding="same",
                               groups=projection_dims[2], name="{}_down2_dconv{}".format(model_name, j))(X_convnext)
    X_convnext = layers.LayerNormalization(epsilon=1e-6, name="{}_down2_dconv{}_norm".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(4 * projection_dims[2], name="{}_down2_dense{}_p1".format(model_name, j))(X_convnext)
    X_convnext = layers.Activation("gelu", name="{}_down2_gelu{}".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(projection_dims[2], name="{}_down2_dense{}_p2".format(model_name, j))(X_convnext)

    X_convnext = LayerScale(layer_scale_init_value, projection_dims[2], name="{}_down2_layerscale{}".format(model_name, j))(X_convnext)

    X = X + X_convnext

# ----- convnext block 3 ----- #

X = layers.LayerNormalization(epsilon=1e-6, name="{}_down3_norm".format(model_name))(X)
X = layers.Conv2D(projection_dims[3], kernel_size=3, padding='same', name="{}_down3".format(model_name))(X)

for j in range(depths[3]):
    
    X_convnext = X
    X_convnext = layers.Conv2D(filters=projection_dims[3], kernel_size=7, padding="same",
                               groups=projection_dims[3], name="{}_down3_dconv{}".format(model_name, j))(X_convnext)
    X_convnext = layers.LayerNormalization(epsilon=1e-6, name="{}_down3_dconv{}_norm".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(4 * projection_dims[3], name="{}_down3_dense{}_p1".format(model_name, j))(X_convnext)
    X_convnext = layers.Activation("gelu", name="{}_down3_gelu{}".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(projection_dims[3], name="{}_down3_dense{}_p2".format(model_name, j))(X_convnext)

    X_convnext = LayerScale(layer_scale_init_value, projection_dims[3], name="{}_down3_layerscale{}".format(model_name, j))(X_convnext)

    X = X + X_convnext

V1 = X

OUT = layers.GlobalMaxPooling2D(name="{}_head_pool64".format(model_name))(V1)
OUT = layers.LayerNormalization(epsilon=1e-6, name="{}_head_norm64".format(model_name))(OUT)

OUT = layers.Dense(256, name="{}_dense1".format(model_name))(OUT)
OUT = layers.LayerNormalization(epsilon=1e-6, name="{}_dense1_norm".format(model_name))(OUT)
OUT = layers.Activation("gelu", name="{}_dense1_gelu{}".format(model_name, j))(OUT)

OUT = layers.Dense(1, name="{}_head_out".format(model_name))(OUT)

model = Model(inputs=IN64, outputs=OUT, name=model_name)

# %%
# OUT1 = layers.GlobalMaxPooling2D(name="{}_head_pool64".format(model_name))(V1)
# OUT1 = layers.LayerNormalization(epsilon=1e-6, name="{}_head_norm64".format(model_name))(OUT1)

# OUT2 = layers.GlobalMaxPooling2D(name="{}_head_pool32".format(model_name))(V2)
# OUT2 = layers.LayerNormalization(epsilon=1e-6, name="{}_head_norm32".format(model_name))(OUT2)

# OUT = layers.Concatenate(axis=-1, name='concat_64_32')([OUT1, OUT2])

# OUT = layers.Dense(256, name="{}_dense1".format(model_name))(OUT)
# OUT = layers.LayerNormalization(epsilon=1e-6, name="{}_dense1_norm".format(model_name))(OUT)
# OUT = layers.Activation("gelu", name="{}_dense1_gelu{}".format(model_name, j))(OUT)

# OUT = layers.Dense(1, name="{}_head_out".format(model_name))(OUT)

# model = Model(inputs=[IN64, IN32], outputs=OUT, name=model_name)

# %%
from sklearn.metrics import brier_score_loss
from sklearn.metrics import log_loss


def verif_metric(VALID_target, Y_pred):


    # fpr, tpr, thresholds = roc_curve(VALID_target.ravel(), Y_pred.ravel())
    # AUC = auc(fpr, tpr)
    # AUC_metric = 1 - AUC
    
    BS = np.mean((VALID_target.ravel() - Y_pred.ravel())**2)
    #ll = log_loss(VALID_target.ravel(), Y_pred.ravel())
    
    print('{}'.format(BS))
    metric = BS

    return metric

# %%
tol = 0
min_del = 0
max_tol = 500 # early stopping with patience

epochs = 500
L_train = 64
batch_size = 100

batch_size_half = 50

valid_size = 1

# %%
batch_dir = '/glade/scratch/ksha/DATA/NCAR_batch/'
temp_dir = '/glade/work/ksha/NCAR/Keras_models/'

key = 'SK15_ISO2_Lead2'

model_name = '{}_pp12'.format(key)
model_path = temp_dir+model_name

# W_old = k_utils.dummy_loader(temp_dir+'LCD_12_Lead2_pp12_tune')
# model.set_weights(W_old)

# %%
# batch_dir = '/glade/scratch/ksha/DATA/NCAR_batch/'
# temp_dir = '/glade/work/ksha/NCAR/Keras_models/'

# key = 'SHM_12_Lead2'

# model_name = '{}_pp12_tune'.format(key)
# model_path = temp_dir+model_name

# W_old = k_utils.dummy_loader(temp_dir+'SHM_12_Lead2_pp12')
# model.set_weights(W_old)

# %%
#model.summary()

# %%
model.compile(loss=keras.losses.mean_absolute_error, optimizer=keras.optimizers.Adam(lr=1e-5))
#keras.losses.BinaryCrossentropy(from_logits=True)

# %%
X_batch_64 = np.empty((batch_size, 64, 64, L_vars))
#X_batch_32 = np.empty((batch_size, 32, 32, L_vars))
Y_batch = np.empty((batch_size, 1))

X_batch_64[...] = np.nan
#X_batch_32[...] = np.nan
Y_batch[...] = np.nan

# %%
Y_pred = model.predict([TEST_input_64])

# %%
# save_dict = {}
# save_dict['y_true'] = TEST_target
# save_dict['y_pred'] = Y_pred

# np.save("ALL_pred_lead2.npy", save_dict)

# %%
# Y_pred[Y_pred<0] = 0
# Y_pred[Y_pred>1] = 1
record = verif_metric(TEST_target, Y_pred)
print("Initial record: {}".format(record))
# Out:
# 1.7647395036921878
# Initial record: 1.7647395036921878

# %%
# 0.034775568168985756
# Initial record: 0.034775568168985756

# %%
plt.figure(figsize=(15, 4))
plt.plot(TEST_target[:], 'b-', lw=3.0)
plt.plot(Y_pred[:], 'r-')
#plt.plot(Y_pred>0.5)

# %%
# plt.pcolormesh(TEST_input[3154, ..., 2], cmap=plt.cm.nipy_spectral_r)
# plt.colorbar()

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ========== Training loop ========== #
L_storm = len(filename_neg_train)
L_aug = len(filename_pos_train)

for i in range(epochs):
    
    shuffle(filename_neg_train)
    shuffle(filename_pos_train)
    
    #print('epoch = {}'.format(i))
    start_time = time.time()
    
    # loop of batch
    for j in range(L_train):
        
        #N_aug = int(np.random.uniform(2, 7))
        N_aug = int(np.random.uniform(8, 14))
        #N_aug = int(np.random.uniform(10, 25))
        #N_aug = int(np.random.uniform(20, 45))
        
        N_storm = 100 - N_aug
        
        ind_storm = du.shuffle_ind(L_storm)
        ind_aug = du.shuffle_ind(L_aug)
        
        file_pick_storm = []
        for ind_temp in ind_storm[:N_storm]:
            file_pick_storm.append(filename_neg_train[ind_temp])

        file_pick_aug = []
        for ind_temp in ind_aug[:N_aug]:
            file_pick_aug.append(filename_pos_train[ind_temp])
        
        file_pick = file_pick_storm + file_pick_aug
        
        if len(file_pick) != 100:
            sregwet
        
        for k in range(batch_size):

            data = np.load(file_pick[k])
            
            for l, c in enumerate(ind_pick_from_batch):
            
                X_batch_64[k, ..., l] = data[..., c]
            
            if 'pos' in file_pick[k]:
                Y_batch[k, :] = 1.0 #np.random.uniform(0.9, 0.99)
            elif 'neg_neg_neg' in file_pick[k]:
                Y_batch[k, :] = 0.0 #np.random.uniform(0.01, 0.05)
            else:
                werhgaer
                
        #Y_batch_cate = tf.keras.utils.to_categorical(Y_batch)
        
        # # add noise within sparse inputs
        # for v in flag_sparse:
        #     X_batch[..., v] += np.random.uniform(0, 0.01, size=(batch_size, 128, 128))

        # shuffle indices
        ind_ = du.shuffle_ind(batch_size)
        X_batch_64 = X_batch_64[ind_, ...]
        Y_batch = Y_batch[ind_, :]
        
        # train on batch
        model.train_on_batch(X_batch_64, Y_batch);
    
    # epoch end operations
    Y_pred = model.predict([TEST_input_64])
    # Y_pred[Y_pred<0] = 0
    # Y_pred[Y_pred>1] = 1
    record_temp = verif_metric(TEST_target, Y_pred)
    
    # if i % 10 == 0:
    #     model.save(model_path_backup)
    
    if (record - record_temp > min_del) and (np.max(Y_pred) > 0.6):
        print('Validation loss improved from {} to {}'.format(record, record_temp))
        record = record_temp
        tol = 0
        #print('tol: {}'.format(tol))
        # save
        print('save to: {}'.format(model_path))
        model.save(model_path)
    else:
        print('Validation loss {} NOT improved'.format(record_temp))
        tol += 1
        #print('tol: {}'.format(tol))
        if tol >= max_tol:
            print('Early stopping')
            sys.exit();
        else:
            #print('Pass to the next epoch')
            continue;
    print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 2022-10-21 13:50:34.796439: W tensorflow/core/common_runtime/bfc_allocator.cc:433] Allocator (GPU_0_bfc) ran out of memory trying to allocate 150.00MiB (rounded to 157286400)requested by op Mul
# Current allocation summary follows.
# 2022-10-21 13:50:34.797297: I tensorflow/core/common_runtime/bfc_allocator.cc:972] BFCAllocator dump for GPU_0_bfc
# 2022-10-21 13:50:34.797316: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (256): 	Total Chunks: 225, Chunks in use: 225. 56.2KiB allocated for chunks. 56.2KiB in use in bin. 20.4KiB client-requested in use in bin.
# 2022-10-21 13:50:34.797324: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (512): 	Total Chunks: 151, Chunks in use: 151. 93.2KiB allocated for chunks. 93.2KiB in use in bin. 83.2KiB client-requested in use in bin.
# 2022-10-21 13:50:34.797331: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1024): 	Total Chunks: 582, Chunks in use: 581. 864.5KiB allocated for chunks. 863.2KiB in use in bin. 862.3KiB client-requested in use in bin.
# 2022-10-21 13:50:34.797337: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2048): 	Total Chunks: 2031, Chunks in use: 2031. 4.05MiB allocated for chunks. 4.05MiB in use in bin. 3.81MiB client-requested in use in bin.
# 2022-10-21 13:50:34.797344: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4096): 	Total Chunks: 106, Chunks in use: 106. 638.2KiB allocated for chunks. 638.2KiB in use in bin. 630.0KiB client-requested in use in bin.
# 2022-10-21 13:50:34.797350: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8192): 	Total Chunks: 15, Chunks in use: 15. 170.0KiB allocated for chunks. 170.0KiB in use in bin. 156.0KiB client-requested in use in bin.
# 2022-10-21 13:50:34.797357: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16384): 	Total Chunks: 13, Chunks in use: 12. 286.2KiB allocated for chunks. 270.0KiB in use in bin. 259.1KiB client-requested in use in bin.
# 2022-10-21 13:50:34.797364: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (32768): 	Total Chunks: 12, Chunks in use: 12. 551.8KiB allocated for chunks. 551.8KiB in use in bin. 518.2KiB client-requested in use in bin.
# 2022-10-21 13:50:34.797370: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (65536): 	Total Chunks: 182, Chunks in use: 181. 16.83MiB allocated for chunks. 16.73MiB in use in bin. 16.64MiB client-requested in use in bin.
# 2022-10-21 13:50:34.797376: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (131072): 	Total Chunks: 42, Chunks in use: 42. 6.43MiB allocated for chunks. 6.43MiB in use in bin. 6.04MiB client-requested in use in bin.
# 2022-10-21 13:50:34.797381: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (262144): 	Total Chunks: 7, Chunks in use: 7. 2.36MiB allocated for chunks. 2.36MiB in use in bin. 2.34MiB client-requested in use in bin.
# 2022-10-21 13:50:34.797388: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (524288): 	Total Chunks: 29, Chunks in use: 29. 17.13MiB allocated for chunks. 17.13MiB in use in bin. 17.13MiB client-requested in use in bin.
# 2022-10-21 13:50:34.797393: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1048576): 	Total Chunks: 6, Chunks in use: 6. 7.12MiB allocated for chunks. 7.12MiB in use in bin. 7.12MiB client-requested in use in bin.
# 2022-10-21 13:50:34.797399: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2097152): 	Total Chunks: 220, Chunks in use: 220. 497.73MiB allocated for chunks. 497.73MiB in use in bin. 495.16MiB client-requested in use in bin.
# 2022-10-21 13:50:34.797406: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4194304): 	Total Chunks: 2, Chunks in use: 2. 12.19MiB allocated for chunks. 12.19MiB in use in bin. 10.03MiB client-requested in use in bin.
# 2022-10-21 13:50:34.797412: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8388608): 	Total Chunks: 76, Chunks in use: 76. 727.09MiB allocated for chunks. 727.09MiB in use in bin. 723.38MiB client-requested in use in bin.
# 2022-10-21 13:50:34.797419: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16777216): 	Total Chunks: 44, Chunks in use: 44. 832.69MiB allocated for chunks. 832.69MiB in use in bin. 821.25MiB client-requested in use in bin.
# 2022-10-21 13:50:34.797425: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (33554432): 	Total Chunks: 205, Chunks in use: 205. 7.55GiB allocated for chunks. 7.55GiB in use in bin. 7.51GiB client-requested in use in bin.
# 2022-10-21 13:50:34.797431: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (67108864): 	Total Chunks: 34, Chunks in use: 34. 2.83GiB allocated for chunks. 2.83GiB in use in bin. 2.81GiB client-requested in use in bin.
# 2022-10-21 13:50:34.797437: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (134217728): 	Total Chunks: 116, Chunks in use: 115. 16.97GiB allocated for chunks. 16.83GiB in use in bin. 16.80GiB client-requested in use in bin.
# 2022-10-21 13:50:34.797443: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-10-21 13:50:34.797465: I tensorflow/core/common_runtime/bfc_allocator.cc:995] Bin for 150.00MiB was 128.00MiB, Chunk State:
# 2022-10-21 13:50:34.797475: I tensorflow/core/common_runtime/bfc_allocator.cc:1001]   Size: 142.90MiB | Requested Size: 5.9KiB | in_use: 0 | bin_num: 19, prev:   Size: 150.00MiB | Requested Size: 150.00MiB | in_use: 1 | bin_num: -1
# 2022-10-21 13:50:34.797480: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 31596547840
# 2022-10-21 13:50:34.797487: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at
# 2022-10-21 13:50:34.883951: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 61803520 totalling 58.94MiB
# 2022-10-21 13:50:34.883955: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 65575424 totalling 62.54MiB
# 2022-10-21 13:50:34.884098: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 21 Chunks of size 78643200 totalling 1.54GiB
# 2022-10-21 13:50:34.884103: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 12 Chunks of size 104857600 totalling 1.17GiB
# 2022-10-21 13:50:34.884108: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 124090368 totalling 118.34MiB
# 2022-10-21 13:50:34.884113: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 142999552 totalling 136.38MiB
# 2022-10-21 13:50:34.884118: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 114 Chunks of size 157286400 totalling 16.70GiB
# 2022-10-21 13:50:34.884122: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Sum Total of in-use chunks: 29.29GiB
# 2022-10-21 13:50:34.884127: I tensorflow/core/common_runtime/bfc_allocator.cc:1042] total_region_allocated_bytes_: 31596547840 memory_limit_: 31596547968 available bytes: 128 curr_region_allocation_bytes_: 63193096192
# 2022-10-21 13:50:34.884137: I tensorflow/core/common_runtime/bfc_allocator.cc:1048] Stats:
# Limit:                     31596547968
# InUse:                     31446589952
# MaxInUse:                  31446589952
# NumAllocs:                    31000846
# MaxAllocSize:               2701262848
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-10-21 13:50:34.884336: W tensorflow/core/common_runtime/bfc_allocator.cc:441] ****************************************************************************************************
# 2022-10-21 13:50:34.912416: W tensorflow/core/framework/op_kernel.cc:1763] OP_REQUIRES failed at cwise_ops_common.h:114 : Resource exhausted: OOM when allocating tensor with shape[100,16,16,1536] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [48], in <cell line: 5>()
#      63     Y_batch = Y_batch[ind_, :]
#      65     # train on batch
# ---> 66     model.train_on_batch(X_batch_64, Y_batch);
#      68 # epoch end operations
#      69 Y_pred = model.predict([TEST_input_64])
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1727, in Model.train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1723   iterator = data_adapter.single_batch_iterator(self.distribute_strategy, x,
#    1724                                                 y, sample_weight,
#    1725                                                 class_weight)
#    1726   self.train_function = self.make_train_function()
# -> 1727   logs = self.train_function(iterator)
#    1729 if reset_metrics:
#    1730   self.reset_metrics()
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:805, in Model.make_train_function.<locals>.train_function(iterator)
#     803 def train_function(iterator):
#     804   """Runs a training execution with one step."""
# --> 805   return step_function(self, iterator)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:795, in Model.make_train_function.<locals>.step_function(model, iterator)
#     792   return outputs
#     794 data = next(iterator)
# --> 795 outputs = model.distribute_strategy.run(run_step, args=(data,))
#     796 outputs = reduce_per_replica(
#     797     outputs, self.distribute_strategy, reduction='first')
#     798 write_scalar_summaries(outputs, step=model._train_counter)  # pylint: disable=protected-access
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:1259, in StrategyBase.run(***failed resolving arguments***)
#    1254 with self.scope():
#    1255   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1256   # applied when when the caller is also in Eager mode.
#    1257   fn = autograph.tf_convert(
#    1258       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1259   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:2730, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2728   kwargs = {}
#    2729 with self._container_strategy().scope():
# -> 2730   return self._call_for_each_replica(fn, args, kwargs)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:3417, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3415 def _call_for_each_replica(self, fn, args, kwargs):
#    3416   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3417     return fn(*args, **kwargs)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:572, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     570 def wrapper(*args, **kwargs):
#     571   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 572     return func(*args, **kwargs)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:788, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#     787 def run_step(data):
# --> 788   outputs = model.train_step(data)
#     789   # Ensure counter is updated only if `train_step` succeeds.
#     790   with ops.control_dependencies(_minimum_control_deps(outputs)):
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:754, in Model.train_step(self, data)
#     751 x, y, sample_weight = data_adapter.unpack_x_y_sample_weight(data)
#     753 with backprop.GradientTape() as tape:
# --> 754   y_pred = self(x, training=True)
#     755   loss = self.compiled_loss(
#     756       y, y_pred, sample_weight, regularization_losses=self.losses)
#     757 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:1012, in Layer.__call__(self, *args, **kwargs)
#    1008   self._maybe_build(inputs)
#    1010 with autocast_variable.enable_auto_cast_variables(
#    1011     self._compute_dtype_object):
# -> 1012   outputs = call_fn(inputs, *args, **kwargs)
#    1014 if self._activity_regularizer:
#    1015   self._handle_activity_regularization(inputs, outputs)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/keras/engine/functional.py:424, in Functional.call(self, inputs, training, mask)
#     406 def call(self, inputs, training=None, mask=None):
#     407   """Calls the model on new inputs.
#     408
#     409   In this case `call` just reapplies
#    (...)
#     422       a list of tensors if there are more than one outputs.
#     423   """
# --> 424   return self._run_internal_graph(
#     425       inputs, training=training, mask=mask)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/keras/engine/functional.py:560, in Functional._run_internal_graph(self, inputs, training, mask)
#     557   continue  # Node is not computable, try skipping.
#     559 args, kwargs = node.map_arguments(tensor_dict)
# --> 560 outputs = node.layer(*args, **kwargs)
#     562 # Update tensor_dict.
#     563 for x_id, y in zip(node.flat_output_ids, nest.flatten(outputs)):
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:1012, in Layer.__call__(self, *args, **kwargs)
#    1008   self._maybe_build(inputs)
#    1010 with autocast_variable.enable_auto_cast_variables(
#    1011     self._compute_dtype_object):
# -> 1012   outputs = call_fn(inputs, *args, **kwargs)
#    1014 if self._activity_regularizer:
#    1015   self._handle_activity_regularization(inputs, outputs)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/keras/layers/core.py:440, in Activation.call(self, inputs)
#     439 def call(self, inputs):
# --> 440   return self.activation(inputs)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:201, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     199 """Call target, and fall back on dispatchers if there is a TypeError."""
#     200 try:
# --> 201   return target(*args, **kwargs)
#     202 except (TypeError, ValueError):
#     203   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     204   # TypeError, when given unexpected types.  So we need to catch both.
#     205   result = dispatch(wrapper, args, kwargs)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/keras/activations.py:346, in gelu(x, approximate)
#     309 @keras_export('keras.activations.gelu', v1=[])
#     310 @dispatch.add_dispatch_support
#     311 def gelu(x, approximate=False):
#     312   """Applies the Gaussian error linear unit (GELU) activation function.
#     313
#     314   Gaussian error linear unit (GELU) computes
#    (...)
#     344     - [Gaussian Error Linear Units (GELUs)](https://arxiv.org/abs/1606.08415)
#     345   """
# --> 346   return nn.gelu(x, approximate)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:201, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     199 """Call target, and fall back on dispatchers if there is a TypeError."""
#     200 try:
# --> 201   return target(*args, **kwargs)
#     202 except (TypeError, ValueError):
#     203   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     204   # TypeError, when given unexpected types.  So we need to catch both.
#     205   result = dispatch(wrapper, args, kwargs)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/nn_ops.py:3547, in gelu(features, approximate, name)
#    3543   return 0.5 * features * (
#    3544       1.0 + math_ops.tanh(0.7978845608028654 *
#    3545                           (features + coeff * math_ops.pow(features, 3))))
#    3546 else:
# -> 3547   return 0.5 * features * (1.0 + math_ops.erf(
#    3548       features / math_ops.cast(1.4142135623730951, features.dtype)))
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:1195, in _OverrideBinaryOperatorHelper.<locals>.r_binary_op_wrapper(y, x)
#    1193 with ops.name_scope(None, op_name, [x, y]) as name:
#    1194   x = ops.convert_to_tensor(x, dtype=y.dtype.base_dtype, name="x")
# -> 1195   return func(x, y, name=name)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:1496, in _mul_dispatch(x, y, name)
#    1494   return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1495 else:
# -> 1496   return multiply(x, y, name=name)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:201, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     199 """Call target, and fall back on dispatchers if there is a TypeError."""
#     200 try:
# --> 201   return target(*args, **kwargs)
#     202 except (TypeError, ValueError):
#     203   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     204   # TypeError, when given unexpected types.  So we need to catch both.
#     205   result = dispatch(wrapper, args, kwargs)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:518, in multiply(x, y, name)
#     472 @tf_export("math.multiply", "multiply")
#     473 @dispatch.add_dispatch_support
#     474 def multiply(x, y, name=None):
#     475   """Returns an element-wise x * y.
#     476
#     477   For example:
#    (...)
#     515    * InvalidArgumentError: When `x` and `y` have incomptatible shapes or types.
#     516   """
# --> 518   return gen_math_ops.mul(x, y, name)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/gen_math_ops.py:6068, in mul(x, y, name)
#    6066   return _result
#    6067 except _core._NotOkStatusException as e:
# -> 6068   _ops.raise_from_not_ok_status(e, name)
#    6069 except _core._FallbackException:
#    6070   pass
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:6862, in raise_from_not_ok_status(e, name)
#    6860 message = e.message + (" name: " + name if name is not None else "")
#    6861 # pylint: disable=protected-access
# -> 6862 six.raise_from(core._status_to_exception(e.code, message), None)
#
# File <string>:3, in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[100,16,16,1536] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Mul]

# %%
# ========== Training loop ========== #
L_storm = len(filename_neg_train)
L_aug = len(filename_pos_train)

for i in range(epochs):
    
    shuffle(filename_neg_train)
    shuffle(filename_pos_train)
    
    #print('epoch = {}'.format(i))
    start_time = time.time()
    
    # loop of batch
    for j in range(L_train):
        
        #N_aug = int(np.random.uniform(2, 7))
        N_aug = int(np.random.uniform(8, 14))
        #N_aug = int(np.random.uniform(10, 25))
        #N_aug = int(np.random.uniform(20, 45))
        
        N_storm = 100 - N_aug
        
        ind_storm = du.shuffle_ind(L_storm)
        ind_aug = du.shuffle_ind(L_aug)
        
        file_pick_storm = []
        for ind_temp in ind_storm[:N_storm]:
            file_pick_storm.append(filename_neg_train[ind_temp])

        file_pick_aug = []
        for ind_temp in ind_aug[:N_aug]:
            file_pick_aug.append(filename_pos_train[ind_temp])
        
        file_pick = file_pick_storm + file_pick_aug
        
        if len(file_pick) != 100:
            sregwet
        
        for k in range(batch_size):

            data = np.load(file_pick[k])
            
            for l, c in enumerate(ind_pick_from_batch):
            
                X_batch_64[k, ..., l] = data[..., c]
                X_batch_32[k, ..., l] = data[:, 16:-16, 16:-16, c]
            
            if 'pos' in file_pick[k]:
                Y_batch[k, :] = 1.0 #np.random.uniform(0.9, 0.99)
            elif 'neg_neg_neg' in file_pick[k]:
                Y_batch[k, :] = 0.0 #np.random.uniform(0.01, 0.05)
            else:
                werhgaer
                
        #Y_batch_cate = tf.keras.utils.to_categorical(Y_batch)
        
        # # add noise within sparse inputs
        # for v in flag_sparse:
        #     X_batch[..., v] += np.random.uniform(0, 0.01, size=(batch_size, 128, 128))

        # shuffle indices
        ind_ = du.shuffle_ind(batch_size)
        X_batch_64 = X_batch_64[ind_, ...]
        X_batch_32 = X_batch_32[ind_, ...]
        Y_batch = Y_batch[ind_, :]
        
        # train on batch
        model.train_on_batch([X_batch_64, X_batch_32], [Y_batch,]);
    
    # epoch end operations
    Y_pred = model.predict([TEST_input_64, TEST_input_32])
    # Y_pred[Y_pred<0] = 0
    # Y_pred[Y_pred>1] = 1
    record_temp = verif_metric(TEST_target, Y_pred)
    
    # if i % 10 == 0:
    #     model.save(model_path_backup)
    
    if (record - record_temp > min_del) and (np.max(Y_pred) > 0.6):
        print('Validation loss improved from {} to {}'.format(record, record_temp))
        record = record_temp
        tol = 0
        #print('tol: {}'.format(tol))
        # save
        print('save to: {}'.format(model_path))
        model.save(model_path)
    else:
        print('Validation loss {} NOT improved'.format(record_temp))
        tol += 1
        #print('tol: {}'.format(tol))
        if tol >= max_tol:
            print('Early stopping')
            sys.exit();
        else:
            #print('Pass to the next epoch')
            continue;
    print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 0.07514533614068455
# Validation loss improved from 0.2998326700708481 to 0.07514533614068455
# save to: /glade/work/ksha/NCAR/Keras_models/LCD_12_Lead2_pp12
# 2022-10-14 13:24:01.764774: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/LCD_12_Lead2_pp12/assets
# --- 633.1284303665161 seconds ---
# /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:3503: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   warnings.warn(
# 0.04136495989064323
# Validation loss improved from 0.07514533614068455 to 0.04136495989064323
# save to: /glade/work/ksha/NCAR/Keras_models/LCD_12_Lead2_pp12
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/LCD_12_Lead2_pp12/assets
# --- 742.1642851829529 seconds ---
# /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:3503: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   warnings.warn(
# 0.038807801316810574
# Validation loss improved from 0.04136495989064323 to 0.038807801316810574
# save to: /glade/work/ksha/NCAR/Keras_models/LCD_12_Lead2_pp12
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/LCD_12_Lead2_pp12/assets
# --- 712.9455497264862 seconds ---
# /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:3503: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   warnings.warn(
# 0.03177556492371975
# Validation loss improved from 0.038807801316810574 to 0.03177556492371975
# save to: /glade/work/ksha/NCAR/Keras_models/LCD_12_Lead2_pp12
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/LCD_12_Lead2_pp12/assets
# --- 660.8410992622375 seconds ---
# /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:3503: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   warnings.warn(
# 0.030470391321217895
# Validation loss improved from 0.03177556492371975 to 0.030470391321217895
# save to: /glade/work/ksha/NCAR/Keras_models/LCD_12_Lead2_pp12
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/LCD_12_Lead2_pp12/assets
# --- 736.8477790355682 seconds ---
# /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:3503: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   warnings.warn(
# 0.02832385153894868
# Validation loss improved from 0.030470391321217895 to 0.02832385153894868
# save to: /glade/work/ksha/NCAR/Keras_models/LCD_12_Lead2_pp12
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/LCD_12_Lead2_pp12/assets
# --- 662.7899610996246 seconds ---
# /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:3503: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   warnings.warn(
#
# KeyboardInterrupt

# %%
j
# Out:
# 123844

# %%
https://mesonet.agron.iastate.edu/pickup/wwa/

# %%
10 % 3
# Out:
# 1
