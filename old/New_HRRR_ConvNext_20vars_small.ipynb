# %%
# general tools
import sys
from glob import glob

# data tools
import time
import h5py
import random
import numpy as np
from random import shuffle

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# deep learning tools
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
tf.config.run_functions_eagerly(True)

# from keras_unet_collection import models as k_models
from keras_unet_collection import utils as k_utils
# from keras_unet_collection import layer_utils as k_layers
# from keras_unet_collection.activations import GELU
# Out:
# 2022-09-22 12:42:58.137347: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
sys.path.insert(0, '/glade/u/home/ksha/NCAR/')
sys.path.insert(0, '/glade/u/home/ksha/NCAR/libs/')

from namelist import *
import data_utils as du
import graph_utils as gu
import convnext_keras as ck

from sklearn.metrics import classification_report, auc, roc_curve
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from importlib import reload
reload(ck)
# Out:
# <module 'convnext_keras' from '/glade/u/home/ksha/NCAR/libs/convnext_keras.py'>

# %%
L_vars = 23

# %%
filename_neg_train = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch/TRAIN*neg_neg_neg*.npy"))
filename_pos_train = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch/TRAIN*pos*.npy"))

# %%
filename_neg_valid = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch/VALID*neg_neg_neg*.npy"))
filename_pos_valid = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch/VALID*pos*.npy"))

# %%
filename_valid = filename_neg_valid[::35] + filename_pos_valid[::35]

# %%
len(filename_valid)
# Out:
# 7690

# %%
with h5py.File(save_dir+'HRRR_domain.hdf', 'r') as h5io:
    lon_3km = h5io['lon_3km'][...]
    lat_3km = h5io['lat_3km'][...]
    lon_72km = h5io['lon_72km'][...]
    lat_72km = h5io['lat_72km'][...]
    land_mask_72km = h5io['land_mask_72km'][...]
    land_mask_3km = h5io['land_mask_3km'][...]

# %%
128-48
# Out:
# 80

# %%
L_valid = len(filename_valid)
L_var = 23

TEST_input = np.empty((L_valid, 48, 48, L_var))
TEST_target = np.ones(L_valid)

for i, name in enumerate(filename_valid):
    data = np.load(name)
    
    TEST_input[i, ...] = data[:, 40:-40, 40:-40, :]
    
    if 'pos' in name:
        TEST_target[i] = 1.0
    else:
        TEST_target[i] = 0.0

# %%
np.sum(TEST_target) / len(TEST_target)
# Out:
# 0.0015604681404421327

# %%
plt.plot(TEST_target)

# %% [markdown]
# **ConvNext**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend
from tensorflow.keras import layers
from tensorflow.keras import utils
from tensorflow.keras import Model

  
class LayerScale(layers.Layer):
    """Layer scale module.
    References:
      - https://arxiv.org/abs/2103.17239
    Args:
      init_values (float): Initial value for layer scale. Should be within
        [0, 1].
      projection_dim (int): Projection dimensionality.
    Returns:
      Tensor multiplied to the scale.
    """

    def __init__(self, init_values, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.init_values = init_values
        self.projection_dim = projection_dim

    def build(self, input_shape):
        self.gamma = tf.Variable(
            self.init_values * tf.ones((self.projection_dim,))
        )

    def call(self, x):
        return x * self.gamma

    def get_config(self):
        config = super().get_config()
        config.update(
            {
                "init_values": self.init_values,
                "projection_dim": self.projection_dim,
            }
        )
        return config
    


def Head(num_classes=1000, name=None):
    """Implementation of classification head of RegNet.
    Args:
      num_classes: number of classes for Dense layer
      name: name prefix
    Returns:
      Classification head function.
    """
    if name is None:
        name = str(backend.get_uid("head"))

    def apply(x):
        x = layers.GlobalAveragePooling2D(name=name + "_head_gap")(x)
        x = layers.LayerNormalization(
            epsilon=1e-6, name=name + "_head_layernorm"
        )(x)
        x = layers.Dense(num_classes, name=name + "_head_dense")(x)
        return x

    return apply

# %%
MODEL_CONFIGS = {
    "tiny": {
        "depths": [3, 3, 9, 3],
        "projection_dims": [96, 192, 384, 768],
    },
    "small": {
        "depths": [3, 3, 27, 3],
        "projection_dims": [96, 192, 384, 768],
    },
    "base": {
        "depths": [3, 3, 27, 3],
        "projection_dims": [128, 256, 512, 1024],
    },
    "large": {
        "depths": [3, 3, 27, 3],
        "projection_dims": [192, 384, 768, 1536],
    },
    "xlarge": {
        "depths": [3, 3, 27, 3],
        "projection_dims": [256, 512, 1024, 2048],
    },
}

# %%
depths=[3, 3, 27, 3]
projection_dims=[96, 192, 384, 768]
drop_path_rate=0.0
layer_scale_init_value=1e-6
model_name='test'
input_shape=(48, 48, 23)
classes=1

IN = layers.Input(shape=input_shape)
X = IN

num_convnext_blocks = 4

# ----- convnext block 0 ----- #

X = layers.Conv2D(projection_dims[0], kernel_size=2, strides=2, name="{}_down0".format(model_name))(X)
X = layers.LayerNormalization(epsilon=1e-6, name="{}_down0_norm".format(model_name))(X)

for j in range(depths[0]):
    
    X_convnext = X
    X_convnext = layers.Conv2D(filters=projection_dims[0], kernel_size=7, padding="same",
                               groups=projection_dims[0], name="{}_down0_dconv{}".format(model_name, j))(X_convnext)
    X_convnext = layers.LayerNormalization(epsilon=1e-6, name="{}_down0_dconv{}_norm".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(4 * projection_dims[0], name="{}_down0_dense{}_p1".format(model_name, j))(X_convnext)
    X_convnext = layers.Activation("gelu", name="{}_down0_gelu{}".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(projection_dims[0], name="{}_down0_dense{}_p2".format(model_name, j))(X_convnext)

    X_convnext = LayerScale(layer_scale_init_value, projection_dims[0], name="{}_down0_layerscale{}".format(model_name, j))(X_convnext)

    X = X + X_convnext


# ----- convnext block 1 ----- #

X = layers.LayerNormalization(epsilon=1e-6, name="{}_down1_norm".format(model_name))(X)
X = layers.Conv2D(projection_dims[1], kernel_size=2, strides=2, name="{}_down1".format(model_name))(X)

for j in range(depths[1]):
    
    X_convnext = X
    X_convnext = layers.Conv2D(filters=projection_dims[1], kernel_size=7, padding="same",
                               groups=projection_dims[1], name="{}_down1_dconv{}".format(model_name, j))(X_convnext)
    X_convnext = layers.LayerNormalization(epsilon=1e-6, name="{}_down1_dconv{}_norm".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(4 * projection_dims[1], name="{}_down1_dense{}_p1".format(model_name, j))(X_convnext)
    X_convnext = layers.Activation("gelu", name="{}_down1_gelu{}".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(projection_dims[1], name="{}_down1_dense{}_p2".format(model_name, j))(X_convnext)

    X_convnext = LayerScale(layer_scale_init_value, projection_dims[1], name="{}_down1_layerscale{}".format(model_name, j))(X_convnext)

    X = X + X_convnext

# ----- convnext block 2 ----- #

X = layers.LayerNormalization(epsilon=1e-6, name="{}_down2_norm".format(model_name))(X)
X = layers.Conv2D(projection_dims[2], kernel_size=2, strides=2, name="{}_down2".format(model_name))(X)

for j in range(depths[2]):
    
    X_convnext = X
    X_convnext = layers.Conv2D(filters=projection_dims[2], kernel_size=7, padding="same",
                               groups=projection_dims[2], name="{}_down2_dconv{}".format(model_name, j))(X_convnext)
    X_convnext = layers.LayerNormalization(epsilon=1e-6, name="{}_down2_dconv{}_norm".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(4 * projection_dims[2], name="{}_down2_dense{}_p1".format(model_name, j))(X_convnext)
    X_convnext = layers.Activation("gelu", name="{}_down2_gelu{}".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(projection_dims[2], name="{}_down2_dense{}_p2".format(model_name, j))(X_convnext)

    X_convnext = LayerScale(layer_scale_init_value, projection_dims[2], name="{}_down2_layerscale{}".format(model_name, j))(X_convnext)

    X = X + X_convnext

# ----- convnext block 3 ----- #

X = layers.LayerNormalization(epsilon=1e-6, name="{}_down3_norm".format(model_name))(X)
X = layers.Conv2D(projection_dims[3], kernel_size=2, padding='same', name="{}_down3".format(model_name))(X)

for j in range(depths[3]):
    
    X_convnext = X
    X_convnext = layers.Conv2D(filters=projection_dims[3], kernel_size=7, padding="same",
                               groups=projection_dims[3], name="{}_down3_dconv{}".format(model_name, j))(X_convnext)
    X_convnext = layers.LayerNormalization(epsilon=1e-6, name="{}_down3_dconv{}_norm".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(4 * projection_dims[3], name="{}_down3_dense{}_p1".format(model_name, j))(X_convnext)
    X_convnext = layers.Activation("gelu", name="{}_down3_gelu{}".format(model_name, j))(X_convnext)
    X_convnext = layers.Dense(projection_dims[3], name="{}_down3_dense{}_p2".format(model_name, j))(X_convnext)

    X_convnext = LayerScale(layer_scale_init_value, projection_dims[3], name="{}_down3_layerscale{}".format(model_name, j))(X_convnext)

    X = X + X_convnext

OUT = X

OUT = layers.GlobalMaxPooling2D(name="{}_head_pool".format(model_name))(OUT)
OUT = layers.LayerNormalization(epsilon=1e-6, name="{}_head_norm".format(model_name))(OUT)
OUT = layers.Dense(1, name="{}_head_out".format(model_name))(OUT)

model = Model(inputs=IN, outputs=OUT, name=model_name)
# Out:
# 2022-09-22 12:48:19.122575: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-09-22 12:48:19.124078: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-09-22 12:48:19.182260: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:62:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2022-09-22 12:48:19.182300: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-09-22 12:48:19.231770: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-09-22 12:48:19.231824: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-09-22 12:48:19.266704: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-09-22 12:48:19.310840: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-09-22 12:48:19.354176: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-09-22 12:48:19.657998: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-09-22 12:48:19.691863: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-09-22 12:48:19.692744: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-09-22 12:48:19.693251: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-22 12:48:19.693527: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-09-22 12:48:19.694004: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:62:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2022-09-22 12:48:19.694044: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-09-22 12:48:19.694078: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-09-22 12:48:19.694092: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-09-22 12:48:19.694105: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-09-22 12:48:19.694118: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-09-22 12:48:19.694132: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-09-22 12:48:19.694145: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-09-22 12:48:19.694158: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-09-22 12:48:19.694773: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-09-22 12:48:19.694813: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-09-22 12:48:20.334774: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-09-22 12:48:20.334812: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-09-22 12:48:20.334825: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-09-22 12:48:20.336010: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30132 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:62:00.0, compute capability: 7.0)

# %%
model.summary()
# Out:
# Model: "test"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 48, 48, 23)] 0
# __________________________________________________________________________________________________
# test_down0 (Conv2D)             (None, 24, 24, 96)   8928        input_1[0][0]
# __________________________________________________________________________________________________
# test_down0_norm (LayerNormaliza (None, 24, 24, 96)   192         test_down0[0][0]
# __________________________________________________________________________________________________
# test_down0_dconv0 (Conv2D)      (None, 24, 24, 96)   4800        test_down0_norm[0][0]
# __________________________________________________________________________________________________
# test_down0_dconv0_norm (LayerNo (None, 24, 24, 96)   192         test_down0_dconv0[0][0]
# __________________________________________________________________________________________________
# test_down0_dense0_p1 (Dense)    (None, 24, 24, 384)  37248       test_down0_dconv0_norm[0][0]
# __________________________________________________________________________________________________
# test_down0_gelu0 (Activation)   (None, 24, 24, 384)  0           test_down0_dense0_p1[0][0]
# __________________________________________________________________________________________________
# test_down0_dense0_p2 (Dense)    (None, 24, 24, 96)   36960       test_down0_gelu0[0][0]
# __________________________________________________________________________________________________
# test_down0_layerscale0 (LayerSc (None, 24, 24, 96)   96          test_down0_dense0_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 24, 24, 96)   0           test_down0_norm[0][0]
#                                                                  test_down0_layerscale0[0][0]
# __________________________________________________________________________________________________
# test_down0_dconv1 (Conv2D)      (None, 24, 24, 96)   4800        tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# test_down0_dconv1_norm (LayerNo (None, 24, 24, 96)   192         test_down0_dconv1[0][0]
# __________________________________________________________________________________________________
# test_down0_dense1_p1 (Dense)    (None, 24, 24, 384)  37248       test_down0_dconv1_norm[0][0]
# __________________________________________________________________________________________________
# test_down0_gelu1 (Activation)   (None, 24, 24, 384)  0           test_down0_dense1_p1[0][0]
# __________________________________________________________________________________________________
# test_down0_dense1_p2 (Dense)    (None, 24, 24, 96)   36960       test_down0_gelu1[0][0]
# __________________________________________________________________________________________________
# test_down0_layerscale1 (LayerSc (None, 24, 24, 96)   96          test_down0_dense1_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 24, 24, 96)   0           tf.__operators__.add[0][0]
#                                                                  test_down0_layerscale1[0][0]
# __________________________________________________________________________________________________
# test_down0_dconv2 (Conv2D)      (None, 24, 24, 96)   4800        tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# test_down0_dconv2_norm (LayerNo (None, 24, 24, 96)   192         test_down0_dconv2[0][0]
# __________________________________________________________________________________________________
# test_down0_dense2_p1 (Dense)    (None, 24, 24, 384)  37248       test_down0_dconv2_norm[0][0]
# __________________________________________________________________________________________________
# test_down0_gelu2 (Activation)   (None, 24, 24, 384)  0           test_down0_dense2_p1[0][0]
# __________________________________________________________________________________________________
# test_down0_dense2_p2 (Dense)    (None, 24, 24, 96)   36960       test_down0_gelu2[0][0]
# __________________________________________________________________________________________________
# test_down0_layerscale2 (LayerSc (None, 24, 24, 96)   96          test_down0_dense2_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 24, 24, 96)   0           tf.__operators__.add_1[0][0]
#                                                                  test_down0_layerscale2[0][0]
# __________________________________________________________________________________________________
# test_down1_norm (LayerNormaliza (None, 24, 24, 96)   192         tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# test_down1 (Conv2D)             (None, 12, 12, 192)  73920       test_down1_norm[0][0]
# __________________________________________________________________________________________________
# test_down1_dconv0 (Conv2D)      (None, 12, 12, 192)  9600        test_down1[0][0]
# __________________________________________________________________________________________________
# test_down1_dconv0_norm (LayerNo (None, 12, 12, 192)  384         test_down1_dconv0[0][0]
# __________________________________________________________________________________________________
# test_down1_dense0_p1 (Dense)    (None, 12, 12, 768)  148224      test_down1_dconv0_norm[0][0]
# __________________________________________________________________________________________________
# test_down1_gelu0 (Activation)   (None, 12, 12, 768)  0           test_down1_dense0_p1[0][0]
# __________________________________________________________________________________________________
# test_down1_dense0_p2 (Dense)    (None, 12, 12, 192)  147648      test_down1_gelu0[0][0]
# __________________________________________________________________________________________________
# test_down1_layerscale0 (LayerSc (None, 12, 12, 192)  192         test_down1_dense0_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 12, 12, 192)  0           test_down1[0][0]
#                                                                  test_down1_layerscale0[0][0]
# __________________________________________________________________________________________________
# test_down1_dconv1 (Conv2D)      (None, 12, 12, 192)  9600        tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# test_down1_dconv1_norm (LayerNo (None, 12, 12, 192)  384         test_down1_dconv1[0][0]
# __________________________________________________________________________________________________
# test_down1_dense1_p1 (Dense)    (None, 12, 12, 768)  148224      test_down1_dconv1_norm[0][0]
# __________________________________________________________________________________________________
# test_down1_gelu1 (Activation)   (None, 12, 12, 768)  0           test_down1_dense1_p1[0][0]
# __________________________________________________________________________________________________
# test_down1_dense1_p2 (Dense)    (None, 12, 12, 192)  147648      test_down1_gelu1[0][0]
# __________________________________________________________________________________________________
# test_down1_layerscale1 (LayerSc (None, 12, 12, 192)  192         test_down1_dense1_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 12, 12, 192)  0           tf.__operators__.add_3[0][0]
#                                                                  test_down1_layerscale1[0][0]
# __________________________________________________________________________________________________
# test_down1_dconv2 (Conv2D)      (None, 12, 12, 192)  9600        tf.__operators__.add_4[0][0]
# __________________________________________________________________________________________________
# test_down1_dconv2_norm (LayerNo (None, 12, 12, 192)  384         test_down1_dconv2[0][0]
# __________________________________________________________________________________________________
# test_down1_dense2_p1 (Dense)    (None, 12, 12, 768)  148224      test_down1_dconv2_norm[0][0]
# __________________________________________________________________________________________________
# test_down1_gelu2 (Activation)   (None, 12, 12, 768)  0           test_down1_dense2_p1[0][0]
# __________________________________________________________________________________________________
# test_down1_dense2_p2 (Dense)    (None, 12, 12, 192)  147648      test_down1_gelu2[0][0]
# __________________________________________________________________________________________________
# test_down1_layerscale2 (LayerSc (None, 12, 12, 192)  192         test_down1_dense2_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 12, 12, 192)  0           tf.__operators__.add_4[0][0]
#                                                                  test_down1_layerscale2[0][0]
# __________________________________________________________________________________________________
# test_down2_norm (LayerNormaliza (None, 12, 12, 192)  384         tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# test_down2 (Conv2D)             (None, 6, 6, 384)    295296      test_down2_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv0 (Conv2D)      (None, 6, 6, 384)    19200       test_down2[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv0_norm (LayerNo (None, 6, 6, 384)    768         test_down2_dconv0[0][0]
# __________________________________________________________________________________________________
# test_down2_dense0_p1 (Dense)    (None, 6, 6, 1536)   591360      test_down2_dconv0_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu0 (Activation)   (None, 6, 6, 1536)   0           test_down2_dense0_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense0_p2 (Dense)    (None, 6, 6, 384)    590208      test_down2_gelu0[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale0 (LayerSc (None, 6, 6, 384)    384         test_down2_dense0_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 6, 6, 384)    0           test_down2[0][0]
#                                                                  test_down2_layerscale0[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv1 (Conv2D)      (None, 6, 6, 384)    19200       tf.__operators__.add_6[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv1_norm (LayerNo (None, 6, 6, 384)    768         test_down2_dconv1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense1_p1 (Dense)    (None, 6, 6, 1536)   591360      test_down2_dconv1_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu1 (Activation)   (None, 6, 6, 1536)   0           test_down2_dense1_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense1_p2 (Dense)    (None, 6, 6, 384)    590208      test_down2_gelu1[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale1 (LayerSc (None, 6, 6, 384)    384         test_down2_dense1_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_7 (TFOpLam (None, 6, 6, 384)    0           tf.__operators__.add_6[0][0]
#                                                                  test_down2_layerscale1[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv2 (Conv2D)      (None, 6, 6, 384)    19200       tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv2_norm (LayerNo (None, 6, 6, 384)    768         test_down2_dconv2[0][0]
# __________________________________________________________________________________________________
# test_down2_dense2_p1 (Dense)    (None, 6, 6, 1536)   591360      test_down2_dconv2_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu2 (Activation)   (None, 6, 6, 1536)   0           test_down2_dense2_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense2_p2 (Dense)    (None, 6, 6, 384)    590208      test_down2_gelu2[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale2 (LayerSc (None, 6, 6, 384)    384         test_down2_dense2_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_8 (TFOpLam (None, 6, 6, 384)    0           tf.__operators__.add_7[0][0]
#                                                                  test_down2_layerscale2[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv3 (Conv2D)      (None, 6, 6, 384)    19200       tf.__operators__.add_8[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv3_norm (LayerNo (None, 6, 6, 384)    768         test_down2_dconv3[0][0]
# __________________________________________________________________________________________________
# test_down2_dense3_p1 (Dense)    (None, 6, 6, 1536)   591360      test_down2_dconv3_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu3 (Activation)   (None, 6, 6, 1536)   0           test_down2_dense3_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense3_p2 (Dense)    (None, 6, 6, 384)    590208      test_down2_gelu3[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale3 (LayerSc (None, 6, 6, 384)    384         test_down2_dense3_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_9 (TFOpLam (None, 6, 6, 384)    0           tf.__operators__.add_8[0][0]
#                                                                  test_down2_layerscale3[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv4 (Conv2D)      (None, 6, 6, 384)    19200       tf.__operators__.add_9[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv4_norm (LayerNo (None, 6, 6, 384)    768         test_down2_dconv4[0][0]
# __________________________________________________________________________________________________
# test_down2_dense4_p1 (Dense)    (None, 6, 6, 1536)   591360      test_down2_dconv4_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu4 (Activation)   (None, 6, 6, 1536)   0           test_down2_dense4_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense4_p2 (Dense)    (None, 6, 6, 384)    590208      test_down2_gelu4[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale4 (LayerSc (None, 6, 6, 384)    384         test_down2_dense4_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_10 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_9[0][0]
#                                                                  test_down2_layerscale4[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv5 (Conv2D)      (None, 6, 6, 384)    19200       tf.__operators__.add_10[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv5_norm (LayerNo (None, 6, 6, 384)    768         test_down2_dconv5[0][0]
# __________________________________________________________________________________________________
# test_down2_dense5_p1 (Dense)    (None, 6, 6, 1536)   591360      test_down2_dconv5_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu5 (Activation)   (None, 6, 6, 1536)   0           test_down2_dense5_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense5_p2 (Dense)    (None, 6, 6, 384)    590208      test_down2_gelu5[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale5 (LayerSc (None, 6, 6, 384)    384         test_down2_dense5_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_11 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_10[0][0]
#                                                                  test_down2_layerscale5[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv6 (Conv2D)      (None, 6, 6, 384)    19200       tf.__operators__.add_11[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv6_norm (LayerNo (None, 6, 6, 384)    768         test_down2_dconv6[0][0]
# __________________________________________________________________________________________________
# test_down2_dense6_p1 (Dense)    (None, 6, 6, 1536)   591360      test_down2_dconv6_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu6 (Activation)   (None, 6, 6, 1536)   0           test_down2_dense6_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense6_p2 (Dense)    (None, 6, 6, 384)    590208      test_down2_gelu6[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale6 (LayerSc (None, 6, 6, 384)    384         test_down2_dense6_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_12 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_11[0][0]
#                                                                  test_down2_layerscale6[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv7 (Conv2D)      (None, 6, 6, 384)    19200       tf.__operators__.add_12[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv7_norm (LayerNo (None, 6, 6, 384)    768         test_down2_dconv7[0][0]
# __________________________________________________________________________________________________
# test_down2_dense7_p1 (Dense)    (None, 6, 6, 1536)   591360      test_down2_dconv7_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu7 (Activation)   (None, 6, 6, 1536)   0           test_down2_dense7_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense7_p2 (Dense)    (None, 6, 6, 384)    590208      test_down2_gelu7[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale7 (LayerSc (None, 6, 6, 384)    384         test_down2_dense7_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_13 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_12[0][0]
#                                                                  test_down2_layerscale7[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv8 (Conv2D)      (None, 6, 6, 384)    19200       tf.__operators__.add_13[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv8_norm (LayerNo (None, 6, 6, 384)    768         test_down2_dconv8[0][0]
# __________________________________________________________________________________________________
# test_down2_dense8_p1 (Dense)    (None, 6, 6, 1536)   591360      test_down2_dconv8_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu8 (Activation)   (None, 6, 6, 1536)   0           test_down2_dense8_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense8_p2 (Dense)    (None, 6, 6, 384)    590208      test_down2_gelu8[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale8 (LayerSc (None, 6, 6, 384)    384         test_down2_dense8_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_14 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_13[0][0]
#                                                                  test_down2_layerscale8[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv9 (Conv2D)      (None, 6, 6, 384)    19200       tf.__operators__.add_14[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv9_norm (LayerNo (None, 6, 6, 384)    768         test_down2_dconv9[0][0]
# __________________________________________________________________________________________________
# test_down2_dense9_p1 (Dense)    (None, 6, 6, 1536)   591360      test_down2_dconv9_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu9 (Activation)   (None, 6, 6, 1536)   0           test_down2_dense9_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense9_p2 (Dense)    (None, 6, 6, 384)    590208      test_down2_gelu9[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale9 (LayerSc (None, 6, 6, 384)    384         test_down2_dense9_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_15 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_14[0][0]
#                                                                  test_down2_layerscale9[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv10 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_15[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv10_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv10[0][0]
# __________________________________________________________________________________________________
# test_down2_dense10_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv10_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu10 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense10_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense10_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu10[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale10 (LayerS (None, 6, 6, 384)    384         test_down2_dense10_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_16 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_15[0][0]
#                                                                  test_down2_layerscale10[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv11 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_16[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv11_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv11[0][0]
# __________________________________________________________________________________________________
# test_down2_dense11_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv11_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu11 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense11_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense11_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu11[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale11 (LayerS (None, 6, 6, 384)    384         test_down2_dense11_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_17 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_16[0][0]
#                                                                  test_down2_layerscale11[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv12 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_17[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv12_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv12[0][0]
# __________________________________________________________________________________________________
# test_down2_dense12_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv12_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu12 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense12_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense12_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu12[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale12 (LayerS (None, 6, 6, 384)    384         test_down2_dense12_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_18 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_17[0][0]
#                                                                  test_down2_layerscale12[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv13 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_18[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv13_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv13[0][0]
# __________________________________________________________________________________________________
# test_down2_dense13_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv13_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu13 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense13_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense13_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu13[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale13 (LayerS (None, 6, 6, 384)    384         test_down2_dense13_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_19 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_18[0][0]
#                                                                  test_down2_layerscale13[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv14 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_19[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv14_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv14[0][0]
# __________________________________________________________________________________________________
# test_down2_dense14_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv14_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu14 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense14_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense14_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu14[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale14 (LayerS (None, 6, 6, 384)    384         test_down2_dense14_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_20 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_19[0][0]
#                                                                  test_down2_layerscale14[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv15 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_20[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv15_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv15[0][0]
# __________________________________________________________________________________________________
# test_down2_dense15_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv15_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu15 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense15_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense15_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu15[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale15 (LayerS (None, 6, 6, 384)    384         test_down2_dense15_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_21 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_20[0][0]
#                                                                  test_down2_layerscale15[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv16 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_21[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv16_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv16[0][0]
# __________________________________________________________________________________________________
# test_down2_dense16_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv16_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu16 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense16_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense16_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu16[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale16 (LayerS (None, 6, 6, 384)    384         test_down2_dense16_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_22 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_21[0][0]
#                                                                  test_down2_layerscale16[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv17 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_22[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv17_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv17[0][0]
# __________________________________________________________________________________________________
# test_down2_dense17_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv17_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu17 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense17_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense17_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu17[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale17 (LayerS (None, 6, 6, 384)    384         test_down2_dense17_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_23 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_22[0][0]
#                                                                  test_down2_layerscale17[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv18 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_23[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv18_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv18[0][0]
# __________________________________________________________________________________________________
# test_down2_dense18_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv18_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu18 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense18_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense18_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu18[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale18 (LayerS (None, 6, 6, 384)    384         test_down2_dense18_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_24 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_23[0][0]
#                                                                  test_down2_layerscale18[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv19 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_24[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv19_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv19[0][0]
# __________________________________________________________________________________________________
# test_down2_dense19_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv19_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu19 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense19_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense19_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu19[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale19 (LayerS (None, 6, 6, 384)    384         test_down2_dense19_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_25 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_24[0][0]
#                                                                  test_down2_layerscale19[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv20 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_25[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv20_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv20[0][0]
# __________________________________________________________________________________________________
# test_down2_dense20_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv20_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu20 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense20_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense20_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu20[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale20 (LayerS (None, 6, 6, 384)    384         test_down2_dense20_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_26 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_25[0][0]
#                                                                  test_down2_layerscale20[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv21 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_26[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv21_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv21[0][0]
# __________________________________________________________________________________________________
# test_down2_dense21_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv21_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu21 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense21_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense21_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu21[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale21 (LayerS (None, 6, 6, 384)    384         test_down2_dense21_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_27 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_26[0][0]
#                                                                  test_down2_layerscale21[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv22 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_27[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv22_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv22[0][0]
# __________________________________________________________________________________________________
# test_down2_dense22_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv22_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu22 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense22_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense22_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu22[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale22 (LayerS (None, 6, 6, 384)    384         test_down2_dense22_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_28 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_27[0][0]
#                                                                  test_down2_layerscale22[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv23 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_28[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv23_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv23[0][0]
# __________________________________________________________________________________________________
# test_down2_dense23_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv23_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu23 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense23_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense23_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu23[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale23 (LayerS (None, 6, 6, 384)    384         test_down2_dense23_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_29 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_28[0][0]
#                                                                  test_down2_layerscale23[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv24 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_29[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv24_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv24[0][0]
# __________________________________________________________________________________________________
# test_down2_dense24_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv24_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu24 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense24_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense24_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu24[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale24 (LayerS (None, 6, 6, 384)    384         test_down2_dense24_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_30 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_29[0][0]
#                                                                  test_down2_layerscale24[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv25 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_30[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv25_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv25[0][0]
# __________________________________________________________________________________________________
# test_down2_dense25_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv25_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu25 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense25_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense25_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu25[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale25 (LayerS (None, 6, 6, 384)    384         test_down2_dense25_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_31 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_30[0][0]
#                                                                  test_down2_layerscale25[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv26 (Conv2D)     (None, 6, 6, 384)    19200       tf.__operators__.add_31[0][0]
# __________________________________________________________________________________________________
# test_down2_dconv26_norm (LayerN (None, 6, 6, 384)    768         test_down2_dconv26[0][0]
# __________________________________________________________________________________________________
# test_down2_dense26_p1 (Dense)   (None, 6, 6, 1536)   591360      test_down2_dconv26_norm[0][0]
# __________________________________________________________________________________________________
# test_down2_gelu26 (Activation)  (None, 6, 6, 1536)   0           test_down2_dense26_p1[0][0]
# __________________________________________________________________________________________________
# test_down2_dense26_p2 (Dense)   (None, 6, 6, 384)    590208      test_down2_gelu26[0][0]
# __________________________________________________________________________________________________
# test_down2_layerscale26 (LayerS (None, 6, 6, 384)    384         test_down2_dense26_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_32 (TFOpLa (None, 6, 6, 384)    0           tf.__operators__.add_31[0][0]
#                                                                  test_down2_layerscale26[0][0]
# __________________________________________________________________________________________________
# test_down3_norm (LayerNormaliza (None, 6, 6, 384)    768         tf.__operators__.add_32[0][0]
# __________________________________________________________________________________________________
# test_down3 (Conv2D)             (None, 6, 6, 768)    1180416     test_down3_norm[0][0]
# __________________________________________________________________________________________________
# test_down3_dconv0 (Conv2D)      (None, 6, 6, 768)    38400       test_down3[0][0]
# __________________________________________________________________________________________________
# test_down3_dconv0_norm (LayerNo (None, 6, 6, 768)    1536        test_down3_dconv0[0][0]
# __________________________________________________________________________________________________
# test_down3_dense0_p1 (Dense)    (None, 6, 6, 3072)   2362368     test_down3_dconv0_norm[0][0]
# __________________________________________________________________________________________________
# test_down3_gelu0 (Activation)   (None, 6, 6, 3072)   0           test_down3_dense0_p1[0][0]
# __________________________________________________________________________________________________
# test_down3_dense0_p2 (Dense)    (None, 6, 6, 768)    2360064     test_down3_gelu0[0][0]
# __________________________________________________________________________________________________
# test_down3_layerscale0 (LayerSc (None, 6, 6, 768)    768         test_down3_dense0_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_33 (TFOpLa (None, 6, 6, 768)    0           test_down3[0][0]
#                                                                  test_down3_layerscale0[0][0]
# __________________________________________________________________________________________________
# test_down3_dconv1 (Conv2D)      (None, 6, 6, 768)    38400       tf.__operators__.add_33[0][0]
# __________________________________________________________________________________________________
# test_down3_dconv1_norm (LayerNo (None, 6, 6, 768)    1536        test_down3_dconv1[0][0]
# __________________________________________________________________________________________________
# test_down3_dense1_p1 (Dense)    (None, 6, 6, 3072)   2362368     test_down3_dconv1_norm[0][0]
# __________________________________________________________________________________________________
# test_down3_gelu1 (Activation)   (None, 6, 6, 3072)   0           test_down3_dense1_p1[0][0]
# __________________________________________________________________________________________________
# test_down3_dense1_p2 (Dense)    (None, 6, 6, 768)    2360064     test_down3_gelu1[0][0]
# __________________________________________________________________________________________________
# test_down3_layerscale1 (LayerSc (None, 6, 6, 768)    768         test_down3_dense1_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_34 (TFOpLa (None, 6, 6, 768)    0           tf.__operators__.add_33[0][0]
#                                                                  test_down3_layerscale1[0][0]
# __________________________________________________________________________________________________
# test_down3_dconv2 (Conv2D)      (None, 6, 6, 768)    38400       tf.__operators__.add_34[0][0]
# __________________________________________________________________________________________________
# test_down3_dconv2_norm (LayerNo (None, 6, 6, 768)    1536        test_down3_dconv2[0][0]
# __________________________________________________________________________________________________
# test_down3_dense2_p1 (Dense)    (None, 6, 6, 3072)   2362368     test_down3_dconv2_norm[0][0]
# __________________________________________________________________________________________________
# test_down3_gelu2 (Activation)   (None, 6, 6, 3072)   0           test_down3_dense2_p1[0][0]
# __________________________________________________________________________________________________
# test_down3_dense2_p2 (Dense)    (None, 6, 6, 768)    2360064     test_down3_gelu2[0][0]
# __________________________________________________________________________________________________
# test_down3_layerscale2 (LayerSc (None, 6, 6, 768)    768         test_down3_dense2_p2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_35 (TFOpLa (None, 6, 6, 768)    0           tf.__operators__.add_34[0][0]
#                                                                  test_down3_layerscale2[0][0]
# __________________________________________________________________________________________________
# test_head_pool (GlobalMaxPoolin (None, 768)          0           tf.__operators__.add_35[0][0]
# __________________________________________________________________________________________________
# test_head_norm (LayerNormalizat (None, 768)          1536        test_head_pool[0][0]
# __________________________________________________________________________________________________
# test_head_out (Dense)           (None, 1)            769         test_head_norm[0][0]
# ==================================================================================================
# Total params: 49,459,681
# Trainable params: 49,459,681
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.metrics import brier_score_loss

def verif_metric(VALID_target, Y_pred, thres=0.5):

    tn, fp, fn, tp = confusion_matrix(VALID_target.ravel(), Y_pred.ravel()>thres).ravel()

    CSI = tp/(tp+fn+fp)
    CSI_metric = 1 - CSI

    fpr, tpr, thresholds = roc_curve(VALID_target.ravel(), Y_pred.ravel())
    AUC = auc(fpr, tpr)
    AUC_metric = 1 - AUC
    
    freq = (tp+fp)/(tp+fn)
    freq_metric = np.abs(freq-1.0)
    
    BS = brier_score_loss(VALID_target.ravel(), Y_pred.ravel())
    
    print('{} {} {} {}'.format(CSI, AUC, freq, BS))
    metric = AUC_metric + 2*BS


    return metric

# %%
tol = 0
min_del = 0
max_tol = 500 # early stopping with patience

epochs = 500
L_train = 64
batch_size = 100

batch_size_half = 50

valid_size = 1

# %%
batch_dir = '/glade/scratch/ksha/DATA/NCAR_batch/'
temp_dir = '/glade/work/ksha/NCAR/Keras_models/'

key = 'FINAL_SMALL'

model_name = '{}_pp23_tune'.format(key)
model_path = temp_dir+model_name

model_name_backup = '{}_pp23_backup'.format(key)
model_path_backup = temp_dir+model_name_backup
W_old = k_utils.dummy_loader(temp_dir+'FINAL_SMALL_pp23')
model.set_weights(W_old)

# %%
model.compile(loss=keras.losses.mean_absolute_error, optimizer=keras.optimizers.Adam(lr=1e-5))

# %%
X_batch = np.empty((batch_size, 48, 48, L_vars))
Y_batch = np.empty((batch_size, 1))
X_batch[...] = np.nan
Y_batch[...] = np.nan

# %%
Y_pred = model.predict([TEST_input,])
Y_pred[Y_pred<0] = 0
Y_pred[Y_pred>1] = 1
record = verif_metric(TEST_target, Y_pred, thres=0.5)
print("Initial record: {}".format(record))
# Out:
# /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:3503: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   warnings.warn(
# 0.02617801047120419 0.9185226187375184 15.333333333333334 0.027188692497672515
# Initial record: 0.13585476625782664

# %%
plt.figure(figsize=(15, 4))
#plt.plot(TEST_target, 'b-', lw=3.0)
plt.plot(Y_pred[-1000:], 'r-')
#plt.plot(Y_pred>0.5)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ========== Training loop ========== #
L_storm = len(filename_neg_train)
L_aug = len(filename_pos_train)

for i in range(epochs):
    
    shuffle(filename_neg_train)
    shuffle(filename_pos_train)
    
    #print('epoch = {}'.format(i))
    start_time = time.time()
    
    # loop of batch
    for j in range(L_train):
        
        N_aug = int(np.random.uniform(2, 14))
        #N_aug = int(np.random.uniform(8, 14))
        #N_aug = int(np.random.uniform(6, 12))
        
        N_storm = 100 - N_aug
        
        ind_storm = du.shuffle_ind(L_storm)
        ind_aug = du.shuffle_ind(L_aug)
        
        file_pick_storm = []
        for ind_temp in ind_storm[:N_storm]:
            file_pick_storm.append(filename_neg_train[ind_temp])

        file_pick_aug = []
        for ind_temp in ind_aug[:N_aug]:
            file_pick_aug.append(filename_pos_train[ind_temp])
        
        file_pick = file_pick_storm + file_pick_aug
        
        if len(file_pick) != 100:
            sregwet
        
        for k in range(batch_size):

            data = np.load(file_pick[k])
            X_batch[k, ...] = data[:, 40:-40, 40:-40, :]
            
            if 'pos' in file_pick[k]:
                Y_batch[k, :] = np.random.uniform(0.9, 0.99)
            elif 'neg_neg_neg' in file_pick[k]:
                Y_batch[k, :] = np.random.uniform(0.01, 0.05)
            else:
                werhgaer
                
        #Y_batch_cate = tf.keras.utils.to_categorical(Y_batch)
        
        # # add noise within sparse inputs
        # for v in flag_sparse:
        #     X_batch[..., v] += np.random.uniform(0, 0.01, size=(batch_size, 128, 128))

        # shuffle indices
        ind_ = du.shuffle_ind(batch_size)
        X_batch = X_batch[ind_, ...]
        Y_batch = Y_batch[ind_, :]
        
        if np.sum(np.isnan(X_batch)) > 0:
            asfeargagqarew
        
        # train on batch
        model.train_on_batch([X_batch,], [Y_batch,]);
    
    # epoch end operations
    Y_pred = model.predict([TEST_input,])
    Y_pred[Y_pred<0] = 0
    Y_pred[Y_pred>1] = 1
    #Y_pred = Y_pred[:, -1]
    
    record_temp = verif_metric(TEST_target, Y_pred)
    
    # if i % 10 == 0:
    #     model.save(model_path_backup)
    
    if (record - record_temp > min_del) and (np.max(Y_pred) > 0.6):
        print('Validation loss improved from {} to {}'.format(record, record_temp))
        record = record_temp
        tol = 0
        #print('tol: {}'.format(tol))
        # save
        print('save to: {}'.format(model_path))
        model.save(model_path)
    else:
        print('Validation loss {} NOT improved'.format(record_temp))
        tol += 1
        #print('tol: {}'.format(tol))
        if tol >= max_tol:
            print('Early stopping')
            sys.exit();
        else:
            #print('Pass to the next epoch')
            continue;
    print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:3503: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   warnings.warn(
# 0.026755852842809364 0.9316662325258314 24.583333333333332 0.04129754633699126
# Validation loss 0.15092886014815116 NOT improved
# /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:3503: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   warnings.warn(
# 0.014106583072100314 0.9191955370322134 52.916666666666664 0.07624678420048689
# Validation loss 0.23329803136876043 NOT improved

# %%
model.save(model_path_backup)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 5591
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/FINAL_pp23_backup/assets

# %%
j
# Out:
# 123844

# %%
https://mesonet.agron.iastate.edu/pickup/wwa/

# %%
10 % 3
# Out:
# 1
