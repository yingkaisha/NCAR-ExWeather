# %%
# general tools
import os
import sys
import time
import h5py
import random
from glob import glob

import numpy as np
from datetime import datetime, timedelta
from random import shuffle

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend
from keras_unet_collection import utils as k_utils
# Out:
# 2023-01-05 21:55:30.172254: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
sys.path.insert(0, '/glade/u/home/ksha/NCAR/')
sys.path.insert(0, '/glade/u/home/ksha/NCAR/libs/')

from namelist import *
import data_utils as du

# %%
import re

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def pos_mixer(TRAIN, L, a0=0, a1=0.2):
    data_shape = TRAIN.shape
    out = np.empty((L, data_shape[-1]))
    
    for i in range(L):
        inds = np.random.choice(data_shape[0], 2)
        a = np.random.uniform(a0, a1)
        out[i, :] = a*TRAIN[inds[0], :] + (1-a)*TRAIN[inds[1], :]
    return out

# %%
def set_seeds(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)

# %%
def verif_metric(VALID_target, Y_pred, ref):


    # fpr, tpr, thresholds = roc_curve(VALID_target.ravel(), Y_pred.ravel())
    # AUC = auc(fpr, tpr)
    # AUC_metric = 1 - AUC
    
    BS = np.mean((VALID_target.ravel() - Y_pred.ravel())**2)
    #ll = log_loss(VALID_target.ravel(), Y_pred.ravel())
    
    #print('{}'.format(BS))
    metric = BS

    return metric / ref

# %%
def set_seeds(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)

# %%
def feature_extract(filenames, lon_80km, lon_minmax, lat_80km, lat_minmax, elev_80km, elev_max):
    
    lon_out = []
    lat_out = []
    elev_out = []
    mon_out = []
    
    base_v3_s = datetime(2018, 7, 15)
    base_v3_e = datetime(2020, 12, 2)

    base_v4_s = datetime(2020, 12, 3)
    base_v4_e = datetime(2022, 7, 15)

    base_ref = datetime(2010, 1, 1)
    
    date_list_v3 = [base_v3_s + timedelta(days=day) for day in range(365+365+142)]
    date_list_v4 = [base_v4_s + timedelta(days=day) for day in range(365+180-151)]
    
    for i, name in enumerate(filenames):
        
        if 'v4' in name:
            date_list = date_list_v4
        else:
            date_list = date_list_v3
        
        nums = re.findall(r'\d+', name)
        indy = int(nums[-2])
        indx = int(nums[-3])
        day = int(nums[-4])
        day = date_list[day]
        month = day.month
        
        month_norm = (month - 1)/(12-1)
        
        lon = lon_80km[indx, indy]
        lat = lat_80km[indx, indy]

        lon = (lon - lon_minmax[0])/(lon_minmax[1] - lon_minmax[0])
        lat = (lat - lat_minmax[0])/(lat_minmax[1] - lat_minmax[0])

        elev = elev_80km[indx, indy]
        elev = elev / elev_max
        
        lon_out.append(lon)
        lat_out.append(lat)
        elev_out.append(elev)
        mon_out.append(month_norm)
        
    return np.array(lon_out), np.array(lat_out), np.array(elev_out), np.array(mon_out)

def create_model():

    
    IN_vec = keras.Input((128,))    
    X = IN_vec
    #
    X = keras.layers.Dense(1024, activity_regularizer=keras.regularizers.L2(1e-2))(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.Activation("gelu")(X)
    #X = keras.layers.Activation("relu")(X)

    X = keras.layers.Dropout(0.4)(X)
    
    #
    X = keras.layers.Dense(512, activity_regularizer=keras.regularizers.L2(1e-2))(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.Activation("gelu")(X)
    #X = keras.layers.Activation("relu")(X)
    
    X = keras.layers.Dropout(0.4)(X)
    
    X = keras.layers.Dense(128, activity_regularizer=keras.regularizers.L2(1e-2))(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.Activation("gelu")(X)
    #X = keras.layers.Activation("relu")(X)
    
    OUT = X
    OUT = keras.layers.Dense(1, activation='sigmoid', bias_initializer=keras.initializers.Constant(-10))(OUT)

    model = keras.models.Model(inputs=IN_vec, outputs=OUT)
    
    return model

# %%
with h5py.File(save_dir+'HRRR_domain.hdf', 'r') as h5io:
    lon_3km = h5io['lon_3km'][...]
    lat_3km = h5io['lat_3km'][...]
    lon_80km = h5io['lon_80km'][...]
    lat_80km = h5io['lat_80km'][...]
    elev_3km = h5io['elev_3km'][...]
    land_mask_80km = h5io['land_mask_80km'][...]
    
grid_shape = land_mask_80km.shape

# %%
elev_80km = du.interp2d_wraper(lon_3km, lat_3km, elev_3km, lon_80km, lat_80km, method='linear')

elev_80km[np.isnan(elev_80km)] = 0
elev_80km[elev_80km<0] = 0
elev_max = np.max(elev_80km)

lon_80km_mask = lon_80km[land_mask_80km]
lat_80km_mask = lat_80km[land_mask_80km]

lon_minmax = [np.min(lon_80km_mask), np.max(lon_80km_mask)]
lat_minmax = [np.min(lat_80km_mask), np.max(lat_80km_mask)]

# %%
lead = 4

# %%
filepath_train = "/glade/scratch/ksha/DATA/NCAR_batch/"
filepath_valid = "/glade/scratch/ksha/DATA/NCAR_batch/"
filepath_test = "/glade/scratch/ksha/DATA/NCAR_batch_v4/"
filepath_vec = "/glade/work/ksha/NCAR/"

# %%
filename_train_lead2 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/TRAIN*lead2.npy"))
filename_train_lead3 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/TRAIN*lead3.npy"))
filename_train_lead4 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/TRAIN*lead4.npy"))
filename_train_lead5 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/TRAIN*lead5.npy"))

# %%
filename_train = filename_train_lead2 + filename_train_lead3 + filename_train_lead4 + filename_train_lead5 + filename_train_lead6

# %%
IND_TRAIN_lead = np.load('/glade/work/ksha/NCAR/IND_TRAIN_lead.npy', allow_pickle=True)[()]
TRAIN_ind2 = IND_TRAIN_lead['lead2']
TRAIN_ind3 = IND_TRAIN_lead['lead3']
TRAIN_ind4 = IND_TRAIN_lead['lead4']
TRAIN_ind5 = IND_TRAIN_lead['lead5']

# %%
data_lead2_p0 = np.load('{}TRAIN_pp15_pred_lead{}_part0_base.npy'.format(filepath_vec, 2), allow_pickle=True)[()]
data_lead2_p1 = np.load('{}TRAIN_pp15_pred_lead{}_part1_base.npy'.format(filepath_vec, 2), allow_pickle=True)[()]
data_lead2_p2 = np.load('{}TRAIN_pp15_pred_lead{}_part2_base.npy'.format(filepath_vec, 2), allow_pickle=True)[()]

data_lead3_p0 = np.load('{}TRAIN_pp15_pred_lead{}_part0_base.npy'.format(filepath_vec, 3), allow_pickle=True)[()]
data_lead3_p1 = np.load('{}TRAIN_pp15_pred_lead{}_part1_base.npy'.format(filepath_vec, 3), allow_pickle=True)[()]
data_lead3_p2 = np.load('{}TRAIN_pp15_pred_lead{}_part2_base.npy'.format(filepath_vec, 3), allow_pickle=True)[()]

data_lead4_p0 = np.load('{}TRAIN_pp15_pred_lead{}_part0_base.npy'.format(filepath_vec, 4), allow_pickle=True)[()]
data_lead4_p1 = np.load('{}TRAIN_pp15_pred_lead{}_part1_base.npy'.format(filepath_vec, 4), allow_pickle=True)[()]
data_lead4_p2 = np.load('{}TRAIN_pp15_pred_lead{}_part2_base.npy'.format(filepath_vec, 4), allow_pickle=True)[()]

data_lead5_p0 = np.load('{}TRAIN_pp15_pred_lead{}_part0_base.npy'.format(filepath_vec, 5), allow_pickle=True)[()]
data_lead5_p1 = np.load('{}TRAIN_pp15_pred_lead{}_part1_base.npy'.format(filepath_vec, 5), allow_pickle=True)[()]
data_lead5_p2 = np.load('{}TRAIN_pp15_pred_lead{}_part2_base.npy'.format(filepath_vec, 5), allow_pickle=True)[()]

# %%
TRAIN_lead2 = np.concatenate((data_lead2_p0['y_vector'], data_lead2_p1['y_vector'], data_lead2_p2['y_vector']), axis=0)
TRAIN_lead3 = np.concatenate((data_lead3_p0['y_vector'], data_lead3_p1['y_vector'], data_lead3_p2['y_vector']), axis=0)
TRAIN_lead4 = np.concatenate((data_lead4_p0['y_vector'], data_lead4_p1['y_vector'], data_lead4_p2['y_vector']), axis=0)
TRAIN_lead5 = np.concatenate((data_lead5_p0['y_vector'], data_lead5_p1['y_vector'], data_lead5_p2['y_vector']), axis=0)

# %%
TRAIN_lead2_y = np.concatenate((data_lead2_p0['y_true'], data_lead2_p1['y_true'], data_lead2_p2['y_true']), axis=0)
TRAIN_lead3_y = np.concatenate((data_lead3_p0['y_true'], data_lead3_p1['y_true'], data_lead3_p2['y_true']), axis=0)
TRAIN_lead4_y = np.concatenate((data_lead4_p0['y_true'], data_lead4_p1['y_true'], data_lead4_p2['y_true']), axis=0)
TRAIN_lead5_y = np.concatenate((data_lead5_p0['y_true'], data_lead5_p1['y_true'], data_lead5_p2['y_true']), axis=0)

# %%
TRAIN_X = np.concatenate((TRAIN_lead2, TRAIN_lead3, TRAIN_lead4, TRAIN_lead5), axis=0)
TRAIN_Y = np.concatenate((TRAIN_lead2_y, TRAIN_lead3_y, TRAIN_lead4_y, TRAIN_lead5_y), axis=0)

# %%
TRAIN_256_pos = TRAIN_X[TRAIN_Y==1, :]
TRAIN_256_neg = TRAIN_X[TRAIN_Y==0, :]

# %% [markdown]
# **Valid**

# %%
filename_valid_lead2 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/VALID*lead2.npy"))
filename_valid_lead3 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/VALID*lead3.npy"))
filename_valid_lead4 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/VALID*lead4.npy"))
filename_valid_lead5 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/VALID*lead5.npy"))

# %%
valid_lead2 = np.load('{}TEST_pp15_pred_lead2_base.npy'.format(filepath_vec), allow_pickle=True)[()]
valid_lead3 = np.load('{}TEST_pp15_pred_lead3_base.npy'.format(filepath_vec), allow_pickle=True)[()]
valid_lead4 = np.load('{}TEST_pp15_pred_lead4_base.npy'.format(filepath_vec), allow_pickle=True)[()]
valid_lead5 = np.load('{}TEST_pp15_pred_lead5_base.npy'.format(filepath_vec), allow_pickle=True)[()]

VALID_lead2 = valid_lead2['y_vector']
VALID_lead3 = valid_lead3['y_vector']
VALID_lead4 = valid_lead4['y_vector']
VALID_lead5 = valid_lead5['y_vector']

VALID_lead2_y = valid_lead2['y_true']
VALID_lead3_y = valid_lead3['y_true']
VALID_lead4_y = valid_lead4['y_true']
VALID_lead5_y = valid_lead5['y_true']

# %%
IND_VALID_lead = np.load('/glade/work/ksha/NCAR/IND_VALID_lead.npy', allow_pickle=True)[()]
VALID_ind2 = IND_VALID_lead['lead2']
VALID_ind3 = IND_VALID_lead['lead3']
VALID_ind4 = IND_VALID_lead['lead4']
VALID_ind5 = IND_VALID_lead['lead5']

# %%
VALID_X = np.concatenate((VALID_lead2, VALID_lead3, VALID_lead4, VALID_lead5), axis=0)
VALID_Y = np.concatenate((VALID_lead2_y, VALID_lead3_y, VALID_lead4_y, VALID_lead5_y), axis=0)

# %%
training_rounds = 30
seeds = [12342, 2536234, 98765, 473, 865, 7456, 69472, 3456357, 3425, 678,
         2452624, 5787, 235362, 67896, 98454, 12445, 46767, 78906, 345, 8695, 
         2463725, 4734, 23234, 884, 2341, 362, 5, 234, 483, 785356, 23425]

# %%
ref = np.sum(VALID_Y) / len(VALID_Y)

# =========== Model Section ========== #

batch_dir = '/glade/scratch/ksha/DATA/NCAR_batch/'
temp_dir = '/glade/work/ksha/NCAR/Keras_models/'

key = 'STN_Lead{}'.format(lead)

model_name = '{}'.format(key)
model_path = temp_dir+model_name

tol = 0

# ========== Training loop ========== #
L_pos = len(TRAIN_256_pos)
L_neg = len(TRAIN_256_neg)

record = 1.1
print("Initial record: {}".format(record))

min_del = 0
max_tol = 15 # early stopping with patience

epochs = 500
batch_size = 64
L_train = 16 #int(len(TRAIN_Y_pick) / batch_size)

for r in range(training_rounds):
    if r == 0:
        tol = 0
    else:
        tol = -200

    model = create_model()
    #
    model.compile(loss=keras.losses.BinaryCrossentropy(from_logits=False),
                  optimizer=keras.optimizers.Adam(lr=1e-4))
    
    # W_old = k_utils.dummy_loader('/glade/work/ksha/NCAR/Keras_models/BASE_Lead2/')
    # model.set_weights(W_old)
    
    set_seeds(int(seeds[r]))
    print('Training round {}'.format(r))

    for i in range(epochs):
        # if i > 0:
        #     backend.set_value(model.optimizer.learning_rate, decayed_learning_rate(i))
            
        start_time = time.time()

        # loop of batch
        for j in range(L_train):
            N_pos = 32
            N_neg = batch_size - N_pos

            ind_neg = du.shuffle_ind(L_neg)
            ind_pos = du.shuffle_ind(L_pos)

            ind_neg_pick = ind_neg[:N_neg]
            ind_pos_pick = ind_pos[:N_pos]

            X_batch_neg = TRAIN_256_neg[ind_neg_pick, :]
            X_batch_pos = TRAIN_256_pos[ind_pos_pick, :]
            X_batch = np.concatenate((X_batch_neg, X_batch_pos), axis=0)

            Y_batch = np.ones([batch_size,])
            Y_batch[:N_neg] = 0.0

            ind_ = du.shuffle_ind(batch_size)

            X_batch = X_batch[ind_, :]
            Y_batch = Y_batch[ind_]

            # train on batch
            model.train_on_batch(X_batch, Y_batch);

        # epoch end operations
        Y_pred = model.predict([VALID_X])

        Y_pred[Y_pred<0] = 0
        Y_pred[Y_pred>1] = 1

        record_temp = verif_metric(VALID_Y, Y_pred, ref)

        # if i % 10 == 0:
        #     model.save(model_path_backup)

        if (record - record_temp > min_del):
            print('Validation loss improved from {} to {}'.format(record, record_temp))
            record = record_temp
            tol = 0
            
            #print('tol: {}'.format(tol))
            # save
            print('save to: {}'.format(model_path))
            model.save(model_path)
        else:
            print('Validation loss {} NOT improved'.format(record_temp))
            if record_temp > 1.0:
                print('Early stopping')
                break;
            else:
                tol += 1
                if tol >= max_tol:
                    print('Early stopping')
                    break;
                else:
                    continue;
        print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Initial record: 1.1
# Training round 0
# Validation loss improved from 1.1 to 0.9997043158606339
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 19.876680612564087 seconds ---
# Validation loss improved from 0.9997043158606339 to 0.9996820541642476
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.770101308822632 seconds ---
# Validation loss improved from 0.9996820541642476 to 0.9996557828189909
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 19.23515748977661 seconds ---
# Validation loss 0.9996605960305971 NOT improved
# Validation loss improved from 0.9996557828189909 to 0.999621864958134
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 19.036137342453003 seconds ---
# Validation loss improved from 0.999621864958134 to 0.9995912302837053
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.94419836997986 seconds ---
# Validation loss improved from 0.9995912302837053 to 0.999588943280071
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.59885859489441 seconds ---
# Validation loss improved from 0.999588943280071 to 0.9995371630330195
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.83968162536621 seconds ---
# Validation loss improved from 0.9995371630330195 to 0.9994621705218696
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.52493977546692 seconds ---
# Validation loss 0.9994646417906952 NOT improved
# Validation loss improved from 0.9994621705218696 to 0.9993652060119302
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.721973657608032 seconds ---
# Validation loss improved from 0.9993652060119302 to 0.9992945520483569
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 19.204519748687744 seconds ---
# Validation loss improved from 0.9992945520483569 to 0.9990076664989973
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.47456383705139 seconds ---
# Validation loss improved from 0.9990076664989973 to 0.9988314104304528
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.92045259475708 seconds ---
# Validation loss improved from 0.9988314104304528 to 0.9985224152695531
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.631508350372314 seconds ---
# Validation loss improved from 0.9985224152695531 to 0.998329276992969
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 19.23616051673889 seconds ---
# Validation loss 0.9984151788551465 NOT improved
# Validation loss improved from 0.998329276992969 to 0.9978581038012582
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 19.255485773086548 seconds ---
# Validation loss improved from 0.9978581038012582 to 0.9975694703067233
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.80557870864868 seconds ---
# Validation loss improved from 0.9975694703067233 to 0.9965545392963759
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 19.044800519943237 seconds ---
# Validation loss improved from 0.9965545392963759 to 0.9963781008763319
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.482494354248047 seconds ---
# Validation loss improved from 0.9963781008763319 to 0.9943543448248678
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.94478440284729 seconds ---
# Validation loss improved from 0.9943543448248678 to 0.9800041481632767
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.896007299423218 seconds ---
# Validation loss 0.9924625371120048 NOT improved
# Validation loss 0.9915016184869497 NOT improved
# Validation loss 0.981446456038836 NOT improved
# Validation loss 0.9895949979765765 NOT improved
# Validation loss improved from 0.9800041481632767 to 0.9761949530059363
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.684627056121826 seconds ---
# Validation loss 0.986877073623118 NOT improved
# Validation loss improved from 0.9761949530059363 to 0.969676519406663
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 19.162624835968018 seconds ---
# Validation loss 0.9839704238732649 NOT improved
# Validation loss 0.9770750862776529 NOT improved
# Validation loss improved from 0.969676519406663 to 0.9301660277216921
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.781594038009644 seconds ---
# Validation loss 0.9662578378487892 NOT improved
# Validation loss 0.9450261880360392 NOT improved
# Validation loss 0.9561530294365507 NOT improved
# Validation loss 0.9614077130440153 NOT improved
# Validation loss 0.9364304751815928 NOT improved
# Validation loss 0.9444446119715995 NOT improved
# Validation loss 0.9379393095282739 NOT improved
# Validation loss 0.9404951116487833 NOT improved
# Validation loss 0.9325154759559401 NOT improved
# Validation loss 0.9395294186129625 NOT improved
# Validation loss 0.9647193276323741 NOT improved
# Validation loss improved from 0.9301660277216921 to 0.9110268891936782
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 19.665332317352295 seconds ---
# Validation loss 0.9220968957078814 NOT improved
# Validation loss 0.943797491076471 NOT improved
# Validation loss 0.9383264255144553 NOT improved
# Validation loss 0.9421978314897533 NOT improved
# Validation loss 0.9304745264316855 NOT improved
# Validation loss 0.9151440915849505 NOT improved
# Validation loss 0.9251026411407954 NOT improved
# Validation loss 0.9739874250277625 NOT improved
# Validation loss 0.9475689013240888 NOT improved
# Validation loss 0.959447059625056 NOT improved
# Validation loss 1.139302327805241 NOT improved
# Early stopping
# Training round 1
# Validation loss 0.9997103566059178 NOT improved
# Validation loss 0.9997010882069549 NOT improved
# Validation loss 0.9996920485850259 NOT improved
# Validation loss 0.9996810182099892 NOT improved
# Validation loss 0.9996602591500553 NOT improved
# Validation loss 0.9996001477319049 NOT improved
# Validation loss 0.9995309661636628 NOT improved
# Validation loss 0.9994916731194426 NOT improved
# Validation loss 0.9994754719669275 NOT improved
# Validation loss 0.9993971415786533 NOT improved
# Validation loss 0.9992905512937217 NOT improved
# Validation loss 0.9991764749864713 NOT improved
# Validation loss 0.9990254310087755 NOT improved
# Validation loss 0.9988494301737675 NOT improved
# Validation loss 0.9983883597991219 NOT improved
# Validation loss 0.9977914985577576 NOT improved
# Validation loss 0.9969685258400794 NOT improved
# Validation loss 0.9974925977918401 NOT improved
# Validation loss 0.9957237311581599 NOT improved
# Validation loss 0.9950740675628585 NOT improved
# Validation loss 0.9935636867381431 NOT improved
# Validation loss 0.9938141312613914 NOT improved
# Validation loss 0.9910959927754437 NOT improved
# Validation loss 0.9907931918636649 NOT improved
# Validation loss 0.9926747210403811 NOT improved
# Validation loss 0.9882442621200029 NOT improved
# Validation loss 0.9817631587853121 NOT improved
# Validation loss 0.9739342195757089 NOT improved
# Validation loss 0.9877994659171175 NOT improved
# Validation loss 0.9462273675112115 NOT improved
# Validation loss 0.9492138306060748 NOT improved
# Validation loss 0.951537032162984 NOT improved
# Validation loss 0.9626035247485661 NOT improved
# Validation loss 0.9710303540906859 NOT improved
# Validation loss 0.9440711113517164 NOT improved
# Validation loss 0.929686321856884 NOT improved
# Validation loss 0.9501940650013844 NOT improved
# Validation loss 0.9346262687014457 NOT improved
# Validation loss 0.9445202601029075 NOT improved
# Validation loss 0.9402480861505788 NOT improved
# Validation loss improved from 0.9110268891936782 to 0.8992688207110302
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.88562250137329 seconds ---
# Validation loss 0.9238404235822291 NOT improved
# Validation loss 0.9527683742428639 NOT improved
# Validation loss 0.9396472717691036 NOT improved
# Validation loss 0.9413504678016479 NOT improved
# Validation loss 0.9250427307244129 NOT improved
# Validation loss 0.9108647155027277 NOT improved
# Validation loss 0.9491586624790684 NOT improved
# Validation loss 0.9291999416616652 NOT improved
# Validation loss 0.961176974580362 NOT improved
# Validation loss 0.9210997130973698 NOT improved
# Validation loss 0.9604880562723822 NOT improved
# Validation loss 0.9820953355386103 NOT improved
# Validation loss 0.9475846946203029 NOT improved
# Validation loss 1.0119267689236628 NOT improved
# Early stopping
# Training round 2
# Validation loss 0.999735289266961 NOT improved
# Validation loss 0.999649088415175 NOT improved
# Validation loss 0.9996249045151531 NOT improved
# Validation loss 0.9996070670286761 NOT improved
# Validation loss 0.9996079268057103 NOT improved
# Validation loss 0.999563272889442 NOT improved
# Validation loss 0.9995654683805681 NOT improved
# Validation loss 0.9994908782911633 NOT improved
# Validation loss 0.9994374193759409 NOT improved
# Validation loss 0.9993764185051965 NOT improved
# Validation loss 0.9992242122606175 NOT improved
# Validation loss 0.9990928898570025 NOT improved
# Validation loss 0.9990472652462645 NOT improved
# Validation loss 0.9986831605472375 NOT improved
# Validation loss 0.9984884558851744 NOT improved
# Validation loss 0.9980051952948985 NOT improved
# Validation loss 0.9968207727641178 NOT improved
# Validation loss 0.9976375645575118 NOT improved
# Validation loss 0.9953321579615517 NOT improved
# Validation loss 0.99582224327681 NOT improved
# Validation loss 0.9926036379414697 NOT improved
# Validation loss 0.9913911918947734 NOT improved
# Validation loss 0.994533230458013 NOT improved
# Validation loss 0.9883701688791956 NOT improved
# Validation loss 0.989208808732988 NOT improved
# Validation loss 0.9817731666620902 NOT improved
# Validation loss 0.9817919215464571 NOT improved
# Validation loss 0.9861661330125587 NOT improved
# Validation loss 0.9718579416847155 NOT improved
# Validation loss 0.9706054686894072 NOT improved
# Validation loss 0.947164237714584 NOT improved
# Validation loss 0.9458169214568498 NOT improved
# Validation loss 0.9438047943891449 NOT improved
# Validation loss 0.9445482825079428 NOT improved
# Validation loss 0.941522285527951 NOT improved
# Validation loss 0.9412091629954438 NOT improved
# Validation loss 0.9032732443131408 NOT improved
# Validation loss 0.940106806363505 NOT improved
# Validation loss 0.913478951934745 NOT improved
# Validation loss 0.9223617333283974 NOT improved
# Validation loss 0.9220084010106059 NOT improved
# Validation loss 0.9104481334329133 NOT improved
# Validation loss 0.9213465591199352 NOT improved
# Validation loss improved from 0.8992688207110302 to 0.8929407747262915
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 19.313074827194214 seconds ---
# Validation loss 0.9958655657844709 NOT improved
# Validation loss 0.9057986658479409 NOT improved
# Validation loss 0.9077254795636559 NOT improved
# Validation loss 0.9325259468052789 NOT improved
# Validation loss improved from 0.8929407747262915 to 0.8804644756499129
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 18.960506439208984 seconds ---
# Validation loss 1.0148452977638263 NOT improved
# Early stopping
# Training round 3
# Validation loss 0.9995061794956092 NOT improved
# Validation loss 0.9995697999521957 NOT improved
# Validation loss 0.9996441040561236 NOT improved
# Validation loss 0.9996604651396023 NOT improved
# Validation loss 0.9996389092874144 NOT improved
# Validation loss 0.99963483615977 NOT improved
# Validation loss 0.9995891840127791 NOT improved
# Validation loss 0.9995077356958016 NOT improved
# Validation loss 0.9994416196755179 NOT improved
# Validation loss 0.9993463809396461 NOT improved
# Validation loss 0.9992143807697165 NOT improved
# Validation loss 0.9989231792258645 NOT improved
# Validation loss 0.9986702813267212 NOT improved
# Validation loss 0.9989066648212405 NOT improved
# Validation loss 0.9985635995023502 NOT improved
# Validation loss 0.9983806090942037 NOT improved
# Validation loss 0.9966724178995828 NOT improved
# Validation loss 0.9978417878014783 NOT improved
# Validation loss 0.9959958900486054 NOT improved
# Validation loss 0.9942436302978361 NOT improved
# Validation loss 0.9924282845754219 NOT improved
# Validation loss 0.9884421654685476 NOT improved
# Validation loss 0.9842374021139207 NOT improved
# Validation loss 0.976525588026114 NOT improved
# Validation loss 0.9771368441720337 NOT improved
# Validation loss 0.9794511652068735 NOT improved
# Validation loss 0.9797928965927579 NOT improved
# Validation loss 0.9668974898646052 NOT improved
# Validation loss 0.9780053992333338 NOT improved
# Validation loss 0.9500657985046679 NOT improved
# Validation loss 0.9641241105895924 NOT improved
# Validation loss 0.9650782493703157 NOT improved
# Validation loss 0.9346543491380551 NOT improved
# Validation loss 0.9222986192056057 NOT improved
# Validation loss 0.9471968149724219 NOT improved
# Validation loss 0.9571313082074558 NOT improved
# Validation loss 0.9134138425304623 NOT improved
# Validation loss 0.9398229379978946 NOT improved
# Validation loss 0.9167326102417006 NOT improved
# Validation loss 0.9665974355580833 NOT improved
# Validation loss 0.9150284766802687 NOT improved
# Validation loss 0.9177893777453215 NOT improved
# Validation loss 0.9140605063765191 NOT improved
# Validation loss 0.9254894747550024 NOT improved
# Validation loss 0.9052035412658695 NOT improved
# Validation loss 0.913063969868523 NOT improved
# Validation loss 0.939790452347201 NOT improved
# Validation loss 0.9027158288263106 NOT improved
# Validation loss 1.0649442274793188 NOT improved
# Early stopping
# Training round 4
# Validation loss 0.9996042171416595 NOT improved
# Validation loss 0.9996348227409663 NOT improved
# Validation loss 0.9996674909143993 NOT improved
# Validation loss 0.9996636679350935 NOT improved
# Validation loss 0.999659841077007 NOT improved
# Validation loss 0.9996329554288388 NOT improved
# Validation loss 0.999610532126151 NOT improved
# Validation loss 0.9995482342481964 NOT improved
# Validation loss 0.9994980839317497 NOT improved
# Validation loss 0.9993522074182666 NOT improved
# Validation loss 0.9993372973076515 NOT improved
# Validation loss 0.999172327208978 NOT improved
# Validation loss 0.9989604043472515 NOT improved
# Validation loss 0.9981096058968933 NOT improved
# Validation loss 0.9986467643585367 NOT improved
# Validation loss 0.9980381394310006 NOT improved
# Validation loss 0.9976578610245628 NOT improved
# Validation loss 0.9971288361320328 NOT improved
# Validation loss 0.9961037474037552 NOT improved
# Validation loss 0.9953920143900585 NOT improved
# Validation loss 0.9948160072493596 NOT improved
# Validation loss 0.9885309213420586 NOT improved
# Validation loss 0.988900643744242 NOT improved
# Validation loss 0.9866989485265433 NOT improved
# Validation loss 0.9758690405380508 NOT improved
# Validation loss 0.9786893620966661 NOT improved
# Validation loss 0.9578337595269393 NOT improved
# Validation loss 0.9728257277749651 NOT improved
# Validation loss 0.9830355204617974 NOT improved
# Validation loss 0.9240070127710871 NOT improved
# Validation loss 0.9430997191598948 NOT improved
# Validation loss 0.9212413953688843 NOT improved
# Validation loss 0.948392600469993 NOT improved
# Validation loss 0.9248104857780067 NOT improved
# Validation loss 0.9721284290451979 NOT improved
# Validation loss 0.9307433094579833 NOT improved
# Validation loss improved from 0.8804644756499129 to 0.8641688041515825
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 19.284343242645264 seconds ---
# Validation loss 0.9414226577861389 NOT improved
# Validation loss 0.9157145940986902 NOT improved
# Validation loss 0.9222605586399172 NOT improved
# Validation loss 0.9215651741463158 NOT improved
# Validation loss 0.9403183645540442 NOT improved
# Validation loss 0.9215291915529458 NOT improved
# Validation loss 0.9199296155857682 NOT improved
# Validation loss 0.9349943211632323 NOT improved
# Validation loss 0.9995749589854909 NOT improved
# Validation loss 1.0376791079908392 NOT improved
# Early stopping
# Training round 5
# Validation loss 0.9995688983274503 NOT improved
# Validation loss 0.9996392105585956 NOT improved
# Validation loss 0.9995756692461539 NOT improved
# Validation loss 0.9995135667129629 NOT improved
# Validation loss 0.9994768613181421 NOT improved
# Validation loss 0.9994654456865819 NOT improved
# Validation loss 0.9993264428872831 NOT improved
# Validation loss 0.99933215670658 NOT improved
# Validation loss 0.9990577154699702 NOT improved
# Validation loss 0.9989352083032509 NOT improved
# Validation loss 0.9986061234401897 NOT improved
# Validation loss 0.9985460792536527 NOT improved
# Validation loss 0.9977202125315489 NOT improved
# Validation loss 0.9969591426529885 NOT improved
# Validation loss 0.9968793379653325 NOT improved
# Validation loss 0.9955147170455916 NOT improved
# Validation loss 0.9925220466833323 NOT improved
# Validation loss 0.9924297418102662 NOT improved
# Validation loss 0.988311530642196 NOT improved
# Validation loss 0.9852248625136443 NOT improved
# Validation loss 0.9831502218058978 NOT improved
# Validation loss 0.9753297123563407 NOT improved
# Validation loss 0.9791191660529541 NOT improved
# Validation loss 0.9780789130327998 NOT improved
# Validation loss 0.9626484401469064 NOT improved
# Validation loss 0.9715210147535465 NOT improved
# Validation loss 0.9751688024548881 NOT improved
# Validation loss 0.9137257271267221 NOT improved
# Validation loss 0.9233622886314958 NOT improved
# Validation loss 0.9493698987812602 NOT improved
# Validation loss 0.9171513788215325 NOT improved
# Validation loss 0.9290988814346737 NOT improved
# Validation loss 0.9324682739404765 NOT improved
# Validation loss 0.9217247934344767 NOT improved
# Validation loss 0.9505128131237954 NOT improved
# Validation loss 0.9474558765389348 NOT improved
# Validation loss 0.9047463689075834 NOT improved
# Validation loss 0.939148703203046 NOT improved
# Validation loss 0.9903722676364499 NOT improved
# Validation loss 0.9257089939609746 NOT improved
# Validation loss 0.9717139147208163 NOT improved
# Validation loss 0.9248485820367344 NOT improved
# Validation loss 0.9236089061700834 NOT improved
# Validation loss 0.931619648890194 NOT improved
# Validation loss 0.9649524755134313 NOT improved
# Validation loss 0.915444352473449 NOT improved
# Validation loss 0.941462650016911 NOT improved
# Validation loss 0.9440850731636159 NOT improved
# Validation loss 1.0107083823256082 NOT improved
# Early stopping
# Training round 6
# Validation loss 0.9992314195746076 NOT improved
# Validation loss 0.9993812804125748 NOT improved
# Validation loss 0.9994977134977989 NOT improved
# Validation loss 0.9995750599923264 NOT improved
# Validation loss 0.9996036210118141 NOT improved
# Validation loss 0.9996020185558437 NOT improved
# Validation loss 0.9995682188882611 NOT improved
# Validation loss 0.9994958320172381 NOT improved
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 79
#      76     model.train_on_batch(X_batch, Y_batch);
#      78 # epoch end operations
# ---> 79 Y_pred = model.predict([VALID_X])
#      81 Y_pred[Y_pred<0] = 0
#      82 Y_pred[Y_pred>1] = 1
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1629, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627 for step in data_handler.steps():
#    1628   callbacks.on_predict_batch_begin(step)
# -> 1629   tmp_batch_outputs = self.predict_function(iterator)
#    1630   if data_handler.should_sync:
#    1631     context.async_wait()
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:828, in Function.__call__(self, *args, **kwds)
#     826 tracing_count = self.experimental_get_tracing_count()
#     827 with trace.Trace(self._name) as tm:
# --> 828   result = self._call(*args, **kwds)
#     829   compiler = "xla" if self._experimental_compile else "nonXla"
#     830   new_tracing_count = self.experimental_get_tracing_count()
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:862, in Function._call(self, *args, **kwds)
#     859 self._lock.release()
#     860 # In this case we have not created variables on the first call. So we can
#     861 # run the first trace but we should fail if variables are created.
# --> 862 results = self._stateful_fn(*args, **kwds)
#     863 if self._created_variables:
#     864   raise ValueError("Creating variables on a non-first call to a function"
#     865                    " decorated with tf.function.")
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2942, in Function.__call__(self, *args, **kwargs)
#    2939 with self._lock:
#    2940   (graph_function,
#    2941    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942 return graph_function._call_flat(
#    2943     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1918, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1914 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1915 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1916     and executing_eagerly):
#    1917   # No tape is watching; skip to running the function.
# -> 1918   return self._build_call_outputs(self._inference_function.call(
#    1919       ctx, args, cancellation_manager=cancellation_manager))
#    1920 forward_backward = self._select_forward_and_backward_functions(
#    1921     args,
#    1922     possible_gradient_type,
#    1923     executing_eagerly)
#    1924 forward_function, args_with_tangents = forward_backward.forward()
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py:555, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     553 with _InterpolateFunctionError(self):
#     554   if cancellation_manager is None:
# --> 555     outputs = execute.execute(
#     556         str(self.signature.name),
#     557         num_outputs=self._num_outputs,
#     558         inputs=args,
#     559         attrs=attrs,
#     560         ctx=ctx)
#     561   else:
#     562     outputs = execute.execute_with_cancellation(
#     563         str(self.signature.name),
#     564         num_outputs=self._num_outputs,
#    (...)
#     567         ctx=ctx,
#     568         cancellation_manager=cancellation_manager)
#
# File /glade/work/ksha/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57 try:
#      58   ctx.ensure_initialized()
# ---> 59   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                       inputs, attrs, num_outputs)
#      61 except core._NotOkStatusException as e:
#      62   if name is not None:
#
# KeyboardInterrupt:

# %%
model = create_model()

model.compile(loss=keras.losses.BinaryCrossentropy(from_logits=False),
              optimizer=keras.optimizers.Adam(lr=0))

W_old = k_utils.dummy_loader('/glade/work/ksha/NCAR/Keras_models/BASE_Lead2/')
model.set_weights(W_old)

# %%
#VALID_Lead2_tune3

# %%
# ref = np.sum(TEST_Y[:405032]) / len(TEST_Y[:405032])
# Y_pred = model.predict([TEST_merge, TEST_256])
# record_temp = verif_metric(TEST_Y[:405032], Y_pred[:405032], ref)

# %%
ref = np.sum(VALID_Y) / len(VALID_Y)
Y_pred = model.predict([VALID_X, VALID_merge])
record_temp = verif_metric(VALID_Y, Y_pred, ref)

# %%
record_temp
# Out:
# 0.8514755852660806

# %%
save_dict = {}
save_dict['Y_pred'] = Y_pred
save_dict['VALID_Y'] = VALID_Y
np.save('{}RESULT_BASE_lead{}_base.npy'.format(filepath_vec, lead), save_dict)
print('{}RESULT_BASE_lead{}_base.npy'.format(filepath_vec, lead))
# Out:
# /glade/work/ksha/NCAR/RESULT_BASE_lead2_base.npy
