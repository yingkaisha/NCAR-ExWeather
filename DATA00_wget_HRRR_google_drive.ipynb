# %%
from datetime import datetime, timedelta

# %%
base = datetime(2018, 1, 1)
date_list = [base + timedelta(days=day) for day in range(365*4+180)]

# %%
for dt in date_list:
    dt_str = datetime.strftime(dt, '%Y%m%d')
    print('wget https://storage.googleapis.com/high-resolution-rapid-refresh/hrrr.{}/conus/hrrr.t00z.wrfnatf17.grib2 -O HRRR.{}.natf17.grib2'.format(dt_str, dt_str))
# Out:
# wget https://storage.googleapis.com/high-resolution-rapid-refresh/hrrr.20180101/conus/hrrr.t00z.wrfnatf17.grib2 -O HRRR.20180101.natf17.grib2
# wget https://storage.googleapis.com/high-resolution-rapid-refresh/hrrr.20180102/conus/hrrr.t00z.wrfnatf17.grib2 -O HRRR.20180102.natf17.grib2
# wget https://storage.googleapis.com/high-resolution-rapid-refresh/hrrr.20180103/conus/hrrr.t00z.wrfnatf17.grib2 -O HRRR.20180103.natf17.grib2
# wget https://storage.googleapis.com/high-resolution-rapid-refresh/hrrr.20180104/conus/hrrr.t00z.wrfnatf17.grib2 -O HRRR.20180104.natf17.grib2
# wget https://storage.googleapis.com/high-resolution-rapid-refresh/hrrr.20180105/conus/hrrr.t00z.wrfnatf17.grib2 -O HRRR.20180105.natf17.grib2
# wget https://storage.googleapis.com/high-resolution-rapid-refresh/hrrr.20180106/conus/hrrr.t00z.wrfnatf17.grib2 -O HRRR.20180106.natf17.grib2
# ...
