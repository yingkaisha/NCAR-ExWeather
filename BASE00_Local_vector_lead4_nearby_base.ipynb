# %%
# general tools
import os
import sys
import time
import h5py
import random
from glob import glob

import numpy as np
from datetime import datetime, timedelta
from random import shuffle

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend
from keras_unet_collection import utils as k_utils
# Out:
# 2022-12-27 12:31:37.759361: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
sys.path.insert(0, '/glade/u/home/ksha/NCAR/')
sys.path.insert(0, '/glade/u/home/ksha/NCAR/libs/')

from namelist import *
import data_utils as du

# %%
import re

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def pos_mixer(TRAIN, L, a0=0, a1=0.2):
    data_shape = TRAIN.shape
    out = np.empty((L, data_shape[-1]))
    
    for i in range(L):
        inds = np.random.choice(data_shape[0], 2)
        a = np.random.uniform(a0, a1)
        out[i, :] = a*TRAIN[inds[0], :] + (1-a)*TRAIN[inds[1], :]
    return out

# %%
def set_seeds(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)

# %%
def verif_metric(VALID_target, Y_pred, ref):


    # fpr, tpr, thresholds = roc_curve(VALID_target.ravel(), Y_pred.ravel())
    # AUC = auc(fpr, tpr)
    # AUC_metric = 1 - AUC
    
    BS = np.mean((VALID_target.ravel() - Y_pred.ravel())**2)
    #ll = log_loss(VALID_target.ravel(), Y_pred.ravel())
    
    #print('{}'.format(BS))
    metric = BS

    return metric / ref

# %%
def set_seeds(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)

# %%
def feature_extract(filenames, lon_80km, lon_minmax, lat_80km, lat_minmax, elev_80km, elev_max):
    
    lon_out = []
    lat_out = []
    elev_out = []
    mon_out = []
    
    base_v3_s = datetime(2018, 7, 15)
    base_v3_e = datetime(2020, 12, 2)

    base_v4_s = datetime(2020, 12, 3)
    base_v4_e = datetime(2022, 7, 15)

    base_ref = datetime(2010, 1, 1)
    
    date_list_v3 = [base_v3_s + timedelta(days=day) for day in range(365+365+142)]
    date_list_v4 = [base_v4_s + timedelta(days=day) for day in range(365+180-151)]
    
    for i, name in enumerate(filenames):
        
        if 'v4' in name:
            date_list = date_list_v4
        else:
            date_list = date_list_v3
        
        nums = re.findall(r'\d+', name)
        indy = int(nums[-2])
        indx = int(nums[-3])
        day = int(nums[-4])
        day = date_list[day]
        month = day.month
        
        month_norm = (month - 1)/(12-1)
        
        lon = lon_80km[indx, indy]
        lat = lat_80km[indx, indy]

        lon = (lon - lon_minmax[0])/(lon_minmax[1] - lon_minmax[0])
        lat = (lat - lat_minmax[0])/(lat_minmax[1] - lat_minmax[0])

        elev = elev_80km[indx, indy]
        elev = elev / elev_max
        
        lon_out.append(lon)
        lat_out.append(lat)
        elev_out.append(elev)
        mon_out.append(month_norm)
        
    return np.array(lon_out), np.array(lat_out), np.array(elev_out), np.array(mon_out)

def create_model():

    
    IN_vec = keras.Input((123,))    
    X = IN_vec
    #
    X = keras.layers.Dense(1024, activity_regularizer=keras.regularizers.L2(1e-2))(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.Activation("gelu")(X)
    #X = keras.layers.Activation("relu")(X)

    X = keras.layers.Dropout(0.4)(X)
    
    #
    X = keras.layers.Dense(512, activity_regularizer=keras.regularizers.L2(1e-2))(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.Activation("gelu")(X)
    #X = keras.layers.Activation("relu")(X)
    
    X = keras.layers.Dropout(0.4)(X)
    
    X = keras.layers.Dense(128, activity_regularizer=keras.regularizers.L2(1e-2))(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.Activation("gelu")(X)
    #X = keras.layers.Activation("relu")(X)
    
    OUT = X
    OUT = keras.layers.Dense(1, activation='sigmoid', bias_initializer=keras.initializers.Constant(-10))(OUT)

    model = keras.models.Model(inputs=IN_vec, outputs=OUT)
    
    return model

# %%
with h5py.File(save_dir+'HRRR_domain.hdf', 'r') as h5io:
    lon_3km = h5io['lon_3km'][...]
    lat_3km = h5io['lat_3km'][...]
    lon_80km = h5io['lon_80km'][...]
    lat_80km = h5io['lat_80km'][...]
    elev_3km = h5io['elev_3km'][...]
    land_mask_80km = h5io['land_mask_80km'][...]
    
grid_shape = land_mask_80km.shape

# %%
elev_80km = du.interp2d_wraper(lon_3km, lat_3km, elev_3km, lon_80km, lat_80km, method='linear')

elev_80km[np.isnan(elev_80km)] = 0
elev_80km[elev_80km<0] = 0
elev_max = np.max(elev_80km)

lon_80km_mask = lon_80km[land_mask_80km]
lat_80km_mask = lat_80km[land_mask_80km]

lon_minmax = [np.min(lon_80km_mask), np.max(lon_80km_mask)]
lat_minmax = [np.min(lat_80km_mask), np.max(lat_80km_mask)]

# %%
lead = 4

# %%
filename_train_lead2 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/TRAIN*lead2.npy"))
filename_train_lead3 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/TRAIN*lead3.npy"))
filename_train_lead4 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/TRAIN*lead4.npy"))
filename_train_lead5 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/TRAIN*lead5.npy"))

# %%
IND_TRAIN_lead = np.load('/glade/work/ksha/NCAR/IND_TRAIN_lead.npy', allow_pickle=True)[()]
TRAIN_ind2 = IND_TRAIN_lead['lead2']
TRAIN_ind3 = IND_TRAIN_lead['lead3']
TRAIN_ind4 = IND_TRAIN_lead['lead4']
TRAIN_ind5 = IND_TRAIN_lead['lead5']

# %%
filepath_vec = "/glade/work/ksha/NCAR/"

# %%
data_lead2_p0 = np.load('{}TRAIN_pp15_pred_lead{}_part0_base.npy'.format(filepath_vec, 2), allow_pickle=True)[()]
data_lead2_p1 = np.load('{}TRAIN_pp15_pred_lead{}_part1_base.npy'.format(filepath_vec, 2), allow_pickle=True)[()]
data_lead2_p2 = np.load('{}TRAIN_pp15_pred_lead{}_part2_base.npy'.format(filepath_vec, 2), allow_pickle=True)[()]

data_lead3_p0 = np.load('{}TRAIN_pp15_pred_lead{}_part0_base.npy'.format(filepath_vec, 3), allow_pickle=True)[()]
data_lead3_p1 = np.load('{}TRAIN_pp15_pred_lead{}_part1_base.npy'.format(filepath_vec, 3), allow_pickle=True)[()]
data_lead3_p2 = np.load('{}TRAIN_pp15_pred_lead{}_part2_base.npy'.format(filepath_vec, 3), allow_pickle=True)[()]

data_lead4_p0 = np.load('{}TRAIN_pp15_pred_lead{}_part0_base.npy'.format(filepath_vec, 4), allow_pickle=True)[()]
data_lead4_p1 = np.load('{}TRAIN_pp15_pred_lead{}_part1_base.npy'.format(filepath_vec, 4), allow_pickle=True)[()]
data_lead4_p2 = np.load('{}TRAIN_pp15_pred_lead{}_part2_base.npy'.format(filepath_vec, 4), allow_pickle=True)[()]

data_lead5_p0 = np.load('{}TRAIN_pp15_pred_lead{}_part0_base.npy'.format(filepath_vec, 5), allow_pickle=True)[()]
data_lead5_p1 = np.load('{}TRAIN_pp15_pred_lead{}_part1_base.npy'.format(filepath_vec, 5), allow_pickle=True)[()]
data_lead5_p2 = np.load('{}TRAIN_pp15_pred_lead{}_part2_base.npy'.format(filepath_vec, 5), allow_pickle=True)[()]

# %%
TRAIN_lead2 = np.concatenate((data_lead2_p0['y_vector'], data_lead2_p1['y_vector'], data_lead2_p2['y_vector']), axis=0)
TRAIN_lead3 = np.concatenate((data_lead3_p0['y_vector'], data_lead3_p1['y_vector'], data_lead3_p2['y_vector']), axis=0)
TRAIN_lead4 = np.concatenate((data_lead4_p0['y_vector'], data_lead4_p1['y_vector'], data_lead4_p2['y_vector']), axis=0)
TRAIN_lead5 = np.concatenate((data_lead5_p0['y_vector'], data_lead5_p1['y_vector'], data_lead5_p2['y_vector']), axis=0)

# %%
TRAIN_lead2_y = np.concatenate((data_lead2_p0['y_true'], data_lead2_p1['y_true'], data_lead2_p2['y_true']), axis=0)
TRAIN_lead3_y = np.concatenate((data_lead3_p0['y_true'], data_lead3_p1['y_true'], data_lead3_p2['y_true']), axis=0)
TRAIN_lead4_y = np.concatenate((data_lead4_p0['y_true'], data_lead4_p1['y_true'], data_lead4_p2['y_true']), axis=0)
TRAIN_lead5_y = np.concatenate((data_lead5_p0['y_true'], data_lead5_p1['y_true'], data_lead5_p2['y_true']), axis=0)

# %%
L = len(TRAIN_ind4)
filename_train2_pick = []
filename_train3_pick = []
filename_train4_pick = []
filename_train5_pick = []

TRAIN_X = np.empty((L, 512))
TRAIN_Y = np.empty(L)

for i in range(L):
    ind_lead2 = int(TRAIN_ind2[i])
    ind_lead3 = int(TRAIN_ind3[i])
    ind_lead4 = int(TRAIN_ind4[i])
    ind_lead5 = int(TRAIN_ind5[i])
    
    filename_train2_pick.append(filename_train_lead2[ind_lead2])
    filename_train3_pick.append(filename_train_lead3[ind_lead3])
    filename_train4_pick.append(filename_train_lead4[ind_lead4])
    filename_train5_pick.append(filename_train_lead5[ind_lead5])
    
    TRAIN_X[i, 0:128]   = TRAIN_lead2[ind_lead2, :]
    TRAIN_X[i, 128:256] = TRAIN_lead3[ind_lead3, :]
    TRAIN_X[i, 256:384] = TRAIN_lead4[ind_lead4, :]
    TRAIN_X[i, 384:512] = TRAIN_lead5[ind_lead5, :]
    
    TRAIN_Y[i] = TRAIN_lead4_y[ind_lead4]

# %%
lon_norm, lat_norm, elev_norm, mon_norm = feature_extract(
    filename_train4_pick, lon_80km, lon_minmax, lat_80km, lat_minmax, elev_80km, elev_max)

# %%
data_temp = np.load('/glade/work/ksha/NCAR/TRAIN_MINMAX_lead{}.npy'.format(2), allow_pickle=True)[()]
MEAN_lead2 = data_temp['MEAN']
MAX_lead2 = data_temp['MAX']

data_temp = np.load('/glade/work/ksha/NCAR/TRAIN_MINMAX_lead{}.npy'.format(3), allow_pickle=True)[()]
MEAN_lead3 = data_temp['MEAN']
MAX_lead3 = data_temp['MAX']

data_temp = np.load('/glade/work/ksha/NCAR/TRAIN_MINMAX_lead{}.npy'.format(4), allow_pickle=True)[()]
MEAN_lead4 = data_temp['MEAN']
MAX_lead4 = data_temp['MAX']

data_temp = np.load('/glade/work/ksha/NCAR/TRAIN_MINMAX_lead{}.npy'.format(5), allow_pickle=True)[()]
MEAN_lead5 = data_temp['MEAN']
MAX_lead5 = data_temp['MAX']

# %%
MAX_lead5.shape
# Out:
# (611660, 15)

# %%
TRAIN_Y.shape
# Out:
# (611660,)

# %%
TRAIN_stn = np.concatenate((lon_norm[:, None], lat_norm[:, None], elev_norm[:, None], 
                            MAX_lead2, MAX_lead3, MAX_lead4, MAX_lead5, 
                            MEAN_lead2, MEAN_lead3, MEAN_lead4, MEAN_lead5), axis=1)
TRAIN_merge = TRAIN_stn

# %%
TRAIN_256_pos = TRAIN_X[TRAIN_Y==1, :]
TRAIN_256_neg = TRAIN_X[TRAIN_Y==0, :]

# %%
TRAIN_stn_pos = TRAIN_merge[TRAIN_Y==1]
TRAIN_stn_neg = TRAIN_merge[TRAIN_Y==0]

# %%
TRAIN_stn_pos.shape
# Out:
# (1944, 123)

# %% [markdown]
# **Valid**

# %%
filename_valid_lead2 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/VALID*lead2.npy"))
filename_valid_lead3 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/VALID*lead3.npy"))
filename_valid_lead4 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/VALID*lead4.npy"))
filename_valid_lead5 = sorted(glob("/glade/scratch/ksha/DATA/NCAR_batch_v3/VALID*lead5.npy"))

# %%
valid_lead2 = np.load('{}TEST_pp15_pred_lead2_base.npy'.format(filepath_vec), allow_pickle=True)[()]
valid_lead3 = np.load('{}TEST_pp15_pred_lead3_base.npy'.format(filepath_vec), allow_pickle=True)[()]
valid_lead4 = np.load('{}TEST_pp15_pred_lead4_base.npy'.format(filepath_vec), allow_pickle=True)[()]
valid_lead5 = np.load('{}TEST_pp15_pred_lead5_base.npy'.format(filepath_vec), allow_pickle=True)[()]

VALID_lead2 = valid_lead2['y_vector']
VALID_lead3 = valid_lead3['y_vector']
VALID_lead4 = valid_lead4['y_vector']
VALID_lead5 = valid_lead5['y_vector']

VALID_lead2_y = valid_lead2['y_true']
VALID_lead3_y = valid_lead3['y_true']
VALID_lead4_y = valid_lead4['y_true']
VALID_lead5_y = valid_lead5['y_true']

# %%
data_p_valid = np.load('{}TEST_pp15_pred_lead{}_base.npy'.format(filepath_vec, lead), allow_pickle=True)[()]

VALID_256 = data_p_valid['y_vector']
VALID_pred = data_p_valid['y_pred']
VALID_Y = data_p_valid['y_true']

# %%
IND_VALID_lead = np.load('/glade/work/ksha/NCAR/IND_VALID_lead.npy', allow_pickle=True)[()]
VALID_ind2 = IND_VALID_lead['lead2']
VALID_ind3 = IND_VALID_lead['lead3']
VALID_ind4 = IND_VALID_lead['lead4']
VALID_ind5 = IND_VALID_lead['lead5']

# %%
L = len(VALID_ind3)
filename_valid2_pick = []
filename_valid3_pick = []
filename_valid4_pick = []
filename_valid5_pick = []

VALID_X = np.empty((L, 512))
VALID_Y = np.zeros(L)

for i in range(L):
    ind_lead2 = int(VALID_ind2[i])
    ind_lead3 = int(VALID_ind3[i])
    ind_lead4 = int(VALID_ind4[i])
    ind_lead5 = int(VALID_ind5[i])
    
    filename_valid2_pick.append(filename_valid_lead2[ind_lead2])
    filename_valid3_pick.append(filename_valid_lead3[ind_lead3])
    filename_valid4_pick.append(filename_valid_lead4[ind_lead4])
    filename_valid5_pick.append(filename_valid_lead5[ind_lead5])
    
    VALID_X[i, 0:128]   = VALID_lead2[ind_lead2, :]
    VALID_X[i, 128:256] = VALID_lead3[ind_lead3, :]
    VALID_X[i, 256:384] = VALID_lead4[ind_lead4, :]
    VALID_X[i, 384:512] = VALID_lead5[ind_lead5, :]
    
    if 'pos' in filename_valid_lead4[ind_lead4]:
        if VALID_lead4_y[ind_lead4] == 1.0:
            VALID_Y[i] = 1.0
        else:
            egwrshat

# %%
lon_norm, lat_norm, elev_norm, mon_norm = feature_extract(
    filename_valid4_pick, lon_80km, lon_minmax, lat_80km, lat_minmax, elev_80km, elev_max)

# %%
data_temp = np.load('/glade/work/ksha/NCAR/VALID_MINMAX_lead{}.npy'.format(2), allow_pickle=True)[()]
MEAN_lead2 = data_temp['MEAN']
MAX_lead2 = data_temp['MAX']

data_temp = np.load('/glade/work/ksha/NCAR/VALID_MINMAX_lead{}.npy'.format(3), allow_pickle=True)[()]
MEAN_lead3 = data_temp['MEAN']
MAX_lead3 = data_temp['MAX']

data_temp = np.load('/glade/work/ksha/NCAR/VALID_MINMAX_lead{}.npy'.format(4), allow_pickle=True)[()]
MEAN_lead4 = data_temp['MEAN']
MAX_lead4 = data_temp['MAX']

data_temp = np.load('/glade/work/ksha/NCAR/VALID_MINMAX_lead{}.npy'.format(5), allow_pickle=True)[()]
MEAN_lead5 = data_temp['MEAN']
MAX_lead5 = data_temp['MAX']

# %%
VALID_stn = np.concatenate((lon_norm[:, None], lat_norm[:, None], elev_norm[:, None], 
                            MAX_lead2, MAX_lead3, MAX_lead4, MAX_lead5, 
                            MEAN_lead2, MEAN_lead3, MEAN_lead4, MEAN_lead5), axis=1)
VALID_merge = VALID_stn

# %%
VALID_merge.shape
# Out:
# (278588, 123)

# %%
training_rounds = 20
seeds = [12342, 2536234, 98765, 473, 865, 7456, 69472, 3456357, 3425, 678,
         2452624, 5787, 235362, 67896, 98454, 12445, 46767, 78906, 345, 8695]

# %%
ref = np.sum(VALID_Y) / len(VALID_Y)

# =========== Model Section ========== #

batch_dir = '/glade/scratch/ksha/DATA/NCAR_batch/'
temp_dir = '/glade/work/ksha/NCAR/Keras_models/'

key = 'STN_Lead{}'.format(lead)

model_name = '{}'.format(key)
model_path = temp_dir+model_name

tol = 0

# ========== Training loop ========== #
L_pos = len(TRAIN_256_pos)
L_neg = len(TRAIN_256_neg)

record = 1.1 #0.8545884976606543 #0.860262977437387 #0.867447696352988 #1.1
print("Initial record: {}".format(record))

min_del = 0
max_tol = 100 # early stopping with patience

epochs = 500
batch_size = 64
L_train = 16 #int(len(TRAIN_Y_pick) / batch_size)

for r in range(training_rounds):
    if r == 0:
        tol = 0
    else:
        tol = -200

    model = create_model()
    #
    model.compile(loss=keras.losses.BinaryCrossentropy(from_logits=False),
                  optimizer=keras.optimizers.Adam(lr=1e-4))
    
    # W_old = k_utils.dummy_loader('/glade/work/ksha/NCAR/Keras_models/BASE_Lead2/')
    # model.set_weights(W_old)
    
    set_seeds(int(seeds[r]))
    print('Training round {}'.format(r))

    for i in range(epochs):
        # if i > 0:
        #     backend.set_value(model.optimizer.learning_rate, decayed_learning_rate(i))
            
        start_time = time.time()

        # loop of batch
        for j in range(L_train):
            N_pos = 32
            N_neg = batch_size - N_pos

            ind_neg = du.shuffle_ind(L_neg)
            ind_pos = du.shuffle_ind(L_pos)

            ind_neg_pick = ind_neg[:N_neg]
            ind_pos_pick = ind_pos[:N_pos]

            X_batch_neg = TRAIN_stn_neg[ind_neg_pick, :]
            X_batch_pos = TRAIN_stn_pos[ind_pos_pick, :]

            X_batch = np.concatenate((X_batch_neg, X_batch_pos), axis=0)

            Y_batch = np.ones([batch_size,])
            Y_batch[:N_neg] = 0.0

            ind_ = du.shuffle_ind(batch_size)

            X_batch = X_batch[ind_, :]
            Y_batch = Y_batch[ind_]

            # train on batch
            model.train_on_batch(X_batch, Y_batch);

        # epoch end operations
        Y_pred = model.predict(VALID_merge)

        Y_pred[Y_pred<0] = 0
        Y_pred[Y_pred>1] = 1

        record_temp = verif_metric(VALID_Y, Y_pred, ref)

        # if i % 10 == 0:
        #     model.save(model_path_backup)

        if (record - record_temp > min_del):
            print('Validation loss improved from {} to {}'.format(record, record_temp))
            record = record_temp
            tol = 0
            
            #print('tol: {}'.format(tol))
            # save
            print('save to: {}'.format(model_path))
            model.save(model_path)
        else:
            print('Validation loss {} NOT improved'.format(record_temp))
            if record_temp > 1.0:
                print('Early stopping')
                break;
            else:
                tol += 1
                if tol >= max_tol:
                    print('Early stopping')
                    break;
                else:
                    continue;
        print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Initial record: 1.1
# Training round 0
# 2022-12-27 12:38:32.543270: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-12-27 12:38:32.595927: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2600000000 Hz
# 2022-12-27 12:38:32.799223: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# Validation loss improved from 1.1 to 0.999269605921409
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# 2022-12-27 12:38:39.362466: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 14.96699571609497 seconds ---
# Validation loss 0.9992801315601394 NOT improved
# Validation loss 0.9994745686577206 NOT improved
# Validation loss 0.9995382996549301 NOT improved
# Validation loss 0.9995022328161836 NOT improved
# Validation loss 0.9995308922542734 NOT improved
# Validation loss 0.9994137301129093 NOT improved
# Validation loss 0.9993688386475339 NOT improved
# Validation loss 0.9992825785147851 NOT improved
# Validation loss improved from 0.999269605921409 to 0.9991731023768907
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 6.464789152145386 seconds ---
# Validation loss improved from 0.9991731023768907 to 0.9989377576290704
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 5.7321999073028564 seconds ---
# Validation loss improved from 0.9989377576290704 to 0.9988066759668078
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 6.305912971496582 seconds ---
# Validation loss improved from 0.9988066759668078 to 0.9983134760155296
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 5.741978168487549 seconds ---
# Validation loss improved from 0.9983134760155296 to 0.998027950520858
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 6.254165887832642 seconds ---
# Validation loss improved from 0.998027950520858 to 0.9967350712660287
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 5.7471864223480225 seconds ---
# Validation loss improved from 0.9967350712660287 to 0.9955741390941008
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 6.397255182266235 seconds ---
# Validation loss improved from 0.9955741390941008 to 0.9936589735714172
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 5.724366188049316 seconds ---
# Validation loss improved from 0.9936589735714172 to 0.9930921518030517
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 6.265181064605713 seconds ---
# Validation loss improved from 0.9930921518030517 to 0.9926939124631866
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 5.737426280975342 seconds ---
# Validation loss improved from 0.9926939124631866 to 0.9886461076134614
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 5.729371786117554 seconds ---
# Validation loss improved from 0.9886461076134614 to 0.9877626869641445
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 6.343444585800171 seconds ---
# Validation loss improved from 0.9877626869641445 to 0.9835875162413016
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 5.698330640792847 seconds ---
# Validation loss improved from 0.9835875162413016 to 0.9713255256183417
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 6.297954320907593 seconds ---
# Validation loss improved from 0.9713255256183417 to 0.970301173983797
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 6.243194818496704 seconds ---
# Validation loss 0.9710345242253382 NOT improved
# Validation loss improved from 0.970301173983797 to 0.9671578944581174
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 5.758666038513184 seconds ---
# Validation loss improved from 0.9671578944581174 to 0.9401460700901185
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 6.371859788894653 seconds ---
# Validation loss 0.9423631194207364 NOT improved
# Validation loss 0.957638844304306 NOT improved
# Validation loss 0.9432691072576914 NOT improved
# Validation loss improved from 0.9401460700901185 to 0.9332698292766645
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 5.713960647583008 seconds ---
# Validation loss improved from 0.9332698292766645 to 0.928575950318096
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 6.305536985397339 seconds ---
# Validation loss improved from 0.928575950318096 to 0.9189019801653276
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 5.7854461669921875 seconds ---
# Validation loss 0.9438659115428276 NOT improved
# Validation loss improved from 0.9189019801653276 to 0.9111807989508468
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 5.733789920806885 seconds ---
# Validation loss 0.9277860352413787 NOT improved
# Validation loss 0.9163960790665047 NOT improved
# Validation loss 0.9323399296261928 NOT improved
# Validation loss improved from 0.9111807989508468 to 0.9084094179190236
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 5.698886394500732 seconds ---
# Validation loss 0.9631395944091805 NOT improved
# Validation loss 0.9319662508167528 NOT improved
# Validation loss 0.989631239790248 NOT improved
# Validation loss 0.9116523388741087 NOT improved
# Validation loss 0.9558780948261474 NOT improved
# Validation loss 1.0295148509477716 NOT improved
# Early stopping
# Training round 1
# Validation loss 0.999621101802806 NOT improved
# Validation loss 0.9995565878350754 NOT improved
# Validation loss 0.9995868732453507 NOT improved
# Validation loss 0.9996212660185284 NOT improved
# Validation loss 0.999621257409584 NOT improved
# Validation loss 0.9995035316067242 NOT improved
# Validation loss 0.9995204816811872 NOT improved
# Validation loss 0.9994615410437355 NOT improved
# Validation loss 0.9992359595053341 NOT improved
# Validation loss 0.9991090628067971 NOT improved
# Validation loss 0.9988101054397605 NOT improved
# Validation loss 0.9982202598153619 NOT improved
# Validation loss 0.9982293294230572 NOT improved
# Validation loss 0.997165878902598 NOT improved
# Validation loss 0.9957315645738727 NOT improved
# Validation loss 0.9932626680364169 NOT improved
# Validation loss 0.9960661384839153 NOT improved
# Validation loss 0.9928181019375331 NOT improved
# Validation loss 0.9888833174765003 NOT improved
# Validation loss 0.9904109986952648 NOT improved
# Validation loss 0.9888161835247692 NOT improved
# Validation loss 0.9827175025319455 NOT improved
# Validation loss 0.9624765542153296 NOT improved
# Validation loss 0.9724419199018971 NOT improved
# Validation loss 0.9497248856859213 NOT improved
# Validation loss 0.9684245161737218 NOT improved
# Validation loss 0.9580379239857034 NOT improved
# Validation loss 0.9291062517979483 NOT improved
# Validation loss 0.9488197217363371 NOT improved
# Validation loss improved from 0.9084094179190236 to 0.905664729870871
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 6.535751104354858 seconds ---
# Validation loss 0.9414129173080051 NOT improved
# Validation loss improved from 0.905664729870871 to 0.8987640176750823
# save to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/STN_Lead4/assets
# --- 6.354640960693359 seconds ---
# Validation loss 0.9405532609329709 NOT improved
# Validation loss 0.9255984701663432 NOT improved
# Validation loss 0.9221238501514344 NOT improved
# Validation loss 0.9430232492883525 NOT improved
# Validation loss 0.9108112228116199 NOT improved
# Validation loss 0.917983323482257 NOT improved
# Validation loss 0.9360704454206273 NOT improved
# Validation loss 0.9328532498542818 NOT improved
# Validation loss 0.9736324537531463 NOT improved
# Validation loss 1.0511499010234306 NOT improved
# Early stopping
# Training round 19
# Validation loss 0.9994631923134021 NOT improved
# Validation loss 0.9993264148349854 NOT improved
# Validation loss 0.9994958721652711 NOT improved
# Validation loss 0.9995097891242747 NOT improved
# Validation loss 0.9994945424629894 NOT improved
# Validation loss 0.9994385359385264 NOT improved
# Validation loss 0.999378406756241 NOT improved
# Validation loss 0.9992963422478262 NOT improved
# Validation loss 0.9992596004431594 NOT improved
# Validation loss 0.9992048079058738 NOT improved
# Validation loss 0.9981887607398211 NOT improved
# Validation loss 0.9981220921761453 NOT improved
# Validation loss 0.9972406769689568 NOT improved
# Validation loss 0.9966901988676026 NOT improved
# Validation loss 0.9963996225682359 NOT improved
# Validation loss 0.9944789889055852 NOT improved
# Validation loss 0.9882099152074832 NOT improved
# Validation loss 0.9873211226709359 NOT improved
# Validation loss 0.9824039744612273 NOT improved
# Validation loss 0.9786673286250218 NOT improved
# Validation loss 0.9837009093205048 NOT improved
# Validation loss 0.9744026939218328 NOT improved
# Validation loss 0.9830001374683741 NOT improved
# Validation loss 0.9633898689729828 NOT improved
# Validation loss 0.9506245110162915 NOT improved
# Validation loss 0.9443667235736565 NOT improved
# Validation loss 0.9496009087580739 NOT improved
# Validation loss 0.9511452654017989 NOT improved
# Validation loss 0.9209695861798792 NOT improved
# Validation loss 0.9273196639784491 NOT improved
# Validation loss 0.9262857840416149 NOT improved
# Validation loss 0.9089386736267624 NOT improved
# Validation loss 0.9063079704746574 NOT improved
# Validation loss 0.9608143979451255 NOT improved
# Validation loss 0.9139460723520498 NOT improved
# Validation loss 0.9377138227650871 NOT improved
# Validation loss 0.9020644602734214 NOT improved
# Validation loss 0.9023508232372752 NOT improved
# Validation loss 0.949701174932806 NOT improved
# Validation loss 0.9357419507423047 NOT improved
# Validation loss 0.9292713573472672 NOT improved
# Validation loss 0.9276083190780162 NOT improved
# Validation loss 1.0433129031869155 NOT improved
# Early stopping

# %%
temp_data = np.load('/glade/work/ksha/NCAR/VALID_MINMAX_lead2.npy')[()]

# %%
temp_data['MAX'].shape

# %%
model = create_model()

model.compile(loss=keras.losses.BinaryCrossentropy(from_logits=False),
              optimizer=keras.optimizers.Adam(lr=0))

W_old = k_utils.dummy_loader('/glade/work/ksha/NCAR/Keras_models/STN_Lead4/')
model.set_weights(W_old)

# %%
ref = np.sum(VALID_Y) / len(VALID_Y)
Y_pred = model.predict(VALID_merge)
record_temp = verif_metric(VALID_Y, Y_pred, ref)

# %%
record_temp
# Out:
# 0.8759321340156129

# %%
record_temp
# Out:
# 0.8759321340156129

# %%
plt.plot(Y_pred)

# %%
plt.plot(Y_pred)
