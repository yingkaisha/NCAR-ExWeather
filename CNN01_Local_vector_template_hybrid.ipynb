# %%
# general tools
import os
import sys
import time
import h5py
import random
from glob import glob

import numpy as np
from datetime import datetime, timedelta
from random import shuffle

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend
from keras_unet_collection import utils as k_utils
# Out:
# 2023-02-01 12:07:05.993250: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
sys.path.insert(0, '/glade/u/home/ksha/NCAR/')
sys.path.insert(0, '/glade/u/home/ksha/NCAR/libs/')

from namelist import *
import data_utils as du

# %%
import re

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def pos_mixer(TRAIN, L, a0=0, a1=0.2):
    data_shape = TRAIN.shape
    out = np.empty((L, data_shape[-1]))
    
    for i in range(L):
        inds = np.random.choice(data_shape[0], 2)
        a = np.random.uniform(a0, a1)
        out[i, :] = a*TRAIN[inds[0], :] + (1-a)*TRAIN[inds[1], :]
    return out

# %%
def set_seeds(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)

# %%
def verif_metric(VALID_target, Y_pred, ref):


    # fpr, tpr, thresholds = roc_curve(VALID_target.ravel(), Y_pred.ravel())
    # AUC = auc(fpr, tpr)
    # AUC_metric = 1 - AUC
    
    BS = np.mean((VALID_target.ravel() - Y_pred.ravel())**2)
    #ll = log_loss(VALID_target.ravel(), Y_pred.ravel())
    
    #print('{}'.format(BS))
    metric = BS

    return metric / ref

# %%
# def set_seeds(seed):
#     os.environ['PYTHONHASHSEED'] = str(seed)
#     random.seed(seed)
#     tf.random.set_seed(seed)
#     np.random.seed(seed)

# %%
def feature_extract(filenames, lon_80km, lon_minmax, lat_80km, lat_minmax, elev_80km, elev_max):
    
    lon_out = []
    lat_out = []
    elev_out = []
    mon_out = []
    
    base_v3_s = datetime(2018, 7, 15)
    base_v3_e = datetime(2020, 12, 2)

    base_v4_s = datetime(2020, 12, 3)
    base_v4_e = datetime(2022, 7, 15)

    base_ref = datetime(2010, 1, 1)
    
    date_list_v3 = [base_v3_s + timedelta(days=day) for day in range(365+365+142)]
    date_list_v4 = [base_v4_s + timedelta(days=day) for day in range(365+180-151)]
    
    for i, name in enumerate(filenames):
        
        if 'v4' in name:
            date_list = date_list_v4
        else:
            date_list = date_list_v3
        
        nums = re.findall(r'\d+', name)
        indy = int(nums[-2])
        indx = int(nums[-3])
        day = int(nums[-4])
        day = date_list[day]
        month = day.month
        
        month_norm = (month - 1)/(12-1)
        
        lon = lon_80km[indx, indy]
        lat = lat_80km[indx, indy]

        lon = (lon - lon_minmax[0])/(lon_minmax[1] - lon_minmax[0])
        lat = (lat - lat_minmax[0])/(lat_minmax[1] - lat_minmax[0])

        elev = elev_80km[indx, indy]
        elev = elev / elev_max
        
        lon_out.append(lon)
        lat_out.append(lat)
        elev_out.append(elev)
        mon_out.append(month_norm)
        
    return np.array(lon_out), np.array(lat_out), np.array(elev_out), np.array(mon_out)

# def create_model():

    
#     IN_vec = keras.Input((512,))    
#     IN_elev = keras.Input((3,))
#     IN = keras.layers.Concatenate()([IN_vec, IN_elev])
    
#     X = IN
#     #
#     X = keras.layers.Dense(1024, activity_regularizer=keras.regularizers.L2(1e-2))(X)
#     X = keras.layers.BatchNormalization()(X)
#     X = keras.layers.Activation("gelu")(X)
#     #X = keras.layers.Activation("relu")(X)

#     X = keras.layers.Dropout(0.4)(X)
#     #X = keras.layers.Dropout(0.2)(X)
#     #
    
#     X = keras.layers.Dense(512, activity_regularizer=keras.regularizers.L2(1e-2))(X)
#     X = keras.layers.BatchNormalization()(X)
#     X = keras.layers.Activation("gelu")(X)
#     #X = keras.layers.Activation("relu")(X)
    
#     X = keras.layers.Dropout(0.4)(X)
#     #X = keras.layers.Dropout(0.2)(X)
    
#     X = keras.layers.Dense(128, activity_regularizer=keras.regularizers.L2(1e-2))(X)
#     X = keras.layers.BatchNormalization()(X)
#     X = keras.layers.Activation("gelu")(X)
#     #X = keras.layers.Activation("relu")(X)
    
#     OUT = X
#     OUT = keras.layers.Dense(1, activation='sigmoid', bias_initializer=keras.initializers.Constant(-10))(OUT)

#     model = keras.models.Model(inputs=[IN_vec, IN_elev], outputs=OUT)
    
#     return model


def create_model():

    
    IN_vec = keras.Input((512,))    
    IN_elev = keras.Input((3,))
    IN = keras.layers.Concatenate()([IN_vec, IN_elev])
    
    X = IN
    #
    X = keras.layers.Dense(48)(X)
    X = keras.layers.Activation("relu")(X)
    X = keras.layers.BatchNormalization()(X)
    
    OUT = X
    OUT = keras.layers.Dense(1, activation='sigmoid', bias_initializer=keras.initializers.Constant(-10))(OUT)

    model = keras.models.Model(inputs=[IN_vec, IN_elev], outputs=OUT)
    
    return model

# %%
with h5py.File(save_dir+'HRRR_domain.hdf', 'r') as h5io:
    lon_3km = h5io['lon_3km'][...]
    lat_3km = h5io['lat_3km'][...]
    lon_80km = h5io['lon_80km'][...]
    lat_80km = h5io['lat_80km'][...]
    elev_3km = h5io['elev_3km'][...]
    land_mask_80km = h5io['land_mask_80km'][...]
    
grid_shape = land_mask_80km.shape

# %%
elev_80km = du.interp2d_wraper(lon_3km, lat_3km, elev_3km, lon_80km, lat_80km, method='linear')

elev_80km[np.isnan(elev_80km)] = 0
elev_80km[elev_80km<0] = 0
elev_max = np.max(elev_80km)

lon_80km_mask = lon_80km[land_mask_80km]
lat_80km_mask = lat_80km[land_mask_80km]

lon_minmax = [np.min(lon_80km_mask), np.max(lon_80km_mask)]
lat_minmax = [np.min(lat_80km_mask), np.max(lat_80km_mask)]

# %%
lead1 = 2
lead2 = 3
lead3 = 4
lead4 = 5

lead_name = 4
model_tag = 'alt'

# %%
filepath_vec = "/glade/work/ksha/NCAR/"

if (lead1 < 9) or (lead1 > 18):
    path_name1_v3 = '/glade/scratch/ksha/DATA/NCAR_batch_v3/'
else:
    path_name1_v3 = '/glade/campaign/cisl/aiml/ksha/NCAR_batch_v3/'

if (lead2 < 9) or (lead2 > 18):
    path_name2_v3 = '/glade/scratch/ksha/DATA/NCAR_batch_v3/'
else:
    path_name2_v3 = '/glade/campaign/cisl/aiml/ksha/NCAR_batch_v3/'
    
if (lead3 < 9) or (lead3 > 18):
    path_name3_v3 = '/glade/scratch/ksha/DATA/NCAR_batch_v3/'
else:
    path_name3_v3 = '/glade/campaign/cisl/aiml/ksha/NCAR_batch_v3/'
    
if (lead4 < 9) or (lead4 > 18):
    path_name4_v3 = '/glade/scratch/ksha/DATA/NCAR_batch_v3/'
else:
    path_name4_v3 = '/glade/campaign/cisl/aiml/ksha/NCAR_batch_v3/'

path_name1_v4 = '/glade/campaign/cisl/aiml/ksha/NCAR_batch_v4x/'
path_name2_v4 = '/glade/campaign/cisl/aiml/ksha/NCAR_batch_v4x/'
path_name3_v4 = '/glade/campaign/cisl/aiml/ksha/NCAR_batch_v4x/'
path_name4_v4 = '/glade/campaign/cisl/aiml/ksha/NCAR_batch_v4x/'

# %%
filename_train_lead1_v3 = sorted(glob("{}TRAIN*lead{}.npy".format(path_name1_v3, lead1)))
filename_train_lead2_v3 = sorted(glob("{}TRAIN*lead{}.npy".format(path_name2_v3, lead2)))
filename_train_lead3_v3 = sorted(glob("{}TRAIN*lead{}.npy".format(path_name3_v3, lead3)))
filename_train_lead4_v3 = sorted(glob("{}TRAIN*lead{}.npy".format(path_name4_v3, lead4)))

filename_train_lead1_v4 = sorted(glob("{}TRAIN*lead{}.npy".format(path_name1_v4, lead1)))
filename_train_lead2_v4 = sorted(glob("{}TRAIN*lead{}.npy".format(path_name2_v4, lead2)))
filename_train_lead3_v4 = sorted(glob("{}TRAIN*lead{}.npy".format(path_name3_v4, lead3)))
filename_train_lead4_v4 = sorted(glob("{}TRAIN*lead{}.npy".format(path_name4_v4, lead4)))

# %%
IND_TRAIN_lead = np.load('/glade/work/ksha/NCAR/IND_TRAIN_lead_full.npy', allow_pickle=True)[()]
TRAIN_ind1_v3 = IND_TRAIN_lead['lead{}'.format(lead1)]
TRAIN_ind2_v3 = IND_TRAIN_lead['lead{}'.format(lead2)]
TRAIN_ind3_v3 = IND_TRAIN_lead['lead{}'.format(lead3)]
TRAIN_ind4_v3 = IND_TRAIN_lead['lead{}'.format(lead4)]

IND_TRAIN_lead = np.load('/glade/work/ksha/NCAR/IND_TRAIN_lead_v4x.npy', allow_pickle=True)[()]
TRAIN_ind1_v4 = IND_TRAIN_lead['lead{}'.format(lead1)]
TRAIN_ind2_v4 = IND_TRAIN_lead['lead{}'.format(lead2)]
TRAIN_ind3_v4 = IND_TRAIN_lead['lead{}'.format(lead3)]
TRAIN_ind4_v4 = IND_TRAIN_lead['lead{}'.format(lead4)]

# %%
data_lead1_p0 = np.load('{}TRAIN_pp15_pred_lead{}_part0_{}.npy'.format(filepath_vec, lead1, model_tag), allow_pickle=True)[()]
data_lead1_p1 = np.load('{}TRAIN_pp15_pred_lead{}_part1_{}.npy'.format(filepath_vec, lead1, model_tag), allow_pickle=True)[()]
data_lead1_p2 = np.load('{}TRAIN_pp15_pred_lead{}_part2_{}.npy'.format(filepath_vec, lead1, model_tag), allow_pickle=True)[()]

data_lead2_p0 = np.load('{}TRAIN_pp15_pred_lead{}_part0_{}.npy'.format(filepath_vec, lead2, model_tag), allow_pickle=True)[()]
data_lead2_p1 = np.load('{}TRAIN_pp15_pred_lead{}_part1_{}.npy'.format(filepath_vec, lead2, model_tag), allow_pickle=True)[()]
data_lead2_p2 = np.load('{}TRAIN_pp15_pred_lead{}_part2_{}.npy'.format(filepath_vec, lead2, model_tag), allow_pickle=True)[()]

data_lead3_p0 = np.load('{}TRAIN_pp15_pred_lead{}_part0_{}.npy'.format(filepath_vec, lead3, model_tag), allow_pickle=True)[()]
data_lead3_p1 = np.load('{}TRAIN_pp15_pred_lead{}_part1_{}.npy'.format(filepath_vec, lead3, model_tag), allow_pickle=True)[()]
data_lead3_p2 = np.load('{}TRAIN_pp15_pred_lead{}_part2_{}.npy'.format(filepath_vec, lead3, model_tag), allow_pickle=True)[()]

data_lead4_p0 = np.load('{}TRAIN_pp15_pred_lead{}_part0_{}.npy'.format(filepath_vec, lead4, model_tag), allow_pickle=True)[()]
data_lead4_p1 = np.load('{}TRAIN_pp15_pred_lead{}_part1_{}.npy'.format(filepath_vec, lead4, model_tag), allow_pickle=True)[()]
data_lead4_p2 = np.load('{}TRAIN_pp15_pred_lead{}_part2_{}.npy'.format(filepath_vec, lead4, model_tag), allow_pickle=True)[()]

# %%
data_lead1_v4 = np.load('{}TRAIN_v4x_vec_lead{}_part0_{}.npy'.format(filepath_vec, lead1, model_tag), allow_pickle=True)[()]
data_lead2_v4 = np.load('{}TRAIN_v4x_vec_lead{}_part0_{}.npy'.format(filepath_vec, lead2, model_tag), allow_pickle=True)[()]
data_lead3_v4 = np.load('{}TRAIN_v4x_vec_lead{}_part0_{}.npy'.format(filepath_vec, lead3, model_tag), allow_pickle=True)[()]
data_lead4_v4 = np.load('{}TRAIN_v4x_vec_lead{}_part0_{}.npy'.format(filepath_vec, lead4, model_tag), allow_pickle=True)[()]

# %%
TRAIN_lead1_v4 = data_lead1_v4['y_vector']
TRAIN_lead2_v4 = data_lead2_v4['y_vector']
TRAIN_lead3_v4 = data_lead3_v4['y_vector']
TRAIN_lead4_v4 = data_lead4_v4['y_vector']

TRAIN_lead1_v3 = np.concatenate((data_lead1_p0['y_vector'], data_lead1_p1['y_vector'], data_lead1_p2['y_vector']), axis=0)
TRAIN_lead2_v3 = np.concatenate((data_lead2_p0['y_vector'], data_lead2_p1['y_vector'], data_lead2_p2['y_vector']), axis=0)
TRAIN_lead3_v3 = np.concatenate((data_lead3_p0['y_vector'], data_lead3_p1['y_vector'], data_lead3_p2['y_vector']), axis=0)
TRAIN_lead4_v3 = np.concatenate((data_lead4_p0['y_vector'], data_lead4_p1['y_vector'], data_lead4_p2['y_vector']), axis=0)

# %%
TRAIN_lead1_y_v4 = data_lead1_v4['y_true']
TRAIN_lead2_y_v4 = data_lead2_v4['y_true']
TRAIN_lead3_y_v4 = data_lead3_v4['y_true']
TRAIN_lead4_y_v4 = data_lead4_v4['y_true']

TRAIN_lead1_y_v3 = np.concatenate((data_lead1_p0['y_true'], data_lead1_p1['y_true'], data_lead1_p2['y_true']), axis=0)
TRAIN_lead2_y_v3 = np.concatenate((data_lead2_p0['y_true'], data_lead2_p1['y_true'], data_lead2_p2['y_true']), axis=0)
TRAIN_lead3_y_v3 = np.concatenate((data_lead3_p0['y_true'], data_lead3_p1['y_true'], data_lead3_p2['y_true']), axis=0)
TRAIN_lead4_y_v3 = np.concatenate((data_lead4_p0['y_true'], data_lead4_p1['y_true'], data_lead4_p2['y_true']), axis=0)

# %%
L = len(TRAIN_ind2_v3)

filename_train1_pick_v3 = []
filename_train2_pick_v3 = []
filename_train3_pick_v3 = []
filename_train4_pick_v3 = []

TRAIN_X_v3 = np.empty((L, 512))
TRAIN_Y_v3 = np.empty(L)

for i in range(L):
    
    ind_lead1_v3 = int(TRAIN_ind1_v3[i])
    ind_lead2_v3 = int(TRAIN_ind2_v3[i])
    ind_lead3_v3 = int(TRAIN_ind3_v3[i])
    ind_lead4_v3 = int(TRAIN_ind4_v3[i])
    
    filename_train1_pick_v3.append(filename_train_lead1_v3[ind_lead1_v3])
    filename_train2_pick_v3.append(filename_train_lead2_v3[ind_lead2_v3])
    filename_train3_pick_v3.append(filename_train_lead3_v3[ind_lead3_v3])
    filename_train4_pick_v3.append(filename_train_lead4_v3[ind_lead4_v3])
    
    TRAIN_X_v3[i, 0:128]   = TRAIN_lead1_v3[ind_lead1_v3, :]
    TRAIN_X_v3[i, 128:256] = TRAIN_lead2_v3[ind_lead2_v3, :]
    TRAIN_X_v3[i, 256:384] = TRAIN_lead3_v3[ind_lead3_v3, :]
    TRAIN_X_v3[i, 384:512] = TRAIN_lead4_v3[ind_lead4_v3, :]
    
    TRAIN_Y_v3[i] = TRAIN_lead3_y_v3[ind_lead3_v3]

# %%
L = len(TRAIN_ind2_v4)

filename_train1_pick_v4 = []
filename_train2_pick_v4 = []
filename_train3_pick_v4 = []
filename_train4_pick_v4 = []

TRAIN_X_v4 = np.empty((L, 512))
TRAIN_Y_v4 = np.empty(L)

for i in range(L):
    
    ind_lead1_v4 = int(TRAIN_ind1_v4[i])
    ind_lead2_v4 = int(TRAIN_ind2_v4[i])
    ind_lead3_v4 = int(TRAIN_ind3_v4[i])
    ind_lead4_v4 = int(TRAIN_ind4_v4[i])
    
    filename_train1_pick_v4.append(filename_train_lead1_v4[ind_lead1_v4])
    filename_train2_pick_v4.append(filename_train_lead2_v4[ind_lead2_v4])
    filename_train3_pick_v4.append(filename_train_lead3_v4[ind_lead3_v4])
    filename_train4_pick_v4.append(filename_train_lead4_v4[ind_lead4_v4])
    
    TRAIN_X_v4[i, 0:128]   = TRAIN_lead1_v4[ind_lead1_v4, :]
    TRAIN_X_v4[i, 128:256] = TRAIN_lead2_v4[ind_lead2_v4, :]
    TRAIN_X_v4[i, 256:384] = TRAIN_lead3_v4[ind_lead3_v4, :]
    TRAIN_X_v4[i, 384:512] = TRAIN_lead4_v4[ind_lead4_v4, :]
    
    TRAIN_Y_v4[i] = TRAIN_lead3_y_v4[ind_lead3_v4]

# %%
lon_norm_v3, lat_norm_v3, elev_norm_v3, mon_norm_v3 = feature_extract(filename_train3_pick_v3, 
                                                                      lon_80km, lon_minmax, 
                                                                      lat_80km, lat_minmax, elev_80km, elev_max)


lon_norm_v4, lat_norm_v4, elev_norm_v4, mon_norm_v4 = feature_extract(filename_train3_pick_v4, 
                                                                      lon_80km, lon_minmax, 
                                                                      lat_80km, lat_minmax, elev_80km, elev_max)

# %%
TRAIN_stn_v3 = np.concatenate((lon_norm_v3[:, None], 
                               lat_norm_v3[:, None], 
                               elev_norm_v3[:, None]), axis=1)

TRAIN_stn_v4 = np.concatenate((lon_norm_v4[:, None], 
                               lat_norm_v4[:, None], 
                               elev_norm_v4[:, None]), axis=1)

# %%
TRAIN_256_pos_v3 = TRAIN_X_v3[TRAIN_Y_v3==1, :]
TRAIN_256_neg_v3 = TRAIN_X_v3[TRAIN_Y_v3==0, :]

TRAIN_256_pos_v4 = TRAIN_X_v4[TRAIN_Y_v4==1, :]
TRAIN_256_neg_v4 = TRAIN_X_v4[TRAIN_Y_v4==0, :]

# %%
TRAIN_stn_pos_v3 = TRAIN_stn_v3[TRAIN_Y_v3==1]
TRAIN_stn_neg_v3 = TRAIN_stn_v3[TRAIN_Y_v3==0]

TRAIN_stn_pos_v4 = TRAIN_stn_v4[TRAIN_Y_v4==1]
TRAIN_stn_neg_v4 = TRAIN_stn_v4[TRAIN_Y_v4==0]

# %%
TRAIN_Y = np.concatenate((TRAIN_Y_v3, TRAIN_Y_v4), axis=0)

TRAIN_256_pos = np.concatenate((TRAIN_256_pos_v3, TRAIN_256_pos_v4), axis=0)
TRAIN_256_neg = np.concatenate((TRAIN_256_neg_v3, TRAIN_256_neg_v4), axis=0)

TRAIN_stn_pos = np.concatenate((TRAIN_stn_pos_v3, TRAIN_stn_pos_v4), axis=0)
TRAIN_stn_neg = np.concatenate((TRAIN_stn_neg_v3, TRAIN_stn_neg_v4), axis=0)


# TRAIN_Y = TRAIN_Y_v4

# TRAIN_256_pos = TRAIN_256_pos_v4
# TRAIN_256_neg = TRAIN_256_neg_v4

# TRAIN_stn_pos = TRAIN_stn_pos_v4
# TRAIN_stn_neg = TRAIN_stn_neg_v4

# %% [markdown]
# **Valid**

# %%
filename_valid_lead1 = sorted(glob("{}VALID*lead{}.npy".format(path_name1_v3, lead1)))
filename_valid_lead2 = sorted(glob("{}VALID*lead{}.npy".format(path_name2_v3, lead2)))
filename_valid_lead3 = sorted(glob("{}VALID*lead{}.npy".format(path_name3_v3, lead3)))
filename_valid_lead4 = sorted(glob("{}VALID*lead{}.npy".format(path_name4_v3, lead4)))

valid_lead1 = np.load('{}TEST_pp15_pred_lead{}_{}.npy'.format(filepath_vec, lead1, model_tag), allow_pickle=True)[()]
valid_lead2 = np.load('{}TEST_pp15_pred_lead{}_{}.npy'.format(filepath_vec, lead2, model_tag), allow_pickle=True)[()]
valid_lead3 = np.load('{}TEST_pp15_pred_lead{}_{}.npy'.format(filepath_vec, lead3, model_tag), allow_pickle=True)[()]
valid_lead4 = np.load('{}TEST_pp15_pred_lead{}_{}.npy'.format(filepath_vec, lead4, model_tag), allow_pickle=True)[()]

VALID_lead1 = valid_lead1['y_vector']
VALID_lead2 = valid_lead2['y_vector']
VALID_lead3 = valid_lead3['y_vector']
VALID_lead4 = valid_lead4['y_vector']

VALID_lead1_y = valid_lead1['y_true']
VALID_lead2_y = valid_lead2['y_true']
VALID_lead3_y = valid_lead3['y_true']
VALID_lead4_y = valid_lead4['y_true']

IND_VALID_lead = np.load('/glade/work/ksha/NCAR/IND_VALID_lead_full.npy', allow_pickle=True)[()]

VALID_ind1 = IND_VALID_lead['lead{}'.format(lead1)]
VALID_ind2 = IND_VALID_lead['lead{}'.format(lead2)]
VALID_ind3 = IND_VALID_lead['lead{}'.format(lead3)]
VALID_ind4 = IND_VALID_lead['lead{}'.format(lead4)]

L = len(VALID_ind3)

filename_valid1_pick = []
filename_valid2_pick = []
filename_valid3_pick = []
filename_valid4_pick = []

VALID_X = np.empty((L, 512))
VALID_Y = np.zeros(L)

for i in range(L):
    
    ind_lead1 = int(VALID_ind1[i])
    ind_lead2 = int(VALID_ind2[i])
    ind_lead3 = int(VALID_ind3[i])
    ind_lead4 = int(VALID_ind4[i])
    
    filename_valid1_pick.append(filename_valid_lead1[ind_lead1])
    filename_valid2_pick.append(filename_valid_lead2[ind_lead2])
    filename_valid3_pick.append(filename_valid_lead3[ind_lead3])
    filename_valid4_pick.append(filename_valid_lead4[ind_lead4])
    
    VALID_X[i, 0:128]   = VALID_lead1[ind_lead1, :]
    VALID_X[i, 128:256] = VALID_lead2[ind_lead2, :]
    VALID_X[i, 256:384] = VALID_lead3[ind_lead3, :]
    VALID_X[i, 384:512] = VALID_lead4[ind_lead4, :]
    
    if 'pos' in filename_valid_lead3[ind_lead3]:
        if VALID_lead3_y[ind_lead3] == 1.0:
            VALID_Y[i] = 1.0
        else:
            egwrshat
            
lon_norm, lat_norm, elev_norm, mon_norm = feature_extract(
    filename_valid3_pick, lon_80km, lon_minmax, lat_80km, lat_minmax, elev_80km, elev_max)

VALID_stn = np.concatenate((lon_norm[:, None], lat_norm[:, None], elev_norm[:, None]), axis=1)
VALID_merge = VALID_stn

# %%
# filename_valid_lead1 = sorted(glob("{}VALID*lead{}.npy".format(path_name1_v4, lead1)))
# filename_valid_lead2 = sorted(glob("{}VALID*lead{}.npy".format(path_name2_v4, lead2)))
# filename_valid_lead3 = sorted(glob("{}VALID*lead{}.npy".format(path_name3_v4, lead3)))
# filename_valid_lead4 = sorted(glob("{}VALID*lead{}.npy".format(path_name4_v4, lead4)))

# valid_lead1 = np.load('{}VALID_v4x_vec_lead{}_{}.npy'.format(filepath_vec, lead1, model_tag), allow_pickle=True)[()]
# valid_lead2 = np.load('{}VALID_v4x_vec_lead{}_{}.npy'.format(filepath_vec, lead2, model_tag), allow_pickle=True)[()]
# valid_lead3 = np.load('{}VALID_v4x_vec_lead{}_{}.npy'.format(filepath_vec, lead3, model_tag), allow_pickle=True)[()]
# valid_lead4 = np.load('{}VALID_v4x_vec_lead{}_{}.npy'.format(filepath_vec, lead4, model_tag), allow_pickle=True)[()]

# VALID_lead1 = valid_lead1['y_vector']
# VALID_lead2 = valid_lead2['y_vector']
# VALID_lead3 = valid_lead3['y_vector']
# VALID_lead4 = valid_lead4['y_vector']

# VALID_lead1_y = valid_lead1['y_true']
# VALID_lead2_y = valid_lead2['y_true']
# VALID_lead3_y = valid_lead3['y_true']
# VALID_lead4_y = valid_lead4['y_true']

# IND_VALID_lead = np.load('/glade/work/ksha/NCAR/IND_VALID_lead_v4x.npy', allow_pickle=True)[()]

# VALID_ind1 = IND_VALID_lead['lead{}'.format(lead1)]
# VALID_ind2 = IND_VALID_lead['lead{}'.format(lead2)]
# VALID_ind3 = IND_VALID_lead['lead{}'.format(lead3)]
# VALID_ind4 = IND_VALID_lead['lead{}'.format(lead4)]

# L = len(VALID_ind3)

# filename_valid1_pick = []
# filename_valid2_pick = []
# filename_valid3_pick = []
# filename_valid4_pick = []

# VALID_X = np.empty((L, 512))
# VALID_Y = np.zeros(L)

# for i in range(L):
    
#     ind_lead1 = int(VALID_ind1[i])
#     ind_lead2 = int(VALID_ind2[i])
#     ind_lead3 = int(VALID_ind3[i])
#     ind_lead4 = int(VALID_ind4[i])
    
#     filename_valid1_pick.append(filename_valid_lead1[ind_lead1])
#     filename_valid2_pick.append(filename_valid_lead2[ind_lead2])
#     filename_valid3_pick.append(filename_valid_lead3[ind_lead3])
#     filename_valid4_pick.append(filename_valid_lead4[ind_lead4])
    
#     VALID_X[i, 0:128]   = VALID_lead1[ind_lead1, :]
#     VALID_X[i, 128:256] = VALID_lead2[ind_lead2, :]
#     VALID_X[i, 256:384] = VALID_lead3[ind_lead3, :]
#     VALID_X[i, 384:512] = VALID_lead4[ind_lead4, :]
    
#     if 'pos' in filename_valid_lead3[ind_lead3]:
#         if VALID_lead3_y[ind_lead3] == 1.0:
#             VALID_Y[i] = 1.0
#         else:
#             egwrshat
            
# lon_norm, lat_norm, elev_norm, mon_norm = feature_extract(
#     filename_valid3_pick, lon_80km, lon_minmax, lat_80km, lat_minmax, elev_80km, elev_max)

# VALID_stn = np.concatenate((lon_norm[:, None], lat_norm[:, None], elev_norm[:, None]), axis=1)
# VALID_merge = VALID_stn

# %%
seeds = [12342, 2536234, 98765, 473, 865, 7456, 69472, 3456357, 3425, 678,
         2452624, 5787, 235362, 67896, 98454, 12445, 46767, 78906, 345, 8695, 
         2463725, 4734, 23234, 884, 2341, 362, 5, 234, 483, 785356, 23425, 3621, 
         58461, 80968765, 123, 425633, 5646, 67635, 76785, 34214]

training_rounds = len(seeds)

# %%
ref = np.sum(VALID_Y) / len(VALID_Y)

# =========== Model Section ========== #

batch_dir = '/glade/scratch/ksha/DATA/NCAR_batch/'
temp_dir = '/glade/work/ksha/NCAR/Keras_models/'

key = 'HY_Lead{}'.format(lead_name)

model_name = '{}'.format(key)
model_path = temp_dir+model_name

tol = 0

# ========== Training loop ========== #
L_pos = len(TRAIN_256_pos)
L_neg = len(TRAIN_256_neg)

record = 1.1
print("Initial record: {}".format(record))

min_del = 0
max_tol = 100 # early stopping with patience

epochs = 500
batch_size = 64
L_train = 16

for r in range(training_rounds):
    if r == 0:
        tol = 0
    else:
        tol = -200

    model = create_model()
    #
    # model.compile(loss=keras.losses.mean_squared_error,
    #               optimizer=keras.optimizers.Adam(lr=1e-5))
    
    model.compile(loss=keras.losses.BinaryCrossentropy(from_logits=False),
                  optimizer=keras.optimizers.Adam(lr=1e-4))
    
    set_seeds(int(seeds[r]))
    print('Training round {}'.format(r))

    for i in range(epochs):            
        start_time = time.time()

        # loop of batch
        for j in range(L_train):
            N_pos = 32
            N_neg = batch_size - N_pos

            ind_neg = du.shuffle_ind(L_neg)
            ind_pos = du.shuffle_ind(L_pos)

            ind_neg_pick = ind_neg[:N_neg]
            ind_pos_pick = ind_pos[:N_pos]

            X_batch_neg = TRAIN_256_neg[ind_neg_pick, :]
            X_batch_pos = TRAIN_256_pos[ind_pos_pick, :]
            
            X_batch_stn_neg = TRAIN_stn_neg[ind_neg_pick, :]
            X_batch_stn_pos = TRAIN_stn_pos[ind_pos_pick, :]

            X_batch = np.concatenate((X_batch_neg, X_batch_pos), axis=0)
            X_batch_stn = np.concatenate((X_batch_stn_neg, X_batch_stn_pos), axis=0)

            Y_batch = np.ones([batch_size,])
            Y_batch[:N_neg] = 0.0

            ind_ = du.shuffle_ind(batch_size)

            X_batch = X_batch[ind_, :]
            X_batch_stn = X_batch_stn[ind_, :]
            Y_batch = Y_batch[ind_]

            # train on batch
            model.train_on_batch([X_batch, X_batch_stn], Y_batch);

        # epoch end operations
        Y_pred = model.predict([VALID_X, VALID_merge])

        Y_pred[Y_pred<0] = 0
        Y_pred[Y_pred>1] = 1

        record_temp = verif_metric(VALID_Y, Y_pred, ref)

        # if i % 10 == 0:
        #     model.save(model_path_backup)

        if (record - record_temp > min_del):
            print('Validation loss improved from {} to {}'.format(record, record_temp))
            record = record_temp
            tol = 0
            
            #print('tol: {}'.format(tol))
            # save
            print('save to: {}'.format(model_path))
            model.save(model_path)
        else:
            print('Validation loss {} NOT improved'.format(record_temp))
            if record_temp > 1.0:
                print('Early stopping')
                break;
            else:
                tol += 1
                if tol >= max_tol:
                    print('Early stopping')
                    break;
                else:
                    continue;
        print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Initial record: 1.1
# Training round 0
# Validation loss improved from 1.1 to 0.9968985684621986
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 7.216843843460083 seconds ---
# Validation loss improved from 0.9968985684621986 to 0.9911586857141215
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.993813753128052 seconds ---
# Validation loss improved from 0.9911586857141215 to 0.9852070372827093
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.864790678024292 seconds ---
# Validation loss improved from 0.9852070372827093 to 0.9791730373871407
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.973909854888916 seconds ---
# Validation loss improved from 0.9791730373871407 to 0.9736234586942555
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.9517762660980225 seconds ---
# Validation loss improved from 0.9736234586942555 to 0.9724824119309037
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.619465351104736 seconds ---
# Validation loss 0.9726156985972328 NOT improved
# Validation loss improved from 0.9724824119309037 to 0.9716338816556412
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.918859004974365 seconds ---
# Validation loss improved from 0.9716338816556412 to 0.9710119552830052
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.845258712768555 seconds ---
# Validation loss improved from 0.9710119552830052 to 0.96981036345689
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.8857293128967285 seconds ---
# Validation loss improved from 0.96981036345689 to 0.9690260004420338
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.8627495765686035 seconds ---
# Validation loss improved from 0.9690260004420338 to 0.9673652889665351
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.56925106048584 seconds ---
# Validation loss improved from 0.9673652889665351 to 0.9671124145846879
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.8914289474487305 seconds ---
# Validation loss improved from 0.9671124145846879 to 0.9658153535483497
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.024487733840942 seconds ---
# Validation loss improved from 0.9658153535483497 to 0.9644321174149009
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.933495044708252 seconds ---
# Validation loss improved from 0.9644321174149009 to 0.962795483390061
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.017452001571655 seconds ---
# Validation loss improved from 0.962795483390061 to 0.9599414845823242
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.93401575088501 seconds ---
# Validation loss improved from 0.9599414845823242 to 0.9556986104987762
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.72008490562439 seconds ---
# Validation loss improved from 0.9556986104987762 to 0.9528631256946665
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.9546144008636475 seconds ---
# Validation loss improved from 0.9528631256946665 to 0.9510123382399559
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.971142768859863 seconds ---
# Validation loss improved from 0.9510123382399559 to 0.9501312853528694
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.931604862213135 seconds ---
# Validation loss improved from 0.9501312853528694 to 0.9488002178691386
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.902167797088623 seconds ---
# Validation loss improved from 0.9488002178691386 to 0.9417045782944716
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.495067834854126 seconds ---
# Validation loss improved from 0.9417045782944716 to 0.9361441251457187
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.986498594284058 seconds ---
# Validation loss improved from 0.9361441251457187 to 0.9315683491258446
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.858563423156738 seconds ---
# Validation loss improved from 0.9315683491258446 to 0.9278465742059399
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.031614303588867 seconds ---
# Validation loss improved from 0.9278465742059399 to 0.9233397382156973
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.09333062171936 seconds ---
# Validation loss improved from 0.9233397382156973 to 0.917285597837046
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.920459270477295 seconds ---
# Validation loss improved from 0.917285597837046 to 0.9111974932233686
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.491604566574097 seconds ---
# Validation loss improved from 0.9111974932233686 to 0.9071753980555565
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.850520372390747 seconds ---
# Validation loss improved from 0.9071753980555565 to 0.9044618391924384
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.049037218093872 seconds ---
# Validation loss improved from 0.9044618391924384 to 0.8996755246139383
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.885979652404785 seconds ---
# Validation loss improved from 0.8996755246139383 to 0.8967961209035038
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.015186548233032 seconds ---
# Validation loss improved from 0.8967961209035038 to 0.8934080464386983
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.946760416030884 seconds ---
# Validation loss improved from 0.8934080464386983 to 0.8910646276551061
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.540321111679077 seconds ---
# Validation loss improved from 0.8910646276551061 to 0.8902603793934919
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.000572681427002 seconds ---
# Validation loss improved from 0.8902603793934919 to 0.8874077306853916
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.908494234085083 seconds ---
# Validation loss improved from 0.8874077306853916 to 0.8852800500950893
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.929376602172852 seconds ---
# Validation loss improved from 0.8852800500950893 to 0.8848690510386362
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.971995830535889 seconds ---
# Validation loss improved from 0.8848690510386362 to 0.8845744457883009
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.510024547576904 seconds ---
# Validation loss 0.8846664126566192 NOT improved
# Validation loss 0.8853014756963012 NOT improved
# Validation loss 0.8864015155823612 NOT improved
# Validation loss 0.8876508941764056 NOT improved
# Validation loss 0.8910983984864961 NOT improved
# Validation loss 0.8963450762119876 NOT improved
# Validation loss 0.892703601095319 NOT improved
# Validation loss 0.8912775033972249 NOT improved
# Validation loss 0.9035890168951489 NOT improved
# Validation loss 0.9065816901549082 NOT improved
# Validation loss 0.9125923367220103 NOT improved
# Validation loss 0.9296127472413268 NOT improved
# Validation loss 1.3179625632304064 NOT improved
# Early stopping
# Training round 1
# Validation loss 0.9884955766692622 NOT improved
# Validation loss 0.9454420311890331 NOT improved
# Validation loss 0.8987596383908936 NOT improved
# Validation loss improved from 0.8845744457883009 to 0.877328797717185
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 17.882652044296265 seconds ---
# Validation loss improved from 0.877328797717185 to 0.8763067343893876
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.8673601150512695 seconds ---
# Validation loss improved from 0.8763067343893876 to 0.8682064758005024
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 4.991004705429077 seconds ---
# Validation loss improved from 0.8682064758005024 to 0.8665634567700535
# save to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4
# INFO:tensorflow:Assets written to: /glade/work/ksha/NCAR/Keras_models/HY_Lead4/assets
# --- 5.0088841915130615 seconds ---
# Validation loss 0.8672552845822256 NOT improved
# Validation loss 0.8871080215696728 NOT improved
# Validation loss 0.8818996269948454 NOT improved
# Validation loss 0.8891894127753184 NOT improved
# Validation loss 0.9706845769364411 NOT improved
# Validation loss 1.3757176478743234 NOT improved
# Early stopping
# Training round 2
# Validation loss 0.9992894505975165 NOT improved
# Validation loss 0.9914469893846192 NOT improved
# Validation loss 0.9650164497097027 NOT improved
# Validation loss 0.9446611315017072 NOT improved
# Validation loss 0.9219422150774986 NOT improved
# Validation loss 0.9070413163458658 NOT improved
# Validation loss 0.8958222730005676 NOT improved
# Validation loss 0.8900006584637495 NOT improved
# Validation loss 0.8843675737199042 NOT improved
# Validation loss 0.8796904257745748 NOT improved
# Validation loss 0.8822675006472968 NOT improved
# Validation loss 0.8953263017732414 NOT improved
# Validation loss 0.903838153273169 NOT improved
# Validation loss 0.9120029130016386 NOT improved
# Validation loss 0.9191094982061 NOT improved
# Validation loss 0.9295744198088 NOT improved
# Validation loss 0.9496230285977132 NOT improved
# Validation loss 0.9640629270324085 NOT improved
# Validation loss 0.9694270173599758 NOT improved
# Validation loss 0.9783255617791854 NOT improved
# Validation loss 0.9781533993923518 NOT improved
# Validation loss 0.9905740781847094 NOT improved
# Validation loss 1.027342999368835 NOT improved
# Early stopping
# Training round 3
# Validation loss 0.9990204896294504 NOT improved
# Validation loss 0.9899697883348954 NOT improved
# Validation loss 0.9728506203170286 NOT improved
# Validation loss 0.9507367114600327 NOT improved
# Validation loss 0.9318130916408455 NOT improved
# Validation loss 0.9243655316190613 NOT improved
# Validation loss 0.9209876052325082 NOT improved
# Validation loss 0.9217750169822753 NOT improved
# Validation loss 0.9199412104873672 NOT improved
# Validation loss 0.9191090615824776 NOT improved
# Validation loss 0.9169806666149505 NOT improved
# Validation loss 0.9172758311747866 NOT improved
# Validation loss 0.9152405955111758 NOT improved
# Validation loss 0.9135591023732933 NOT improved
# Validation loss 0.9113786725590688 NOT improved
# Validation loss 0.9076552999635142 NOT improved
# Validation loss 0.9035523821202357 NOT improved
# Validation loss 0.9024611762183027 NOT improved
# Validation loss 0.8997723184135887 NOT improved
# Validation loss 0.8960908062841316 NOT improved
# Validation loss 0.8935728544658517 NOT improved
# Validation loss 0.8909961589457959 NOT improved
# Validation loss 0.8888068619648589 NOT improved
# Validation loss 0.88552254262637 NOT improved
# Validation loss 0.8850770040389917 NOT improved
# Validation loss 0.8830317676084819 NOT improved
# Validation loss 0.8792541704281833 NOT improved
# Validation loss 0.8789438371816303 NOT improved
# Validation loss 0.8794197494338101 NOT improved
# Validation loss 0.8799738612677311 NOT improved
# Validation loss 0.880899090332839 NOT improved
# Validation loss 0.8806680325836317 NOT improved
# Validation loss 0.8810122374920614 NOT improved
# Validation loss 0.8805659635253454 NOT improved
# Validation loss 0.8795812827409311 NOT improved
# Validation loss 0.8791966313382482 NOT improved
# Validation loss 0.8795161309331774 NOT improved
# Validation loss 0.8800441574485126 NOT improved
# Validation loss 0.882541260369166 NOT improved
# Validation loss 0.8863076294425225 NOT improved
# Validation loss 0.8894829255289287 NOT improved
# Validation loss 0.8920571219129834 NOT improved
# Validation loss 0.8911471815325196 NOT improved
# Validation loss 0.8856513886569505 NOT improved
# Validation loss 0.8826628918142994 NOT improved
# Validation loss 0.8865980006675714 NOT improved
# Validation loss 0.8897298731925352 NOT improved
# Validation loss 0.8931803718835509 NOT improved
# Validation loss 0.8896595998247966 NOT improved
# Validation loss 0.8905325703052729 NOT improved
# Validation loss 0.9058740124790416 NOT improved
# Validation loss 0.921216852972246 NOT improved
# Validation loss 0.9333754620547111 NOT improved
# Validation loss 0.9129318406783062 NOT improved
# Validation loss 0.8965906571071686 NOT improved
# Validation loss 0.9397121310566442 NOT improved
# Validation loss 0.9103939423440401 NOT improved
# Validation loss 0.9226736101087544 NOT improved
# Validation loss 1.1410452047454964 NOT improved
# Early stopping
# Training round 4
# Validation loss 0.9991553374035028 NOT improved
# Validation loss 0.9962374091754492 NOT improved
# Validation loss 0.9889529359330911 NOT improved
# Validation loss 0.9832299953827112 NOT improved
# Validation loss 0.9796852854855849 NOT improved
# Validation loss 0.9734304264871806 NOT improved
# Validation loss 0.9730637462093247 NOT improved
# Validation loss 0.9750625997851685 NOT improved
# Validation loss 0.9769756353009176 NOT improved
# Validation loss 0.9784540853388954 NOT improved
# Validation loss 0.9787833308283244 NOT improved
# Validation loss 0.9785691684475389 NOT improved
# Validation loss 0.9790693025938482 NOT improved
# Validation loss 0.9795750871682806 NOT improved
# Validation loss 0.9788453313701343 NOT improved
# Validation loss 0.9785469804909818 NOT improved
# Validation loss 0.9780859235516294 NOT improved
# Validation loss 0.9769233701730714 NOT improved
# Validation loss 0.9765421571742915 NOT improved
# Validation loss 0.9758591422681021 NOT improved
# Validation loss 0.9744458170328483 NOT improved
# Validation loss 0.9730395570495619 NOT improved
# Validation loss 0.9715657375100811 NOT improved
# Validation loss 0.9702158767498874 NOT improved
# Validation loss 0.9690794489275497 NOT improved
# Validation loss 0.9673916306248653 NOT improved
# Validation loss 0.9644239617660832 NOT improved
# Validation loss 0.9621021307549409 NOT improved
# Validation loss 0.958376002914013 NOT improved
# Validation loss 0.9551999731960107 NOT improved
# Validation loss 0.952334154105042 NOT improved
# Validation loss 0.9499749058581118 NOT improved
# Validation loss 0.9478590778693418 NOT improved
# Validation loss 0.94395729424821 NOT improved
# Validation loss 0.9395215917333442 NOT improved
# Validation loss 0.9351276617466776 NOT improved
# Validation loss 0.9284098165315062 NOT improved
# Validation loss 0.915199286000965 NOT improved
# Validation loss 0.9078858241518148 NOT improved
# Validation loss 0.9034242945069837 NOT improved
# Validation loss 0.9044217543024725 NOT improved
# Validation loss 0.9006930828539602 NOT improved
# Validation loss 0.9009974820441133 NOT improved
# Validation loss 0.8983561409319909 NOT improved
# Validation loss 0.9024361149016904 NOT improved
# Validation loss 0.8925860491541641 NOT improved
# Validation loss 0.8857517151658684 NOT improved
# Validation loss 0.8841028838840538 NOT improved
# Validation loss 0.8818584016696135 NOT improved
# Validation loss 0.8781125514611459 NOT improved
# Validation loss 0.8784997661581272 NOT improved
# Validation loss 0.8849566032625178 NOT improved
# Validation loss 0.8825886937530972 NOT improved
# Validation loss 0.8832906338266422 NOT improved
# Validation loss 0.8785983917515657 NOT improved
# Validation loss 0.8791894782015214 NOT improved
# Validation loss 0.8803101139367431 NOT improved
# Validation loss 0.8866188040466512 NOT improved
# Validation loss 0.889041342227272 NOT improved
# Validation loss 0.9051786918356998 NOT improved
# Validation loss 0.9235254480739161 NOT improved
# Validation loss 0.9208254191577107 NOT improved
# Validation loss 0.9395128840675285 NOT improved
# Validation loss 0.8961777244188038 NOT improved
# Validation loss 0.9357351876142336 NOT improved
# Validation loss 0.921555223401104 NOT improved
# Validation loss 0.9200834687171242 NOT improved
# Validation loss 0.905909693087033 NOT improved
# Validation loss 0.9207630461003291 NOT improved
# Validation loss 0.9049880470413972 NOT improved
# Validation loss 0.9445553264495768 NOT improved
# Validation loss 0.9103078714741868 NOT improved
# Validation loss 0.9197780488270468 NOT improved
# Validation loss 0.9261431245017416 NOT improved
# Validation loss 0.9555714261595184 NOT improved
# Validation loss 0.9196743222716531 NOT improved
# Validation loss 0.9435343888831764 NOT improved
# Validation loss 0.9152567217909753 NOT improved
# Validation loss 0.9205049795176112 NOT improved
# Validation loss 0.9429929039892422 NOT improved
# Validation loss 0.9216211544800275 NOT improved
# Validation loss 0.93383807204944 NOT improved
# Validation loss 0.9462868086229986 NOT improved
# Validation loss 0.9236520973201066 NOT improved
# Validation loss 0.974515797672699 NOT improved
# Validation loss 1.0226703237428114 NOT improved
# Early stopping
# Training round 5
# Validation loss 0.999169463181456 NOT improved
# Validation loss 0.9982414246904191 NOT improved
# Validation loss 0.9973167217302951 NOT improved
# Validation loss 0.9969578195434932 NOT improved
# Validation loss 0.9960960496397188 NOT improved
# Validation loss 0.9930918174768171 NOT improved
# Validation loss 0.9917849474434665 NOT improved
# Validation loss 0.9913962443349871 NOT improved
# Validation loss 0.9912423126726108 NOT improved
# Validation loss 0.9911542617082157 NOT improved
# Validation loss 0.9908732940148994 NOT improved
# Validation loss 0.990377974703337 NOT improved
# Validation loss 0.9900881068940177 NOT improved
# Validation loss 0.9895711388431323 NOT improved
# Validation loss 0.9886486403220209 NOT improved
# Validation loss 0.9877056683086154 NOT improved
# Validation loss 0.9871942371141411 NOT improved
# Validation loss 0.986569718007991 NOT improved
# Validation loss 0.9856523966792041 NOT improved
# Validation loss 0.9849621644603381 NOT improved
# Validation loss 0.9844828772224058 NOT improved
# Validation loss 0.9839246133570393 NOT improved
# Validation loss 0.9826699633997528 NOT improved
# Validation loss 0.9823179269603907 NOT improved
# Validation loss 0.9809886040553802 NOT improved
# Validation loss 0.9793404976596572 NOT improved
# Validation loss 0.9772953754696884 NOT improved
# Validation loss 0.9758182304844776 NOT improved
# Validation loss 0.9739894777557222 NOT improved
# Validation loss 0.9717933492113745 NOT improved
# Validation loss 0.9705228083677392 NOT improved
# Validation loss 0.9682282265703726 NOT improved
# Validation loss 0.9668539716279297 NOT improved
# Validation loss 0.9642792800257708 NOT improved
# Validation loss 0.960962865554448 NOT improved
# Validation loss 0.9587548475435154 NOT improved
# Validation loss 0.9551020260123487 NOT improved
# Validation loss 0.9522603196537838 NOT improved
# Validation loss 0.9496883701071215 NOT improved
# Validation loss 0.946643330554409 NOT improved
# Validation loss 0.9428130804460692 NOT improved
# Validation loss 0.9404447560693333 NOT improved
# Validation loss 0.9361217860136549 NOT improved
# Validation loss 0.9324160824729797 NOT improved
# Validation loss 0.9275311067772477 NOT improved
# Validation loss 0.9247859097709913 NOT improved
# Validation loss 0.9218995420096692 NOT improved
# Validation loss 0.9188933424558912 NOT improved
# Validation loss 0.9149479625630398 NOT improved
# Validation loss 0.9113183858359675 NOT improved
# Validation loss 0.9085756459341315 NOT improved
# Validation loss 0.9047989717843506 NOT improved
# Validation loss 0.9018685223607376 NOT improved
# Validation loss 0.8983107756650367 NOT improved
# Validation loss 0.8948445054063764 NOT improved
# Validation loss 0.891972148870692 NOT improved
# Validation loss 0.8921520919633948 NOT improved
# Validation loss 0.8902991385833955 NOT improved
# Validation loss 0.8889738420754549 NOT improved
# Validation loss 0.8897983045836928 NOT improved
# Validation loss 0.8947670599499251 NOT improved
# Validation loss 0.8963878789343918 NOT improved
# Validation loss 0.8967196875707013 NOT improved
# Validation loss 0.9026720859545178 NOT improved
# Validation loss 0.8985634767755872 NOT improved
# Validation loss 0.905676303117572 NOT improved
# Validation loss 0.9132906876191952 NOT improved
# Validation loss 0.9166239452247001 NOT improved
# Validation loss 0.9087548291583005 NOT improved
# Validation loss 0.9154007182582145 NOT improved
# Validation loss 0.9517304171260534 NOT improved
# Validation loss 0.9840633368637665 NOT improved
# Validation loss 0.963901165463096 NOT improved
# Validation loss 0.9228864704857626 NOT improved
# Validation loss 1.0064952258815387 NOT improved
# Early stopping
# Training round 6
# Validation loss 0.9999405900544097 NOT improved
# Validation loss 0.9991006603880116 NOT improved
# Validation loss 0.9969278906468688 NOT improved
# Validation loss 0.9949452344251655 NOT improved
# Validation loss 0.9896955012853696 NOT improved
# Validation loss 0.9769071061047034 NOT improved
# Validation loss 0.9669700760837844 NOT improved
# Validation loss 0.9623962231289955 NOT improved
# Validation loss 0.9447911211216448 NOT improved
# Validation loss 0.937293720115931 NOT improved
# Validation loss 0.9377882507562753 NOT improved
# Validation loss 0.9371127796414013 NOT improved
# Validation loss 0.9331760162077689 NOT improved
# Validation loss 0.9308337279589299 NOT improved
# Validation loss 0.9305679374814605 NOT improved
# Validation loss 0.930109221790203 NOT improved
# Validation loss 0.9304976716050384 NOT improved
# Validation loss 0.9285881393372026 NOT improved
# Validation loss 0.9268239227937555 NOT improved
# Validation loss 0.9250806148783698 NOT improved

# %%
seeds[r]
# Out:
# 5646523431

# %%
0.8648959337310276

# %%
model = create_model()

model.compile(loss=keras.losses.BinaryCrossentropy(from_logits=False),
              optimizer=keras.optimizers.Adam(lr=0))

W_old = k_utils.dummy_loader('/glade/work/ksha/NCAR/Keras_models/HY_Lead{}'.format(lead_name))
model.set_weights(W_old)

# %%
ref = np.sum(VALID_Y) / len(VALID_Y)
Y_pred = model.predict([VALID_X, VALID_merge])
record_temp = verif_metric(VALID_Y, Y_pred, ref)

# %%
# save_dict = {}
# save_dict['Y_pred'] = Y_pred
# save_dict['VALID_Y'] = VALID_Y
# np.save('{}RESULT_BASE_lead{}_base.npy'.format(filepath_vec, lead), save_dict)
# print('{}RESULT_BASE_lead{}_base.npy'.format(filepath_vec, lead))

# %%
record_temp
# Out:
# 0.8665634567700535

# %%
plt.plot(Y_pred)

# %%
plt.plot(Y_pred)

# %%
plt.plot(Y_pred)
