# %%
from datetime import datetime, timedelta

# %%
base = datetime(2017, 1, 1)
date_list = [base + timedelta(days=day) for day in range(365*6)]

# %%
for dt in date_list:
    dt_str = datetime.strftime(dt, '%Y%m%d')
    print('wget https://storage.googleapis.com/high-resolution-rapid-refresh/hrrr.{}/conus/hrrr.t00z.wrfnatf06.grib2 -O HRRR.{}.natf06.grib2'.format(dt_str, dt_str))
# Out:
# wget https://storage.googleapis.com/high-resolution-rapid-refresh/hrrr.20170101/conus/hrrr.t00z.wrfnatf06.grib2 -O HRRR.20170101.natf06.grib2
# wget https://storage.googleapis.com/high-resolution-rapid-refresh/hrrr.20170102/conus/hrrr.t00z.wrfnatf06.grib2 -O HRRR.20170102.natf06.grib2
# wget https://storage.googleapis.com/high-resolution-rapid-refresh/hrrr.20170103/conus/hrrr.t00z.wrfnatf06.grib2 -O HRRR.20170103.natf06.grib2
# wget https://storage.googleapis.com/high-resolution-rapid-refresh/hrrr.20170104/conus/hrrr.t00z.wrfnatf06.grib2 -O HRRR.20170104.natf06.grib2
# wget https://storage.googleapis.com/high-resolution-rapid-refresh/hrrr.20170105/conus/hrrr.t00z.wrfnatf06.grib2 -O HRRR.20170105.natf06.grib2
# wget https://storage.googleapis.com/high-resolution-rapid-refresh/hrrr.20170106/conus/hrrr.t00z.wrfnatf06.grib2 -O HRRR.20170106.natf06.grib2
# ...
